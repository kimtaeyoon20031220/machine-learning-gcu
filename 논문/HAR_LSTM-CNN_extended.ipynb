# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values


# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    #filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '../../dataset/UCI_HAR/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '../../dataset/UCI_HAR/UCI HAR Dataset/')
    
    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1
    #one hot encode y
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# (7352, 128, 6) (7352, 1) (7352, 6) (2947, 128, 6) (2947, 1) (2947, 6)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 6)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 6)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
print("0: Walking:" ,np.where(trainy == 0)[0].size)
print("1: WU:" ,np.where(trainy == 1)[0].size)
print("2: WD:" ,np.where(trainy == 2)[0].size)
print("3: Sitting:" ,np.where(trainy == 3)[0].size)
print("4: Standing:" ,np.where(trainy == 4)[0].size)
print("5: Laying:" ,np.where(trainy == 5)[0].size)
# Out:
# 0: Walking: 1226
# 1: WU: 1073
# 2: WD: 986
# 3: Sitting: 1286
# 4: Standing: 1374
# 5: Laying: 1407

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)  

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1226]
#  [   1 1073]
#  [   2  986]
#  [   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  0 496]
#  [  1 471]
#  [  2 420]
#  [  3 491]
#  [  4 532]
#  [  5 537]]

# %%
X_train_all = trainX   # at this stage, the data includes both dynamic and static HAR data
y_train_all = trainy

X_test_all = testX
y_test_all = testy

# %%
X_train_all = (X_train_all - X_train_all.min()) / (X_train_all.max() - X_train_all.min())
X_test_all = (X_test_all - X_test_all.min()) / (X_test_all.max() - X_test_all.min())

X_train_all = X_train_all.astype('float32')
X_test_all = X_test_all.astype('float32')

# %%
import random

static_2 = np.where(trainy  == 0)[0]
static_3 = np.where(trainy == 1)[0]
static_4 = np.where(trainy  == 2)[0]

dynamic_3 = np.where(trainy == 3)[0]
dynamic_4 = np.where(trainy == 4)[0]
dynamic_5 = np.where(trainy == 5)[0]

static = np.concatenate([static_2, static_3, static_4])
static_list = static.tolist()

dynamic = np.concatenate([dynamic_3, dynamic_4, dynamic_5])
dynamic_list = dynamic.tolist()

# Shuffle dynamic data index
r = random.random()
random.shuffle(static_list, lambda: r)
random.shuffle(dynamic_list, lambda: r)

static = np.array(static_list)
dynamic = np.array(dynamic_list)

trainX_static = X_train_all[static]
trainy_static = y_train_all[static]

trainX_dynamic = X_train_all[dynamic]
trainy_dynamic = y_train_all[dynamic]

trainX_combined = X_train_all
trainy_combined = y_train_all
# Out:
# /var/folders/hf/lrx32m9n0n7f1twmsv3x62gw0000gn/T/ipykernel_67257/1208802571.py:19: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(static_list, lambda: r)
# /var/folders/hf/lrx32m9n0n7f1twmsv3x62gw0000gn/T/ipykernel_67257/1208802571.py:20: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(dynamic_list, lambda: r)

# %%
static_2 = np.where(testy == 0)[0]
static_3 = np.where(testy == 1)[0]
static_4 = np.where(testy == 2)[0]
static = np.concatenate([static_2, static_3, static_4])
static_list = static.tolist()

dynamic_3 = np.where(testy == 3)[0]
dynamic_4 = np.where(testy == 4)[0]
dynamic_5 = np.where(testy == 5)[0]
dynamic = np.concatenate([dynamic_3, dynamic_4, dynamic_5])
dynamic_list = dynamic.tolist()

r = random.random()
random.shuffle(static_list, lambda: r)
random.shuffle(dynamic_list, lambda: r)

static = np.array(static_list)
dynamic = np.array(dynamic_list)

testX_static = X_test_all[static]
testy_static = y_test_all[static]

testX_dynamic = X_test_all[dynamic]
testy_dynamic = y_test_all[dynamic]

testX_combined = X_test_all
testy_combined = y_test_all
# Out:
# /var/folders/hf/lrx32m9n0n7f1twmsv3x62gw0000gn/T/ipykernel_67257/3041243064.py:14: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(static_list, lambda: r)
# /var/folders/hf/lrx32m9n0n7f1twmsv3x62gw0000gn/T/ipykernel_67257/3041243064.py:15: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(dynamic_list, lambda: r)

# %%
print("Train 0_s: Walking:" ,np.where(testy_static == 0)[0].size)
print("Train1_s: WU:" ,np.where(testy_static == 1)[0].size)
print("Train2_s: WD:" ,np.where(testy_static == 2)[0].size)
print("Train3_s: Sitting:" ,np.where(testy_static == 3)[0].size)
print("Train4_s: Standing:" ,np.where(testy_static == 4)[0].size)
print("Train5_s: Laying:" ,np.where(testy_static == 5)[0].size) 

print("Test 0_s: Walking:" ,np.where(trainy_static == 0)[0].size)
print("Test 1_s: WU:" ,np.where(trainy_static == 1)[0].size)
print("Test 2_s: WD:" ,np.where(trainy_static == 2)[0].size)
print("Test 3_s: Sitting:" ,np.where(trainy_static == 3)[0].size)
print("Test 4_s: Standing:" ,np.where(trainy_static == 4)[0].size)
print("Test 5_s: Laying:" ,np.where(trainy_static == 5)[0].size)
# Out:
# Train 0_s: Walking: 496
# Train1_s: WU: 471
# Train2_s: WD: 420
# Train3_s: Sitting: 0
# Train4_s: Standing: 0
# Train5_s: Laying: 0
# Test 0_s: Walking: 1226
# Test 1_s: WU: 1073
# Test 2_s: WD: 986
# Test 3_s: Sitting: 0
# Test 4_s: Standing: 0
# Test 5_s: Laying: 0

# %%
print("Train 0_d: Walking:" ,np.where(testy_dynamic == 0)[0].size)
print("Train1_d: WU:" ,np.where(testy_dynamic == 1)[0].size)
print("Train2_d: WD:" ,np.where(testy_dynamic == 2)[0].size)
print("Train3_d: Sitting:" ,np.where(testy_dynamic == 3)[0].size)
print("Train4_d: Standing:" ,np.where(testy_dynamic == 4)[0].size)
print("Train5_d: Laying:" ,np.where(testy_dynamic == 5)[0].size) 

print("Test 0_d: Walking:" ,np.where(trainy_dynamic == 0)[0].size)
print("Test 1_d: WU:" ,np.where(trainy_dynamic == 1)[0].size)
print("Test 2_d: WD:" ,np.where(trainy_dynamic == 2)[0].size)
print("Test 3_d: Sitting:" ,np.where(trainy_dynamic == 3)[0].size)
print("Test 4_d: Standing:" ,np.where(trainy_dynamic == 4)[0].size)
print("Test 5_d: Laying:" ,np.where(trainy_dynamic == 5)[0].size)
# Out:
# Train 0_d: Walking: 0
# Train1_d: WU: 0
# Train2_d: WD: 0
# Train3_d: Sitting: 491
# Train4_d: Standing: 532
# Train5_d: Laying: 537
# Test 0_d: Walking: 0
# Test 1_d: WU: 0
# Test 2_d: WD: 0
# Test 3_d: Sitting: 1286
# Test 4_d: Standing: 1374
# Test 5_d: Laying: 1407

# %%
trainy_static_one_hot = to_categorical(trainy_static)
testy_static_one_hot = to_categorical(testy_static)

trainy_dynamic_one_hot = to_categorical(trainy_dynamic)
testy_dynamic_one_hot = to_categorical(testy_dynamic)

trainy_combined_one_hot = to_categorical(trainy)
testy_combined_one_hot = to_categorical(testy)

# %%
print("X train shape: ", trainX_static.shape)
print("Y train shape: ", trainy_static.shape)
print("Y train One hot shape: ", trainy_static_one_hot.shape)
print("X test shape: ", testX_static.shape)
print("Y test shape: ", testy_static.shape)
print("Y test One hot shape: ", testy_static_one_hot.shape)
# Out:
# X train shape:  (3285, 128, 6)
# Y train shape:  (3285, 1)
# Y train One hot shape:  (3285, 3)
# X test shape:  (1387, 128, 6)
# Y test shape:  (1387, 1)
# Y test One hot shape:  (1387, 3)

# %%
print("X train shape: ", trainX_dynamic.shape)
print("Y train shape: ", trainy_dynamic.shape)
print("Y train One hot shape: ", trainy_dynamic_one_hot.shape)
print("X test shape: ", testX_dynamic.shape)
print("Y test shape: ", testy_dynamic.shape)
print("Y test One hot shape: ", testy_dynamic_one_hot.shape)
# Out:
# X train shape:  (4067, 128, 6)
# Y train shape:  (4067, 1)
# Y train One hot shape:  (4067, 6)
# X test shape:  (1560, 128, 6)
# Y test shape:  (1560, 1)
# Y test One hot shape:  (1560, 6)

# %%
print("X train shape: ", trainX_combined.shape)
print("Y train shape: ", trainy_combined.shape)
print("Y train One hot shape: ", trainy_combined_one_hot.shape)
print("X test shape: ", testX_combined.shape)
print("Y test shape: ", testy_combined.shape)
print("Y test One hot shape: ", testy_combined_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 6)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 6)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
unique, counts = np.unique(trainy_static, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)  

unique, counts = np.unique(testy_static, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1226]
#  [   1 1073]
#  [   2  986]]
# Test data label statistics::
# [[  0 496]
#  [  1 471]
#  [  2 420]]

# %%
unique, counts = np.unique(trainy_dynamic, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)  

unique, counts = np.unique(testy_dynamic, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  3 491]
#  [  4 532]
#  [  5 537]]

# %%
unique, counts = np.unique(trainy_combined, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)  

unique, counts = np.unique(testy_combined, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1226]
#  [   1 1073]
#  [   2  986]
#  [   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  0 496]
#  [  1 471]
#  [  2 420]
#  [  3 491]
#  [  4 532]
#  [  5 537]]

# %%
from sklearn.model_selection import train_test_split

X_train_static,X_val_static,y_train_static_one_hot,y_val_static_one_hot,y_train_static,y_val_static=train_test_split(trainX_static, trainy_static_one_hot, trainy_static,test_size=0.2,random_state=100)

# %%
from sklearn.model_selection import train_test_split

X_train_dynamic,X_val_dynamic,y_train_dynamic_one_hot,y_val_dynamic_one_hot,y_train_dynamic,y_val_dynamic=train_test_split(trainX_dynamic, trainy_dynamic_one_hot, trainy_dynamic,test_size=0.2,random_state=100)

# %%
from sklearn.model_selection import train_test_split

X_train_combined,X_val_combined,y_train_combined_one_hot,y_val_combined_one_hot,y_train_combined,y_val_combined=train_test_split(trainX_combined, trainy_combined_one_hot, trainy_combined,test_size=0.2,random_state=100)

# %%
X_train_combined.shape, y_train_combined.shape, testX_combined.shape, testy_combined.shape
# Out:
# ((5881, 128, 6), (5881, 1), (2947, 128, 6), (2947, 1))

# %%
n_timesteps_dynamic, n_features_dynamic, n_outputs_dynamic = X_train_dynamic.shape[1], X_train_dynamic.shape[2], testy_dynamic_one_hot.shape[1]

# %%
n_timesteps_static, n_features_static, n_outputs_static = X_train_static.shape[1], X_train_static.shape[2], testy_static_one_hot.shape[1]

# %%
n_timesteps_combined, n_features_combined, n_outputs_combined = X_train_combined.shape[1], X_train_combined.shape[2], testy_combined_one_hot.shape[1]

# %%
n_timesteps_static, n_features_static, n_outputs_static, n_timesteps_dynamic, n_features_dynamic, n_outputs_dynamic, n_timesteps_combined, n_features_combined, n_features_combined
# Out:
# (128, 6, 3, 128, 6, 6, 128, 6, 6)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout

import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, InputLayer, Dropout, Flatten, BatchNormalization, Conv1D, GlobalAveragePooling1D
from tensorflow.keras.layers import concatenate
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import SGD
from keras.utils import to_categorical

# %% [markdown]
# # Model

# %%
learning_rate = 0.0001
momentum = 0.9
sgd = SGD(lr=learning_rate, momentum=momentum,  nesterov=False)
# Out:
# /Users/kimtaeyoon/opt/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
def L1C1(n_timesteps, n_features, n_outputs):
    model = Sequential([
        LSTM(64, input_shape=(n_timesteps, n_features), return_sequences=True, activation='relu'),
        Dropout(0.3),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        GlobalAveragePooling1D(),
        BatchNormalization(epsilon=1e-06),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    return model

# %%
def L1C2(n_timesteps, n_features, n_outputs):
    model = Sequential([
        LSTM(64, input_shape=(n_timesteps, n_features), return_sequences=True, activation='relu'),
        Dropout(0.3),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        MaxPooling1D(5),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        GlobalAveragePooling1D(),
        BatchNormalization(epsilon=1e-06),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def L2C1(n_timesteps, n_features, n_outputs):
    model = Sequential([
        LSTM(64, input_shape=(n_timesteps, n_features), return_sequences=True, activation='relu'),
        Dropout(0.3),
        LSTM(64, return_sequences=True, activation='relu'),
        Dropout(0.3),
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)),
        GlobalAveragePooling1D(),
        BatchNormalization(epsilon=1e-06),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def L2C2(n_timesteps, n_features, n_outputs):
    model = Sequential([
        LSTM(64, input_shape=(n_timesteps, n_features), return_sequences=True, activation='relu'),
        Dropout(0.3),
        LSTM(64, activation='relu', return_sequences=True),
        Dropout(0.3),
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)),
        MaxPooling1D(5),
        Conv1D(filters=64, kernel_size=3, activation='relu'),
        GlobalAveragePooling1D(),
        BatchNormalization(epsilon=1e-06),
        Dense(n_outputs, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
import os
MODEL_SAVE_FOLDER_PATH = './model/'
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)

# %% [markdown]
# # Static

# %%
def make_static_history(model, filename):
    model_path = MODEL_SAVE_FOLDER_PATH + f'{filename}_static' + '-{epoch:02d}-{val_loss:.4f}.hdf5'
    cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    return model.fit(x=X_train_static, y=y_train_static_one_hot, epochs=50, batch_size=32, validation_data=(X_val_static, y_val_static_one_hot), callbacks=[cb_checkpoint])

# %%
X_train_static.shape, y_train_static_one_hot.shape, X_val_static.shape, y_val_static_one_hot.shape
# Out:
# ((2628, 128, 6), (2628, 3), (657, 128, 6), (657, 3))

# %%
# fit network
L1C1_model_static = L1C1(n_timesteps_static, n_features_static, n_outputs_static)
L1C2_model_static = L1C2(n_timesteps_static, n_features_static, n_outputs_static)
L2C1_model_static = L2C1(n_timesteps_static, n_features_static, n_outputs_static)
L2C2_model_static = L2C2(n_timesteps_static, n_features_static, n_outputs_static)

L1C1_history_static = make_static_history(L1C1_model_static, "L1C1")
L1C2_history_static = make_static_history(L1C2_model_static, "L1C2")
L2C1_history_static = make_static_history(L2C1_model_static, "L2C1")
L2C2_history_static = make_static_history(L2C2_model_static, "L2C2")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128, 64)           18176
#
#  dropout (Dropout)           (None, 128, 64)           0
#
#  conv1d (Conv1D)             (None, 126, 64)           12352
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 30,979
# Trainable params: 30,851
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 0.6859 - accuracy: 0.6990
# Epoch 1: val_loss improved from inf to 1.07784, saving model to ./model/L1C1_static-01-1.0778.hdf5
# 83/83 [==============================] - 5s 43ms/step - loss: 0.6859 - accuracy: 0.6990 - val_loss: 1.0778 - val_accuracy: 0.4033
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4285 - accuracy: 0.8120
# Epoch 2: val_loss improved from 1.07784 to 1.06981, saving model to ./model/L1C1_static-02-1.0698.hdf5
# 83/83 [==============================] - 4s 51ms/step - loss: 0.4285 - accuracy: 0.8120 - val_loss: 1.0698 - val_accuracy: 0.3333
# Epoch 3/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.3314 - accuracy: 0.8670
# Epoch 3: val_loss improved from 1.06981 to 1.06908, saving model to ./model/L1C1_static-03-1.0691.hdf5
# 83/83 [==============================] - 4s 46ms/step - loss: 0.3309 - accuracy: 0.8672 - val_loss: 1.0691 - val_accuracy: 0.3333
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9094
# Epoch 4: val_loss improved from 1.06908 to 1.04325, saving model to ./model/L1C1_static-04-1.0432.hdf5
# 83/83 [==============================] - 3s 40ms/step - loss: 0.2442 - accuracy: 0.9094 - val_loss: 1.0432 - val_accuracy: 0.3333
# Epoch 5/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.1892 - accuracy: 0.9318
# Epoch 5: val_loss improved from 1.04325 to 0.97010, saving model to ./model/L1C1_static-05-0.9701.hdf5
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1894 - accuracy: 0.9319 - val_loss: 0.9701 - val_accuracy: 0.6651
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9425
# Epoch 6: val_loss improved from 0.97010 to 0.85264, saving model to ./model/L1C1_static-06-0.8526.hdf5
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1487 - accuracy: 0.9425 - val_loss: 0.8526 - val_accuracy: 0.9011
# Epoch 7/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.1208 - accuracy: 0.9581
# Epoch 7: val_loss improved from 0.85264 to 0.82028, saving model to ./model/L1C1_static-07-0.8203.hdf5
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1209 - accuracy: 0.9581 - val_loss: 0.8203 - val_accuracy: 0.5495
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9608
# Epoch 8: val_loss improved from 0.82028 to 0.53630, saving model to ./model/L1C1_static-08-0.5363.hdf5
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1079 - accuracy: 0.9608 - val_loss: 0.5363 - val_accuracy: 0.8295
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9699
# Epoch 9: val_loss improved from 0.53630 to 0.48705, saving model to ./model/L1C1_static-09-0.4871.hdf5
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0884 - accuracy: 0.9699 - val_loss: 0.4871 - val_accuracy: 0.8813
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9741
# Epoch 10: val_loss improved from 0.48705 to 0.40797, saving model to ./model/L1C1_static-10-0.4080.hdf5
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0778 - accuracy: 0.9741 - val_loss: 0.4080 - val_accuracy: 0.7945
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9718
# Epoch 11: val_loss improved from 0.40797 to 0.12913, saving model to ./model/L1C1_static-11-0.1291.hdf5
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0823 - accuracy: 0.9718 - val_loss: 0.1291 - val_accuracy: 0.9802
# Epoch 12/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9851
# Epoch 12: val_loss improved from 0.12913 to 0.12204, saving model to ./model/L1C1_static-12-0.1220.hdf5
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0496 - accuracy: 0.9848 - val_loss: 0.1220 - val_accuracy: 0.9772
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9749
# Epoch 13: val_loss improved from 0.12204 to 0.05788, saving model to ./model/L1C1_static-13-0.0579.hdf5
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0671 - accuracy: 0.9749 - val_loss: 0.0579 - val_accuracy: 0.9893
# Epoch 14/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0491 - accuracy: 0.9825
# Epoch 14: val_loss did not improve from 0.05788
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0493 - accuracy: 0.9825 - val_loss: 0.1300 - val_accuracy: 0.9482
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9798
# Epoch 15: val_loss did not improve from 0.05788
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0564 - accuracy: 0.9798 - val_loss: 0.2094 - val_accuracy: 0.9285
# Epoch 16/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0626 - accuracy: 0.9768
# Epoch 16: val_loss did not improve from 0.05788
# 83/83 [==============================] - 4s 45ms/step - loss: 0.0626 - accuracy: 0.9768 - val_loss: 0.0633 - val_accuracy: 0.9756
# Epoch 17/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0447 - accuracy: 0.9855
# Epoch 17: val_loss did not improve from 0.05788
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0446 - accuracy: 0.9855 - val_loss: 0.1207 - val_accuracy: 0.9513
# Epoch 18/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0403 - accuracy: 0.9870
# Epoch 18: val_loss did not improve from 0.05788
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0431 - accuracy: 0.9863 - val_loss: 4.6445 - val_accuracy: 0.5875
# Epoch 19/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9463
# Epoch 19: val_loss did not improve from 0.05788
# 83/83 [==============================] - 3s 40ms/step - loss: 0.1413 - accuracy: 0.9463 - val_loss: 0.2267 - val_accuracy: 0.8980
# Epoch 20/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0533 - accuracy: 0.9832
# Epoch 20: val_loss did not improve from 0.05788
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0533 - accuracy: 0.9833 - val_loss: 1.1455 - val_accuracy: 0.6423
# Epoch 21/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9806
# Epoch 21: val_loss improved from 0.05788 to 0.03711, saving model to ./model/L1C1_static-21-0.0371.hdf5
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0491 - accuracy: 0.9806 - val_loss: 0.0371 - val_accuracy: 0.9909
# Epoch 22/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9691
# Epoch 22: val_loss did not improve from 0.03711
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0826 - accuracy: 0.9688 - val_loss: 4.3039 - val_accuracy: 0.3349
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0614 - accuracy: 0.9772
# Epoch 23: val_loss did not improve from 0.03711
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0614 - accuracy: 0.9772 - val_loss: 0.1668 - val_accuracy: 0.9346
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.9905
# Epoch 24: val_loss did not improve from 0.03711
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.8126 - val_accuracy: 0.8204
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9783
# Epoch 25: val_loss improved from 0.03711 to 0.01949, saving model to ./model/L1C1_static-25-0.0195.hdf5
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0617 - accuracy: 0.9783 - val_loss: 0.0195 - val_accuracy: 0.9954
# Epoch 26/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0374 - accuracy: 0.9874
# Epoch 26: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0374 - accuracy: 0.9874 - val_loss: 0.0312 - val_accuracy: 0.9909
# Epoch 27/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9863
# Epoch 27: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0369 - accuracy: 0.9863 - val_loss: 0.0826 - val_accuracy: 0.9696
# Epoch 28/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0368 - accuracy: 0.9867
# Epoch 28: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 39ms/step - loss: 0.0368 - accuracy: 0.9867 - val_loss: 0.1954 - val_accuracy: 0.9254
# Epoch 29/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0257 - accuracy: 0.9924
# Epoch 29: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 40ms/step - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.0248 - val_accuracy: 0.9924
# Epoch 30/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9874
# Epoch 30: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 0.1691 - val_accuracy: 0.9269
# Epoch 31/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9707
# Epoch 31: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0754 - accuracy: 0.9707 - val_loss: 0.1978 - val_accuracy: 0.9148
# Epoch 32/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9855
# Epoch 32: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0406 - accuracy: 0.9855 - val_loss: 3.2663 - val_accuracy: 0.6423
# Epoch 33/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0345 - accuracy: 0.9859
# Epoch 33: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0346 - accuracy: 0.9859 - val_loss: 0.1424 - val_accuracy: 0.9391
# Epoch 34/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9916
# Epoch 34: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0283 - accuracy: 0.9916 - val_loss: 0.0860 - val_accuracy: 0.9756
# Epoch 35/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0318 - accuracy: 0.9893
# Epoch 35: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 1.8765 - val_accuracy: 0.6362
# Epoch 36/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0365 - accuracy: 0.9889
# Epoch 36: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0372 - accuracy: 0.9886 - val_loss: 0.9385 - val_accuracy: 0.7123
# Epoch 37/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9764
# Epoch 37: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0606 - accuracy: 0.9764 - val_loss: 0.6446 - val_accuracy: 0.7717
# Epoch 38/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9890
# Epoch 38: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0331 - accuracy: 0.9890 - val_loss: 0.0564 - val_accuracy: 0.9848
# Epoch 39/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9851
# Epoch 39: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0330 - accuracy: 0.9852 - val_loss: 0.1427 - val_accuracy: 0.9528
# Epoch 40/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0360 - accuracy: 0.9886
# Epoch 40: val_loss did not improve from 0.01949
# 83/83 [==============================] - 3s 41ms/step - loss: 0.0360 - accuracy: 0.9886 - val_loss: 0.3576 - val_accuracy: 0.8554
# Epoch 41/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0262 - accuracy: 0.9905
# Epoch 41: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0268 - accuracy: 0.9901 - val_loss: 0.5387 - val_accuracy: 0.8234
# Epoch 42/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9726
# Epoch 42: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0713 - accuracy: 0.9726 - val_loss: 0.3517 - val_accuracy: 0.8721
# Epoch 43/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9901
# Epoch 43: val_loss did not improve from 0.01949
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0248 - accuracy: 0.9901 - val_loss: 0.1788 - val_accuracy: 0.9269
# Epoch 44/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9951
# Epoch 44: val_loss improved from 0.01949 to 0.01635, saving model to ./model/L1C1_static-44-0.0163.hdf5
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.0163 - val_accuracy: 0.9954
# Epoch 45/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0258 - accuracy: 0.9901
# Epoch 45: val_loss did not improve from 0.01635
# 83/83 [==============================] - 4s 45ms/step - loss: 0.0257 - accuracy: 0.9901 - val_loss: 0.1627 - val_accuracy: 0.9498
# Epoch 46/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9950
# Epoch 46: val_loss did not improve from 0.01635
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.0741 - val_accuracy: 0.9696
# Epoch 47/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0216 - accuracy: 0.9935
# Epoch 47: val_loss did not improve from 0.01635
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.2324 - val_accuracy: 0.9224
# Epoch 48/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9707
# Epoch 48: val_loss did not improve from 0.01635
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0827 - accuracy: 0.9707 - val_loss: 0.1045 - val_accuracy: 0.9574
# Epoch 49/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9893
# Epoch 49: val_loss did not improve from 0.01635
# 83/83 [==============================] - 3s 42ms/step - loss: 0.0305 - accuracy: 0.9893 - val_loss: 1.4484 - val_accuracy: 0.7275
# Epoch 50/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9870
# Epoch 50: val_loss did not improve from 0.01635
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0375 - accuracy: 0.9871 - val_loss: 0.2196 - val_accuracy: 0.9056
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 0.7601 - accuracy: 0.6682
# Epoch 1: val_loss improved from inf to 1.06870, saving model to ./model/L1C2_static-01-1.0687.hdf5
# 83/83 [==============================] - 5s 48ms/step - loss: 0.7601 - accuracy: 0.6682 - val_loss: 1.0687 - val_accuracy: 0.4033
# Epoch 2/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.5141 - accuracy: 0.7881
# Epoch 2: val_loss improved from 1.06870 to 1.04781, saving model to ./model/L1C2_static-02-1.0478.hdf5
# 83/83 [==============================] - 4s 45ms/step - loss: 0.5140 - accuracy: 0.7881 - val_loss: 1.0478 - val_accuracy: 0.3333
# Epoch 3/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.3807 - accuracy: 0.8476
# Epoch 3: val_loss improved from 1.04781 to 0.94551, saving model to ./model/L1C2_static-03-0.9455.hdf5
# 83/83 [==============================] - 4s 44ms/step - loss: 0.3803 - accuracy: 0.8478 - val_loss: 0.9455 - val_accuracy: 0.5084
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.9083
# Epoch 4: val_loss improved from 0.94551 to 0.80589, saving model to ./model/L1C2_static-04-0.8059.hdf5
# 83/83 [==============================] - 4s 48ms/step - loss: 0.2600 - accuracy: 0.9083 - val_loss: 0.8059 - val_accuracy: 0.8782
# Epoch 5/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9242
# Epoch 5: val_loss did not improve from 0.80589
# 83/83 [==============================] - 4s 46ms/step - loss: 0.2078 - accuracy: 0.9239 - val_loss: 1.2850 - val_accuracy: 0.3333
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2361 - accuracy: 0.9148
# Epoch 6: val_loss did not improve from 0.80589
# 83/83 [==============================] - 4s 45ms/step - loss: 0.2361 - accuracy: 0.9148 - val_loss: 0.9595 - val_accuracy: 0.3349
# Epoch 7/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.1373 - accuracy: 0.9486
# Epoch 7: val_loss did not improve from 0.80589
# 83/83 [==============================] - 4s 44ms/step - loss: 0.1371 - accuracy: 0.9486 - val_loss: 0.8627 - val_accuracy: 0.5616
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9593
# Epoch 8: val_loss did not improve from 0.80589
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1167 - accuracy: 0.9593 - val_loss: 0.9260 - val_accuracy: 0.5951
# Epoch 9/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0926 - accuracy: 0.9668
# Epoch 9: val_loss improved from 0.80589 to 0.76465, saving model to ./model/L1C2_static-09-0.7647.hdf5
# 83/83 [==============================] - 5s 66ms/step - loss: 0.0926 - accuracy: 0.9669 - val_loss: 0.7647 - val_accuracy: 0.5936
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9612
# Epoch 10: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1018 - accuracy: 0.9612 - val_loss: 0.9054 - val_accuracy: 0.5967
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9623
# Epoch 11: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0920 - accuracy: 0.9623 - val_loss: 1.2800 - val_accuracy: 0.3866
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9703
# Epoch 12: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 51ms/step - loss: 0.0925 - accuracy: 0.9703 - val_loss: 1.9129 - val_accuracy: 0.5114
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9768
# Epoch 13: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0716 - accuracy: 0.9768 - val_loss: 1.1245 - val_accuracy: 0.5616
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9722
# Epoch 14: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0929 - accuracy: 0.9722 - val_loss: 1.8487 - val_accuracy: 0.2709
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9806
# Epoch 15: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0601 - accuracy: 0.9806 - val_loss: 0.9090 - val_accuracy: 0.4932
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9775
# Epoch 16: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0643 - accuracy: 0.9775 - val_loss: 0.7866 - val_accuracy: 0.6180
# Epoch 17/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9809
# Epoch 17: val_loss did not improve from 0.76465
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0630 - accuracy: 0.9810 - val_loss: 1.7882 - val_accuracy: 0.4125
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9787
# Epoch 18: val_loss improved from 0.76465 to 0.23952, saving model to ./model/L1C2_static-18-0.2395.hdf5
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0590 - accuracy: 0.9787 - val_loss: 0.2395 - val_accuracy: 0.9482
# Epoch 19/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9813
# Epoch 19: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0618 - accuracy: 0.9814 - val_loss: 0.4033 - val_accuracy: 0.8676
# Epoch 20/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9882
# Epoch 20: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0436 - accuracy: 0.9882 - val_loss: 1.3171 - val_accuracy: 0.5967
# Epoch 21/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9844
# Epoch 21: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0469 - accuracy: 0.9844 - val_loss: 0.6294 - val_accuracy: 0.5951
# Epoch 22/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9871
# Epoch 22: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0412 - accuracy: 0.9871 - val_loss: 2.3243 - val_accuracy: 0.5495
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0680 - accuracy: 0.9745
# Epoch 23: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 43ms/step - loss: 0.0680 - accuracy: 0.9745 - val_loss: 0.3162 - val_accuracy: 0.8661
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9775
# Epoch 24: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 45ms/step - loss: 0.0618 - accuracy: 0.9775 - val_loss: 0.6161 - val_accuracy: 0.7154
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9829
# Epoch 25: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 49ms/step - loss: 0.0445 - accuracy: 0.9829 - val_loss: 1.9676 - val_accuracy: 0.5906
# Epoch 26/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.1377 - accuracy: 0.9512
# Epoch 26: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 48ms/step - loss: 0.1375 - accuracy: 0.9513 - val_loss: 2.3695 - val_accuracy: 0.3333
# Epoch 27/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9859
# Epoch 27: val_loss did not improve from 0.23952
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0431 - accuracy: 0.9859 - val_loss: 0.4637 - val_accuracy: 0.7382
# Epoch 28/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9833
# Epoch 28: val_loss improved from 0.23952 to 0.15999, saving model to ./model/L1C2_static-28-0.1600.hdf5
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0441 - accuracy: 0.9833 - val_loss: 0.1600 - val_accuracy: 0.9696
# Epoch 29/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9821
# Epoch 29: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0472 - accuracy: 0.9821 - val_loss: 2.9822 - val_accuracy: 0.5845
# Epoch 30/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.9840
# Epoch 30: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0426 - accuracy: 0.9840 - val_loss: 3.1278 - val_accuracy: 0.3820
# Epoch 31/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0313 - accuracy: 0.9905
# Epoch 31: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 2.6137 - val_accuracy: 0.5175
# Epoch 32/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9859
# Epoch 32: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0420 - accuracy: 0.9859 - val_loss: 2.3759 - val_accuracy: 0.5601
# Epoch 33/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9855
# Epoch 33: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 45ms/step - loss: 0.0369 - accuracy: 0.9855 - val_loss: 4.8072 - val_accuracy: 0.3486
# Epoch 34/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0393 - accuracy: 0.9874
# Epoch 34: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0402 - accuracy: 0.9871 - val_loss: 4.0047 - val_accuracy: 0.3409
# Epoch 35/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0551 - accuracy: 0.9821
# Epoch 35: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0550 - accuracy: 0.9821 - val_loss: 3.4998 - val_accuracy: 0.4353
# Epoch 36/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9882
# Epoch 36: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0295 - accuracy: 0.9882 - val_loss: 3.1069 - val_accuracy: 0.4810
# Epoch 37/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9886
# Epoch 37: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0344 - accuracy: 0.9886 - val_loss: 8.1657 - val_accuracy: 0.3349
# Epoch 38/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9912
# Epoch 38: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0279 - accuracy: 0.9912 - val_loss: 2.5198 - val_accuracy: 0.5495
# Epoch 39/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0239 - accuracy: 0.9928
# Epoch 39: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0251 - accuracy: 0.9924 - val_loss: 3.6829 - val_accuracy: 0.5890
# Epoch 40/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9764
# Epoch 40: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 51ms/step - loss: 0.0597 - accuracy: 0.9764 - val_loss: 5.2695 - val_accuracy: 0.4460
# Epoch 41/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9912
# Epoch 41: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 6.1967 - val_accuracy: 0.3333
# Epoch 42/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9909
# Epoch 42: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.7902 - val_accuracy: 0.7397
# Epoch 43/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0385 - accuracy: 0.9886
# Epoch 43: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0385 - accuracy: 0.9886 - val_loss: 6.8117 - val_accuracy: 0.3729
# Epoch 44/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0274 - accuracy: 0.9920
# Epoch 44: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0273 - accuracy: 0.9920 - val_loss: 3.0403 - val_accuracy: 0.5906
# Epoch 45/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9920
# Epoch 45: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 47ms/step - loss: 0.0220 - accuracy: 0.9920 - val_loss: 0.3375 - val_accuracy: 0.8615
# Epoch 46/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0748 - accuracy: 0.9760
# Epoch 46: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 48ms/step - loss: 0.0752 - accuracy: 0.9756 - val_loss: 2.5457 - val_accuracy: 0.4231
# Epoch 47/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9867
# Epoch 47: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 46ms/step - loss: 0.0453 - accuracy: 0.9867 - val_loss: 3.0108 - val_accuracy: 0.4368
# Epoch 48/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9871
# Epoch 48: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 45ms/step - loss: 0.0407 - accuracy: 0.9871 - val_loss: 4.5508 - val_accuracy: 0.3364
# Epoch 49/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9791
# Epoch 49: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 44ms/step - loss: 0.0598 - accuracy: 0.9791 - val_loss: 4.0375 - val_accuracy: 0.4962
# Epoch 50/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9429
# Epoch 50: val_loss did not improve from 0.15999
# 83/83 [==============================] - 4s 45ms/step - loss: 0.1926 - accuracy: 0.9429 - val_loss: 0.3351 - val_accuracy: 0.8737
# Epoch 1/50
# 83/83 [==============================] - ETA: 0s - loss: 0.9483 - accuracy: 0.5495
# Epoch 1: val_loss improved from inf to 1.08282, saving model to ./model/L2C1_static-01-1.0828.hdf5
# 83/83 [==============================] - 9s 94ms/step - loss: 0.9483 - accuracy: 0.5495 - val_loss: 1.0828 - val_accuracy: 0.4033
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4237 - accuracy: 0.8166
# Epoch 2: val_loss improved from 1.08282 to 1.06650, saving model to ./model/L2C1_static-02-1.0665.hdf5
# 83/83 [==============================] - 7s 90ms/step - loss: 0.4237 - accuracy: 0.8166 - val_loss: 1.0665 - val_accuracy: 0.4033
# Epoch 3/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.8961
# Epoch 3: val_loss improved from 1.06650 to 1.03834, saving model to ./model/L2C1_static-03-1.0383.hdf5
# 83/83 [==============================] - 8s 91ms/step - loss: 0.2519 - accuracy: 0.8961 - val_loss: 1.0383 - val_accuracy: 0.3333
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9212
# Epoch 4: val_loss did not improve from 1.03834
# 83/83 [==============================] - 8s 93ms/step - loss: 0.2110 - accuracy: 0.9212 - val_loss: 1.0523 - val_accuracy: 0.3333
# Epoch 5/50
# 83/83 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.9220
# Epoch 5: val_loss improved from 1.03834 to 0.90569, saving model to ./model/L2C1_static-05-0.9057.hdf5
# 83/83 [==============================] - 7s 88ms/step - loss: 0.2103 - accuracy: 0.9220 - val_loss: 0.9057 - val_accuracy: 0.6591
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9566
# Epoch 6: val_loss improved from 0.90569 to 0.89964, saving model to ./model/L2C1_static-06-0.8996.hdf5
# 83/83 [==============================] - 8s 97ms/step - loss: 0.1208 - accuracy: 0.9566 - val_loss: 0.8996 - val_accuracy: 0.3577
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9597
# Epoch 7: val_loss improved from 0.89964 to 0.69329, saving model to ./model/L2C1_static-07-0.6933.hdf5
# 83/83 [==============================] - 7s 90ms/step - loss: 0.1134 - accuracy: 0.9597 - val_loss: 0.6933 - val_accuracy: 0.7321
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9612
# Epoch 8: val_loss improved from 0.69329 to 0.51269, saving model to ./model/L2C1_static-08-0.5127.hdf5
# 83/83 [==============================] - 8s 95ms/step - loss: 0.1147 - accuracy: 0.9612 - val_loss: 0.5127 - val_accuracy: 0.8767
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9745
# Epoch 9: val_loss improved from 0.51269 to 0.42397, saving model to ./model/L2C1_static-09-0.4240.hdf5
# 83/83 [==============================] - 8s 94ms/step - loss: 0.0738 - accuracy: 0.9745 - val_loss: 0.4240 - val_accuracy: 0.9361
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9684
# Epoch 10: val_loss improved from 0.42397 to 0.23856, saving model to ./model/L2C1_static-10-0.2386.hdf5
# 83/83 [==============================] - 8s 100ms/step - loss: 0.0945 - accuracy: 0.9684 - val_loss: 0.2386 - val_accuracy: 0.9406
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9680
# Epoch 11: val_loss did not improve from 0.23856
# 83/83 [==============================] - 8s 92ms/step - loss: 0.0851 - accuracy: 0.9680 - val_loss: 0.4546 - val_accuracy: 0.7854
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9775
# Epoch 12: val_loss did not improve from 0.23856
# 83/83 [==============================] - 7s 89ms/step - loss: 0.0688 - accuracy: 0.9775 - val_loss: 0.9498 - val_accuracy: 0.7047
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9783
# Epoch 13: val_loss improved from 0.23856 to 0.08522, saving model to ./model/L2C1_static-13-0.0852.hdf5
# 83/83 [==============================] - 7s 88ms/step - loss: 0.0560 - accuracy: 0.9783 - val_loss: 0.0852 - val_accuracy: 0.9543
# Epoch 14/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0792 - accuracy: 0.9741
# Epoch 14: val_loss did not improve from 0.08522
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0791 - accuracy: 0.9741 - val_loss: 0.6857 - val_accuracy: 0.7732
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9916
# Epoch 15: val_loss did not improve from 0.08522
# 83/83 [==============================] - 8s 98ms/step - loss: 0.0306 - accuracy: 0.9916 - val_loss: 0.2091 - val_accuracy: 0.9132
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0785 - accuracy: 0.9737
# Epoch 16: val_loss did not improve from 0.08522
# 83/83 [==============================] - 7s 89ms/step - loss: 0.0785 - accuracy: 0.9737 - val_loss: 0.1391 - val_accuracy: 0.9482
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9814
# Epoch 17: val_loss did not improve from 0.08522
# 83/83 [==============================] - 8s 91ms/step - loss: 0.0506 - accuracy: 0.9814 - val_loss: 0.1679 - val_accuracy: 0.9422
# Epoch 18/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0948 - accuracy: 0.9638
# Epoch 18: val_loss did not improve from 0.08522
# 83/83 [==============================] - 7s 85ms/step - loss: 0.0955 - accuracy: 0.9635 - val_loss: 0.9697 - val_accuracy: 0.7002
# Epoch 19/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0894 - accuracy: 0.9688
# Epoch 19: val_loss did not improve from 0.08522
# 83/83 [==============================] - 7s 89ms/step - loss: 0.0899 - accuracy: 0.9684 - val_loss: 0.2381 - val_accuracy: 0.9224
# Epoch 20/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0568 - accuracy: 0.9790
# Epoch 20: val_loss did not improve from 0.08522
# 83/83 [==============================] - 8s 93ms/step - loss: 0.0567 - accuracy: 0.9791 - val_loss: 0.5441 - val_accuracy: 0.7991
# Epoch 21/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0457 - accuracy: 0.9825
# Epoch 21: val_loss improved from 0.08522 to 0.03252, saving model to ./model/L2C1_static-21-0.0325.hdf5
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0484 - accuracy: 0.9821 - val_loss: 0.0325 - val_accuracy: 0.9863
# Epoch 22/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0714 - accuracy: 0.9768
# Epoch 22: val_loss did not improve from 0.03252
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0714 - accuracy: 0.9768 - val_loss: 0.1712 - val_accuracy: 0.9315
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9874
# Epoch 23: val_loss did not improve from 0.03252
# 83/83 [==============================] - 7s 83ms/step - loss: 0.0367 - accuracy: 0.9874 - val_loss: 0.3818 - val_accuracy: 0.8691
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9890
# Epoch 24: val_loss did not improve from 0.03252
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0351 - accuracy: 0.9890 - val_loss: 0.0335 - val_accuracy: 0.9878
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9939
# Epoch 25: val_loss did not improve from 0.03252
# 83/83 [==============================] - 7s 83ms/step - loss: 0.0217 - accuracy: 0.9939 - val_loss: 0.0527 - val_accuracy: 0.9817
# Epoch 26/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9760
# Epoch 26: val_loss improved from 0.03252 to 0.02767, saving model to ./model/L2C1_static-26-0.0277.hdf5
# 83/83 [==============================] - 8s 92ms/step - loss: 0.0720 - accuracy: 0.9760 - val_loss: 0.0277 - val_accuracy: 0.9924
# Epoch 27/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0380 - accuracy: 0.9848
# Epoch 27: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 84ms/step - loss: 0.0381 - accuracy: 0.9848 - val_loss: 0.0463 - val_accuracy: 0.9863
# Epoch 28/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9893
# Epoch 28: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0280 - accuracy: 0.9893 - val_loss: 0.2763 - val_accuracy: 0.9072
# Epoch 29/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9817
# Epoch 29: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 85ms/step - loss: 0.0480 - accuracy: 0.9817 - val_loss: 0.0349 - val_accuracy: 0.9848
# Epoch 30/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0300 - accuracy: 0.9909
# Epoch 30: val_loss did not improve from 0.02767
# 83/83 [==============================] - 8s 102ms/step - loss: 0.0300 - accuracy: 0.9909 - val_loss: 0.2218 - val_accuracy: 0.9087
# Epoch 31/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9943
# Epoch 31: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 88ms/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.0550 - val_accuracy: 0.9848
# Epoch 32/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9909
# Epoch 32: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 84ms/step - loss: 0.0241 - accuracy: 0.9909 - val_loss: 0.6857 - val_accuracy: 0.7900
# Epoch 33/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0451 - accuracy: 0.9821
# Epoch 33: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 86ms/step - loss: 0.0450 - accuracy: 0.9821 - val_loss: 0.0419 - val_accuracy: 0.9878
# Epoch 34/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9886
# Epoch 34: val_loss did not improve from 0.02767
# 83/83 [==============================] - 7s 83ms/step - loss: 0.0351 - accuracy: 0.9886 - val_loss: 0.0777 - val_accuracy: 0.9772
# Epoch 35/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9958
# Epoch 35: val_loss improved from 0.02767 to 0.01236, saving model to ./model/L2C1_static-35-0.0124.hdf5
# 83/83 [==============================] - 7s 86ms/step - loss: 0.0166 - accuracy: 0.9958 - val_loss: 0.0124 - val_accuracy: 0.9970
# Epoch 36/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9893
# Epoch 36: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 86ms/step - loss: 0.0283 - accuracy: 0.9893 - val_loss: 0.0759 - val_accuracy: 0.9650
# Epoch 37/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9920
# Epoch 37: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 89ms/step - loss: 0.0311 - accuracy: 0.9920 - val_loss: 0.0206 - val_accuracy: 0.9954
# Epoch 38/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9852
# Epoch 38: val_loss did not improve from 0.01236
# 83/83 [==============================] - 8s 91ms/step - loss: 0.0531 - accuracy: 0.9852 - val_loss: 0.4262 - val_accuracy: 0.8569
# Epoch 39/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9566
# Epoch 39: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 88ms/step - loss: 0.1194 - accuracy: 0.9566 - val_loss: 0.0778 - val_accuracy: 0.9665
# Epoch 40/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9848
# Epoch 40: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0421 - accuracy: 0.9848 - val_loss: 0.0659 - val_accuracy: 0.9802
# Epoch 41/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9890
# Epoch 41: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 86ms/step - loss: 0.0341 - accuracy: 0.9890 - val_loss: 1.0643 - val_accuracy: 0.7336
# Epoch 42/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9764
# Epoch 42: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 85ms/step - loss: 0.0688 - accuracy: 0.9764 - val_loss: 0.0158 - val_accuracy: 0.9970
# Epoch 43/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9878
# Epoch 43: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 88ms/step - loss: 0.0366 - accuracy: 0.9878 - val_loss: 0.3360 - val_accuracy: 0.8630
# Epoch 44/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9874
# Epoch 44: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 84ms/step - loss: 0.0346 - accuracy: 0.9874 - val_loss: 0.3003 - val_accuracy: 0.8980
# Epoch 45/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9951
# Epoch 45: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 88ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.0871 - val_accuracy: 0.9665
# Epoch 46/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9958
# Epoch 46: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0738 - val_accuracy: 0.9635
# Epoch 47/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9966
# Epoch 47: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 87ms/step - loss: 0.0135 - accuracy: 0.9966 - val_loss: 0.0203 - val_accuracy: 0.9924
# Epoch 48/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9912
# Epoch 48: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 85ms/step - loss: 0.0243 - accuracy: 0.9912 - val_loss: 0.3669 - val_accuracy: 0.8995
# Epoch 49/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9836
# Epoch 49: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 86ms/step - loss: 0.0458 - accuracy: 0.9836 - val_loss: 0.1623 - val_accuracy: 0.9437
# Epoch 50/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9928
# Epoch 50: val_loss did not improve from 0.01236
# 83/83 [==============================] - 7s 84ms/step - loss: 0.0252 - accuracy: 0.9928 - val_loss: 0.0180 - val_accuracy: 0.9924
# Epoch 1/50
# 82/83 [============================>.] - ETA: 0s - loss: 0.8607 - accuracy: 0.5934
# Epoch 1: val_loss improved from inf to 1.07819, saving model to ./model/L2C2_static-01-1.0782.hdf5
# 83/83 [==============================] - 9s 89ms/step - loss: 0.8612 - accuracy: 0.5928 - val_loss: 1.0782 - val_accuracy: 0.4033
# Epoch 2/50
# 83/83 [==============================] - ETA: 0s - loss: 0.4732 - accuracy: 0.8090
# Epoch 2: val_loss did not improve from 1.07819
# 83/83 [==============================] - 7s 85ms/step - loss: 0.4732 - accuracy: 0.8090 - val_loss: 1.1525 - val_accuracy: 0.3318
# Epoch 3/50
# 83/83 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.7941
# Epoch 3: val_loss improved from 1.07819 to 1.07102, saving model to ./model/L2C2_static-03-1.0710.hdf5
# 83/83 [==============================] - 10s 120ms/step - loss: 0.5081 - accuracy: 0.7941 - val_loss: 1.0710 - val_accuracy: 0.3333
# Epoch 4/50
# 83/83 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.8744
# Epoch 4: val_loss improved from 1.07102 to 1.04851, saving model to ./model/L2C2_static-04-1.0485.hdf5
# 83/83 [==============================] - 8s 100ms/step - loss: 0.3190 - accuracy: 0.8744 - val_loss: 1.0485 - val_accuracy: 0.3333
# Epoch 5/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1959 - accuracy: 0.9326
# Epoch 5: val_loss improved from 1.04851 to 0.90223, saving model to ./model/L2C2_static-05-0.9022.hdf5
# 83/83 [==============================] - 8s 94ms/step - loss: 0.1959 - accuracy: 0.9326 - val_loss: 0.9022 - val_accuracy: 0.4490
# Epoch 6/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1740 - accuracy: 0.9365
# Epoch 6: val_loss improved from 0.90223 to 0.82680, saving model to ./model/L2C2_static-06-0.8268.hdf5
# 83/83 [==============================] - 9s 103ms/step - loss: 0.1740 - accuracy: 0.9365 - val_loss: 0.8268 - val_accuracy: 0.6986
# Epoch 7/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9353
# Epoch 7: val_loss improved from 0.82680 to 0.50286, saving model to ./model/L2C2_static-07-0.5029.hdf5
# 83/83 [==============================] - 9s 110ms/step - loss: 0.1748 - accuracy: 0.9353 - val_loss: 0.5029 - val_accuracy: 0.9589
# Epoch 8/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1181 - accuracy: 0.9585
# Epoch 8: val_loss improved from 0.50286 to 0.35235, saving model to ./model/L2C2_static-08-0.3524.hdf5
# 83/83 [==============================] - 8s 93ms/step - loss: 0.1181 - accuracy: 0.9585 - val_loss: 0.3524 - val_accuracy: 0.9482
# Epoch 9/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9570
# Epoch 9: val_loss did not improve from 0.35235
# 83/83 [==============================] - 7s 89ms/step - loss: 0.1159 - accuracy: 0.9570 - val_loss: 0.4627 - val_accuracy: 0.8067
# Epoch 10/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9639
# Epoch 10: val_loss did not improve from 0.35235
# 83/83 [==============================] - 7s 90ms/step - loss: 0.0938 - accuracy: 0.9639 - val_loss: 0.9573 - val_accuracy: 0.7062
# Epoch 11/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9639
# Epoch 11: val_loss improved from 0.35235 to 0.16183, saving model to ./model/L2C2_static-11-0.1618.hdf5
# 83/83 [==============================] - 7s 90ms/step - loss: 0.0954 - accuracy: 0.9639 - val_loss: 0.1618 - val_accuracy: 0.9391
# Epoch 12/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0913 - accuracy: 0.9665
# Epoch 12: val_loss did not improve from 0.16183
# 83/83 [==============================] - 7s 90ms/step - loss: 0.0913 - accuracy: 0.9665 - val_loss: 0.9615 - val_accuracy: 0.7656
# Epoch 13/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9699
# Epoch 13: val_loss did not improve from 0.16183
# 83/83 [==============================] - 9s 103ms/step - loss: 0.0844 - accuracy: 0.9699 - val_loss: 0.7594 - val_accuracy: 0.7626
# Epoch 14/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9787
# Epoch 14: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 98ms/step - loss: 0.0605 - accuracy: 0.9787 - val_loss: 0.4763 - val_accuracy: 0.7854
# Epoch 15/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9639
# Epoch 15: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 91ms/step - loss: 0.0965 - accuracy: 0.9639 - val_loss: 0.7051 - val_accuracy: 0.7976
# Epoch 16/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9768
# Epoch 16: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 91ms/step - loss: 0.0668 - accuracy: 0.9768 - val_loss: 0.3244 - val_accuracy: 0.8600
# Epoch 17/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9692
# Epoch 17: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 91ms/step - loss: 0.0845 - accuracy: 0.9692 - val_loss: 0.3276 - val_accuracy: 0.8630
# Epoch 18/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9753
# Epoch 18: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 101ms/step - loss: 0.0603 - accuracy: 0.9753 - val_loss: 0.4586 - val_accuracy: 0.8234
# Epoch 19/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9768
# Epoch 19: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0603 - accuracy: 0.9768 - val_loss: 3.5443 - val_accuracy: 0.4916
# Epoch 20/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1537 - accuracy: 0.9384
# Epoch 20: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 98ms/step - loss: 0.1537 - accuracy: 0.9384 - val_loss: 0.3034 - val_accuracy: 0.8980
# Epoch 21/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9718
# Epoch 21: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0864 - accuracy: 0.9718 - val_loss: 4.2562 - val_accuracy: 0.6301
# Epoch 22/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9600
# Epoch 22: val_loss did not improve from 0.16183
# 83/83 [==============================] - 8s 100ms/step - loss: 0.1160 - accuracy: 0.9600 - val_loss: 4.0215 - val_accuracy: 0.6210
# Epoch 23/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9589
# Epoch 23: val_loss improved from 0.16183 to 0.10044, saving model to ./model/L2C2_static-23-0.1004.hdf5
# 83/83 [==============================] - 9s 103ms/step - loss: 0.1236 - accuracy: 0.9589 - val_loss: 0.1004 - val_accuracy: 0.9680
# Epoch 24/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9798
# Epoch 24: val_loss did not improve from 0.10044
# 83/83 [==============================] - 8s 100ms/step - loss: 0.0641 - accuracy: 0.9798 - val_loss: 0.8299 - val_accuracy: 0.7108
# Epoch 25/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0568 - accuracy: 0.9795
# Epoch 25: val_loss did not improve from 0.10044
# 83/83 [==============================] - 8s 101ms/step - loss: 0.0568 - accuracy: 0.9795 - val_loss: 0.4105 - val_accuracy: 0.8630
# Epoch 26/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9855
# Epoch 26: val_loss did not improve from 0.10044
# 83/83 [==============================] - 8s 102ms/step - loss: 0.0434 - accuracy: 0.9855 - val_loss: 0.1555 - val_accuracy: 0.9330
# Epoch 27/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9772
# Epoch 27: val_loss did not improve from 0.10044
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0573 - accuracy: 0.9772 - val_loss: 0.6908 - val_accuracy: 0.7839
# Epoch 28/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9661
# Epoch 28: val_loss did not improve from 0.10044
# 83/83 [==============================] - 8s 101ms/step - loss: 0.0966 - accuracy: 0.9661 - val_loss: 0.1759 - val_accuracy: 0.9346
# Epoch 29/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9829
# Epoch 29: val_loss did not improve from 0.10044
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0470 - accuracy: 0.9829 - val_loss: 0.5457 - val_accuracy: 0.8311
# Epoch 30/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9798
# Epoch 30: val_loss improved from 0.10044 to 0.09654, saving model to ./model/L2C2_static-30-0.0965.hdf5
# 83/83 [==============================] - 9s 107ms/step - loss: 0.0607 - accuracy: 0.9798 - val_loss: 0.0965 - val_accuracy: 0.9726
# Epoch 31/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9836
# Epoch 31: val_loss did not improve from 0.09654
# 83/83 [==============================] - 8s 101ms/step - loss: 0.0476 - accuracy: 0.9836 - val_loss: 1.1317 - val_accuracy: 0.6986
# Epoch 32/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9893
# Epoch 32: val_loss did not improve from 0.09654
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 2.1632 - val_accuracy: 0.6104
# Epoch 33/50
# 83/83 [==============================] - ETA: 0s - loss: 0.1262 - accuracy: 0.9570
# Epoch 33: val_loss improved from 0.09654 to 0.02749, saving model to ./model/L2C2_static-33-0.0275.hdf5
# 83/83 [==============================] - 8s 98ms/step - loss: 0.1262 - accuracy: 0.9570 - val_loss: 0.0275 - val_accuracy: 0.9878
# Epoch 34/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0561 - accuracy: 0.9817
# Epoch 34: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 100ms/step - loss: 0.0561 - accuracy: 0.9817 - val_loss: 0.9782 - val_accuracy: 0.7717
# Epoch 35/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9833
# Epoch 35: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 102ms/step - loss: 0.0431 - accuracy: 0.9833 - val_loss: 0.2517 - val_accuracy: 0.9026
# Epoch 36/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0618 - accuracy: 0.9772
# Epoch 36: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 100ms/step - loss: 0.0618 - accuracy: 0.9772 - val_loss: 1.3382 - val_accuracy: 0.7473
# Epoch 37/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9787
# Epoch 37: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 98ms/step - loss: 0.0692 - accuracy: 0.9787 - val_loss: 0.7345 - val_accuracy: 0.8143
# Epoch 38/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9772
# Epoch 38: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 97ms/step - loss: 0.0675 - accuracy: 0.9772 - val_loss: 0.2768 - val_accuracy: 0.9011
# Epoch 39/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9741
# Epoch 39: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0668 - accuracy: 0.9741 - val_loss: 1.3272 - val_accuracy: 0.5951
# Epoch 40/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9760
# Epoch 40: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 94ms/step - loss: 0.0613 - accuracy: 0.9760 - val_loss: 0.0622 - val_accuracy: 0.9817
# Epoch 41/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9912
# Epoch 41: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.6512 - val_accuracy: 0.7976
# Epoch 42/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.9859
# Epoch 42: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 96ms/step - loss: 0.0410 - accuracy: 0.9859 - val_loss: 0.0347 - val_accuracy: 0.9863
# Epoch 43/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9795
# Epoch 43: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 97ms/step - loss: 0.0580 - accuracy: 0.9795 - val_loss: 0.2569 - val_accuracy: 0.8950
# Epoch 44/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 0.9874
# Epoch 44: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 97ms/step - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.0311 - val_accuracy: 0.9893
# Epoch 45/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9806
# Epoch 45: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 96ms/step - loss: 0.0529 - accuracy: 0.9806 - val_loss: 0.4798 - val_accuracy: 0.8584
# Epoch 46/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9810
# Epoch 46: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 96ms/step - loss: 0.0536 - accuracy: 0.9810 - val_loss: 0.1751 - val_accuracy: 0.9254
# Epoch 47/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9886
# Epoch 47: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 98ms/step - loss: 0.0314 - accuracy: 0.9886 - val_loss: 0.2174 - val_accuracy: 0.9254
# Epoch 48/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9897
# Epoch 48: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 94ms/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.1789 - val_accuracy: 0.9285
# Epoch 49/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0910 - accuracy: 0.9680
# Epoch 49: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 99ms/step - loss: 0.0910 - accuracy: 0.9680 - val_loss: 0.5992 - val_accuracy: 0.8174
# Epoch 50/50
# 83/83 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9871
# Epoch 50: val_loss did not improve from 0.02749
# 83/83 [==============================] - 8s 96ms/step - loss: 0.0337 - accuracy: 0.9871 - val_loss: 0.2426 - val_accuracy: 0.9148

# %% [markdown]
# # Dynamic

# %%
def make_dynamic_history(model, filename):
    model_path = MODEL_SAVE_FOLDER_PATH + f'{filename}_dynamic' + '-{epoch:02d}-{val_loss:.4f}.hdf5'
    cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    cb_early_stopping = EarlyStopping(monitor='val_loss', patience=20)
    return model.fit(x=X_train_dynamic, y=y_train_dynamic_one_hot, epochs=50, batch_size=32, validation_data=(X_val_dynamic, y_val_dynamic_one_hot), callbacks=[cb_checkpoint, cb_early_stopping])

# %%
# fit network
L1C1_model_dynamic = L1C1(n_timesteps_dynamic, n_features_dynamic, n_outputs_dynamic)
L1C2_model_dynamic = L1C2(n_timesteps_dynamic, n_features_dynamic, n_outputs_dynamic)
L2C1_model_dynamic = L2C1(n_timesteps_dynamic, n_features_dynamic, n_outputs_dynamic)
L2C2_model_dynamic = L2C2(n_timesteps_dynamic, n_features_dynamic, n_outputs_dynamic)

L1C1_history_dynamic = make_dynamic_history(L1C1_model_dynamic, "L1C1")
L1C2_history_dynamic = make_dynamic_history(L1C2_model_dynamic, "L1C2")
L2C1_history_dynamic = make_dynamic_history(L2C1_model_dynamic, "L2C1")
L2C2_history_dynamic = make_dynamic_history(L2C2_model_dynamic, "L2C2")
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 128, 64)           18176
#
#  dropout_24 (Dropout)        (None, 128, 64)           0
#
#  conv1d_24 (Conv1D)          (None, 126, 64)           12352
#
#  global_average_pooling1d_16  (None, 64)               0
#   (GlobalAveragePooling1D)
#
#  batch_normalization_16 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_16 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 31,174
# Trainable params: 31,046
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 102/102 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8657
# Epoch 1: val_loss improved from inf to 1.52585, saving model to ./model/L1C1_dynamic-01-1.5258.hdf5
# 102/102 [==============================] - 5s 43ms/step - loss: 0.3678 - accuracy: 0.8657 - val_loss: 1.5258 - val_accuracy: 0.4975
# Epoch 2/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2598 - accuracy: 0.8960
# Epoch 2: val_loss improved from 1.52585 to 1.39404, saving model to ./model/L1C1_dynamic-02-1.3940.hdf5
# 102/102 [==============================] - 4s 41ms/step - loss: 0.2593 - accuracy: 0.8964 - val_loss: 1.3940 - val_accuracy: 0.5590
# Epoch 3/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8986
# Epoch 3: val_loss improved from 1.39404 to 1.18116, saving model to ./model/L1C1_dynamic-03-1.1812.hdf5
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2496 - accuracy: 0.8986 - val_loss: 1.1812 - val_accuracy: 0.6609
# Epoch 4/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9047
# Epoch 4: val_loss improved from 1.18116 to 0.92224, saving model to ./model/L1C1_dynamic-04-0.9222.hdf5
# 102/102 [==============================] - 4s 42ms/step - loss: 0.2315 - accuracy: 0.9047 - val_loss: 0.9222 - val_accuracy: 0.6388
# Epoch 5/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2455 - accuracy: 0.9001
# Epoch 5: val_loss improved from 0.92224 to 0.62003, saving model to ./model/L1C1_dynamic-05-0.6200.hdf5
# 102/102 [==============================] - 4s 41ms/step - loss: 0.2455 - accuracy: 0.9001 - val_loss: 0.6200 - val_accuracy: 0.7224
# Epoch 6/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9026
# Epoch 6: val_loss improved from 0.62003 to 0.49372, saving model to ./model/L1C1_dynamic-06-0.4937.hdf5
# 102/102 [==============================] - 4s 42ms/step - loss: 0.2490 - accuracy: 0.9026 - val_loss: 0.4937 - val_accuracy: 0.7002
# Epoch 7/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.8964
# Epoch 7: val_loss improved from 0.49372 to 0.34391, saving model to ./model/L1C1_dynamic-07-0.3439.hdf5
# 102/102 [==============================] - 4s 42ms/step - loss: 0.2424 - accuracy: 0.8964 - val_loss: 0.3439 - val_accuracy: 0.8808
# Epoch 8/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2421 - accuracy: 0.8985
# Epoch 8: val_loss did not improve from 0.34391
# 102/102 [==============================] - 4s 42ms/step - loss: 0.2418 - accuracy: 0.8989 - val_loss: 0.6093 - val_accuracy: 0.6916
# Epoch 9/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2344 - accuracy: 0.9050
# Epoch 9: val_loss improved from 0.34391 to 0.22012, saving model to ./model/L1C1_dynamic-09-0.2201.hdf5
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2344 - accuracy: 0.9050 - val_loss: 0.2201 - val_accuracy: 0.9238
# Epoch 10/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9019
# Epoch 10: val_loss improved from 0.22012 to 0.21466, saving model to ./model/L1C1_dynamic-10-0.2147.hdf5
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2301 - accuracy: 0.9019 - val_loss: 0.2147 - val_accuracy: 0.9103
# Epoch 11/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2329 - accuracy: 0.8985
# Epoch 11: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2345 - accuracy: 0.8986 - val_loss: 0.3695 - val_accuracy: 0.8649
# Epoch 12/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2349 - accuracy: 0.9041
# Epoch 12: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2353 - accuracy: 0.9038 - val_loss: 0.5749 - val_accuracy: 0.7346
# Epoch 13/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2261 - accuracy: 0.9044
# Epoch 13: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2256 - accuracy: 0.9044 - val_loss: 0.6113 - val_accuracy: 0.7015
# Epoch 14/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2386 - accuracy: 0.8998
# Epoch 14: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2386 - accuracy: 0.8998 - val_loss: 0.2246 - val_accuracy: 0.8907
# Epoch 15/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9096
# Epoch 15: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2253 - accuracy: 0.9096 - val_loss: 0.3058 - val_accuracy: 0.8698
# Epoch 16/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9056
# Epoch 16: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2319 - accuracy: 0.9056 - val_loss: 0.3877 - val_accuracy: 0.8206
# Epoch 17/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9072
# Epoch 17: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2295 - accuracy: 0.9072 - val_loss: 0.3667 - val_accuracy: 0.8354
# Epoch 18/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2345 - accuracy: 0.9025
# Epoch 18: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2351 - accuracy: 0.9022 - val_loss: 0.2673 - val_accuracy: 0.8833
# Epoch 19/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9069
# Epoch 19: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2304 - accuracy: 0.9069 - val_loss: 0.3013 - val_accuracy: 0.8833
# Epoch 20/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2394 - accuracy: 0.8998
# Epoch 20: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2392 - accuracy: 0.9001 - val_loss: 0.2486 - val_accuracy: 0.8845
# Epoch 21/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2273 - accuracy: 0.9013
# Epoch 21: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2265 - accuracy: 0.9019 - val_loss: 1.1847 - val_accuracy: 0.6486
# Epoch 22/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.9093
# Epoch 22: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2285 - accuracy: 0.9093 - val_loss: 0.2294 - val_accuracy: 0.8808
# Epoch 23/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2268 - accuracy: 0.9019
# Epoch 23: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2268 - accuracy: 0.9019 - val_loss: 0.5556 - val_accuracy: 0.8047
# Epoch 24/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2346 - accuracy: 0.8963
# Epoch 24: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2343 - accuracy: 0.8967 - val_loss: 0.2577 - val_accuracy: 0.8993
# Epoch 25/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9044
# Epoch 25: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 39ms/step - loss: 0.2354 - accuracy: 0.9044 - val_loss: 0.2960 - val_accuracy: 0.8808
# Epoch 26/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2315 - accuracy: 0.9044
# Epoch 26: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2305 - accuracy: 0.9050 - val_loss: 0.2423 - val_accuracy: 0.9103
# Epoch 27/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2305 - accuracy: 0.9047
# Epoch 27: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2318 - accuracy: 0.9041 - val_loss: 0.2328 - val_accuracy: 0.8833
# Epoch 28/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.8973
# Epoch 28: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2426 - accuracy: 0.8973 - val_loss: 0.9421 - val_accuracy: 0.6339
# Epoch 29/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2386 - accuracy: 0.8991
# Epoch 29: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2380 - accuracy: 0.8995 - val_loss: 0.2557 - val_accuracy: 0.9251
# Epoch 30/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9032
# Epoch 30: val_loss did not improve from 0.21466
# 102/102 [==============================] - 4s 40ms/step - loss: 0.2258 - accuracy: 0.9032 - val_loss: 0.2756 - val_accuracy: 0.8771
# Epoch 1/50
# 102/102 [==============================] - ETA: 0s - loss: 0.3944 - accuracy: 0.8737
# Epoch 1: val_loss improved from inf to 1.43141, saving model to ./model/L1C2_dynamic-01-1.4314.hdf5
# 102/102 [==============================] - 6s 46ms/step - loss: 0.3944 - accuracy: 0.8737 - val_loss: 1.4314 - val_accuracy: 0.8501
# Epoch 2/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.9038
# Epoch 2: val_loss improved from 1.43141 to 1.20474, saving model to ./model/L1C2_dynamic-02-1.2047.hdf5
# 102/102 [==============================] - 5s 44ms/step - loss: 0.2576 - accuracy: 0.9038 - val_loss: 1.2047 - val_accuracy: 0.8956
# Epoch 3/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2658 - accuracy: 0.8957
# Epoch 3: val_loss improved from 1.20474 to 1.01980, saving model to ./model/L1C2_dynamic-03-1.0198.hdf5
# 102/102 [==============================] - 5s 46ms/step - loss: 0.2661 - accuracy: 0.8958 - val_loss: 1.0198 - val_accuracy: 0.8133
# Epoch 4/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2452 - accuracy: 0.9028
# Epoch 4: val_loss improved from 1.01980 to 0.57548, saving model to ./model/L1C2_dynamic-04-0.5755.hdf5
# 102/102 [==============================] - 4s 44ms/step - loss: 0.2468 - accuracy: 0.9016 - val_loss: 0.5755 - val_accuracy: 0.8857
# Epoch 5/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9047
# Epoch 5: val_loss improved from 0.57548 to 0.36350, saving model to ./model/L1C2_dynamic-05-0.3635.hdf5
# 102/102 [==============================] - 5s 44ms/step - loss: 0.2382 - accuracy: 0.9047 - val_loss: 0.3635 - val_accuracy: 0.9238
# Epoch 6/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2367 - accuracy: 0.8985
# Epoch 6: val_loss did not improve from 0.36350
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2367 - accuracy: 0.8982 - val_loss: 0.3767 - val_accuracy: 0.8256
# Epoch 7/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2471 - accuracy: 0.8976
# Epoch 7: val_loss did not improve from 0.36350
# 102/102 [==============================] - 5s 44ms/step - loss: 0.2469 - accuracy: 0.8976 - val_loss: 0.5984 - val_accuracy: 0.8071
# Epoch 8/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2347 - accuracy: 0.9004
# Epoch 8: val_loss improved from 0.36350 to 0.31599, saving model to ./model/L1C2_dynamic-08-0.3160.hdf5
# 102/102 [==============================] - 5s 44ms/step - loss: 0.2344 - accuracy: 0.9004 - val_loss: 0.3160 - val_accuracy: 0.8759
# Epoch 9/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2407 - accuracy: 0.9053
# Epoch 9: val_loss did not improve from 0.31599
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2405 - accuracy: 0.9053 - val_loss: 0.4315 - val_accuracy: 0.7445
# Epoch 10/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.9028
# Epoch 10: val_loss improved from 0.31599 to 0.22011, saving model to ./model/L1C2_dynamic-10-0.2201.hdf5
# 102/102 [==============================] - 5s 46ms/step - loss: 0.2279 - accuracy: 0.9026 - val_loss: 0.2201 - val_accuracy: 0.8956
# Epoch 11/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2262 - accuracy: 0.9072
# Epoch 11: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2263 - accuracy: 0.9075 - val_loss: 0.3863 - val_accuracy: 0.8292
# Epoch 12/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2312 - accuracy: 0.9038
# Epoch 12: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2316 - accuracy: 0.9035 - val_loss: 0.4819 - val_accuracy: 0.7273
# Epoch 13/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2404 - accuracy: 0.8982
# Epoch 13: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2396 - accuracy: 0.8986 - val_loss: 0.2966 - val_accuracy: 0.8649
# Epoch 14/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2304 - accuracy: 0.9075
# Epoch 14: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2299 - accuracy: 0.9078 - val_loss: 0.8452 - val_accuracy: 0.6855
# Epoch 15/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9013
# Epoch 15: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 44ms/step - loss: 0.2310 - accuracy: 0.9013 - val_loss: 0.5727 - val_accuracy: 0.7211
# Epoch 16/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.8998
# Epoch 16: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2306 - accuracy: 0.8998 - val_loss: 0.2979 - val_accuracy: 0.8698
# Epoch 17/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2260 - accuracy: 0.9081
# Epoch 17: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 43ms/step - loss: 0.2253 - accuracy: 0.9087 - val_loss: 0.2401 - val_accuracy: 0.9128
# Epoch 18/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2245 - accuracy: 0.9062
# Epoch 18: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2235 - accuracy: 0.9069 - val_loss: 7.4586 - val_accuracy: 0.3440
# Epoch 19/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2344 - accuracy: 0.9062
# Epoch 19: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2346 - accuracy: 0.9059 - val_loss: 0.2231 - val_accuracy: 0.9251
# Epoch 20/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9090
# Epoch 20: val_loss did not improve from 0.22011
# 102/102 [==============================] - 4s 44ms/step - loss: 0.2230 - accuracy: 0.9090 - val_loss: 0.2792 - val_accuracy: 0.8821
# Epoch 21/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9069
# Epoch 21: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 44ms/step - loss: 0.2258 - accuracy: 0.9069 - val_loss: 0.5296 - val_accuracy: 0.7236
# Epoch 22/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2353 - accuracy: 0.9007
# Epoch 22: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2353 - accuracy: 0.9007 - val_loss: 0.2420 - val_accuracy: 0.9115
# Epoch 23/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2299 - accuracy: 0.9022
# Epoch 23: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 44ms/step - loss: 0.2293 - accuracy: 0.9022 - val_loss: 0.2779 - val_accuracy: 0.8845
# Epoch 24/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2269 - accuracy: 0.9078
# Epoch 24: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 47ms/step - loss: 0.2262 - accuracy: 0.9078 - val_loss: 0.2378 - val_accuracy: 0.9128
# Epoch 25/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2279 - accuracy: 0.9053
# Epoch 25: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2279 - accuracy: 0.9053 - val_loss: 0.9796 - val_accuracy: 0.6486
# Epoch 26/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2293 - accuracy: 0.9004
# Epoch 26: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 46ms/step - loss: 0.2300 - accuracy: 0.9001 - val_loss: 1.0076 - val_accuracy: 0.7310
# Epoch 27/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9112
# Epoch 27: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 46ms/step - loss: 0.2199 - accuracy: 0.9112 - val_loss: 0.2619 - val_accuracy: 0.8771
# Epoch 28/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2270 - accuracy: 0.9062
# Epoch 28: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 47ms/step - loss: 0.2268 - accuracy: 0.9062 - val_loss: 0.3764 - val_accuracy: 0.8563
# Epoch 29/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2253 - accuracy: 0.9081
# Epoch 29: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2250 - accuracy: 0.9081 - val_loss: 0.3694 - val_accuracy: 0.8563
# Epoch 30/50
# 101/102 [============================>.] - ETA: 0s - loss: 0.2258 - accuracy: 0.9053
# Epoch 30: val_loss did not improve from 0.22011
# 102/102 [==============================] - 5s 45ms/step - loss: 0.2257 - accuracy: 0.9053 - val_loss: 0.3549 - val_accuracy: 0.7924
# Epoch 1/50
# 102/102 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.8614
# Epoch 1: val_loss improved from inf to 1.52935, saving model to ./model/L2C1_dynamic-01-1.5294.hdf5
# 102/102 [==============================] - 11s 95ms/step - loss: 0.3628 - accuracy: 0.8614 - val_loss: 1.5294 - val_accuracy: 0.6585
# Epoch 2/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.9010
# Epoch 2: val_loss improved from 1.52935 to 1.34058, saving model to ./model/L2C1_dynamic-02-1.3406.hdf5
# 102/102 [==============================] - 9s 93ms/step - loss: 0.2524 - accuracy: 0.9010 - val_loss: 1.3406 - val_accuracy: 0.7322
# Epoch 3/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.8976
# Epoch 3: val_loss improved from 1.34058 to 1.11865, saving model to ./model/L2C1_dynamic-03-1.1186.hdf5
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2513 - accuracy: 0.8976 - val_loss: 1.1186 - val_accuracy: 0.6241
# Epoch 4/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.8909
# Epoch 4: val_loss improved from 1.11865 to 0.83985, saving model to ./model/L2C1_dynamic-04-0.8399.hdf5
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2700 - accuracy: 0.8909 - val_loss: 0.8399 - val_accuracy: 0.6585
# Epoch 5/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.9019
# Epoch 5: val_loss improved from 0.83985 to 0.71319, saving model to ./model/L2C1_dynamic-05-0.7132.hdf5
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2479 - accuracy: 0.9019 - val_loss: 0.7132 - val_accuracy: 0.7801
# Epoch 6/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.8989
# Epoch 6: val_loss did not improve from 0.71319
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2421 - accuracy: 0.8989 - val_loss: 2.0780 - val_accuracy: 0.3907
# Epoch 7/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.8896
# Epoch 7: val_loss improved from 0.71319 to 0.31273, saving model to ./model/L2C1_dynamic-07-0.3127.hdf5
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2492 - accuracy: 0.8896 - val_loss: 0.3127 - val_accuracy: 0.8784
# Epoch 8/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.8964
# Epoch 8: val_loss improved from 0.31273 to 0.30222, saving model to ./model/L2C1_dynamic-08-0.3022.hdf5
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2415 - accuracy: 0.8964 - val_loss: 0.3022 - val_accuracy: 0.8686
# Epoch 9/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9019
# Epoch 9: val_loss did not improve from 0.30222
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2454 - accuracy: 0.9019 - val_loss: 0.6560 - val_accuracy: 0.8010
# Epoch 10/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.8970
# Epoch 10: val_loss did not improve from 0.30222
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2454 - accuracy: 0.8970 - val_loss: 0.9447 - val_accuracy: 0.7555
# Epoch 11/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.8958
# Epoch 11: val_loss did not improve from 0.30222
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2473 - accuracy: 0.8958 - val_loss: 1.1880 - val_accuracy: 0.7420
# Epoch 12/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.8964
# Epoch 12: val_loss did not improve from 0.30222
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2434 - accuracy: 0.8964 - val_loss: 2.5509 - val_accuracy: 0.5811
# Epoch 13/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.8979
# Epoch 13: val_loss improved from 0.30222 to 0.22042, saving model to ./model/L2C1_dynamic-13-0.2204.hdf5
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2407 - accuracy: 0.8979 - val_loss: 0.2204 - val_accuracy: 0.8894
# Epoch 14/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9062
# Epoch 14: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2301 - accuracy: 0.9062 - val_loss: 0.3813 - val_accuracy: 0.8329
# Epoch 15/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.8986
# Epoch 15: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 93ms/step - loss: 0.2399 - accuracy: 0.8986 - val_loss: 0.6645 - val_accuracy: 0.7064
# Epoch 16/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9084
# Epoch 16: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2315 - accuracy: 0.9084 - val_loss: 1.0933 - val_accuracy: 0.6585
# Epoch 17/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9026
# Epoch 17: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2291 - accuracy: 0.9026 - val_loss: 0.3129 - val_accuracy: 0.8894
# Epoch 18/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.8893
# Epoch 18: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2563 - accuracy: 0.8893 - val_loss: 3.6976 - val_accuracy: 0.3440
# Epoch 19/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2596 - accuracy: 0.8943
# Epoch 19: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2596 - accuracy: 0.8943 - val_loss: 0.5488 - val_accuracy: 0.6843
# Epoch 20/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9078
# Epoch 20: val_loss did not improve from 0.22042
# 102/102 [==============================] - 8s 83ms/step - loss: 0.2265 - accuracy: 0.9078 - val_loss: 0.3129 - val_accuracy: 0.8698
# Epoch 21/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9004
# Epoch 21: val_loss did not improve from 0.22042
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2317 - accuracy: 0.9004 - val_loss: 0.5250 - val_accuracy: 0.7138
# Epoch 22/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2262 - accuracy: 0.9062
# Epoch 22: val_loss improved from 0.22042 to 0.21766, saving model to ./model/L2C1_dynamic-22-0.2177.hdf5
# 102/102 [==============================] - 9s 93ms/step - loss: 0.2262 - accuracy: 0.9062 - val_loss: 0.2177 - val_accuracy: 0.9251
# Epoch 23/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9029
# Epoch 23: val_loss improved from 0.21766 to 0.21716, saving model to ./model/L2C1_dynamic-23-0.2172.hdf5
# 102/102 [==============================] - 9s 89ms/step - loss: 0.2326 - accuracy: 0.9029 - val_loss: 0.2172 - val_accuracy: 0.9238
# Epoch 24/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2302 - accuracy: 0.9056
# Epoch 24: val_loss did not improve from 0.21716
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2302 - accuracy: 0.9056 - val_loss: 0.2814 - val_accuracy: 0.8796
# Epoch 25/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.8992
# Epoch 25: val_loss did not improve from 0.21716
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2447 - accuracy: 0.8992 - val_loss: 0.7643 - val_accuracy: 0.6941
# Epoch 26/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9007
# Epoch 26: val_loss improved from 0.21716 to 0.19773, saving model to ./model/L2C1_dynamic-26-0.1977.hdf5
# 102/102 [==============================] - 9s 91ms/step - loss: 0.2324 - accuracy: 0.9007 - val_loss: 0.1977 - val_accuracy: 0.9017
# Epoch 27/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9029
# Epoch 27: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2317 - accuracy: 0.9029 - val_loss: 0.5237 - val_accuracy: 0.8120
# Epoch 28/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.8989
# Epoch 28: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 90ms/step - loss: 0.2406 - accuracy: 0.8989 - val_loss: 0.5421 - val_accuracy: 0.7297
# Epoch 29/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9087
# Epoch 29: val_loss did not improve from 0.19773
# 102/102 [==============================] - 8s 83ms/step - loss: 0.2238 - accuracy: 0.9087 - val_loss: 0.2235 - val_accuracy: 0.9201
# Epoch 30/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9026
# Epoch 30: val_loss did not improve from 0.19773
# 102/102 [==============================] - 8s 83ms/step - loss: 0.2307 - accuracy: 0.9026 - val_loss: 0.7020 - val_accuracy: 0.7555
# Epoch 31/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.8992
# Epoch 31: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2394 - accuracy: 0.8992 - val_loss: 0.3508 - val_accuracy: 0.8538
# Epoch 32/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9047
# Epoch 32: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2276 - accuracy: 0.9047 - val_loss: 0.2177 - val_accuracy: 0.9263
# Epoch 33/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9004
# Epoch 33: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2305 - accuracy: 0.9004 - val_loss: 0.7492 - val_accuracy: 0.7002
# Epoch 34/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9013
# Epoch 34: val_loss did not improve from 0.19773
# 102/102 [==============================] - 8s 82ms/step - loss: 0.2280 - accuracy: 0.9013 - val_loss: 0.8197 - val_accuracy: 0.6523
# Epoch 35/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2345 - accuracy: 0.9019
# Epoch 35: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2345 - accuracy: 0.9019 - val_loss: 1.0597 - val_accuracy: 0.6032
# Epoch 36/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9069
# Epoch 36: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2303 - accuracy: 0.9069 - val_loss: 0.2058 - val_accuracy: 0.9152
# Epoch 37/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.9084
# Epoch 37: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2309 - accuracy: 0.9084 - val_loss: 0.3653 - val_accuracy: 0.8464
# Epoch 38/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.8982
# Epoch 38: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2432 - accuracy: 0.8982 - val_loss: 0.5312 - val_accuracy: 0.8292
# Epoch 39/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9044
# Epoch 39: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2372 - accuracy: 0.9044 - val_loss: 0.6474 - val_accuracy: 0.6978
# Epoch 40/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9044
# Epoch 40: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 84ms/step - loss: 0.2307 - accuracy: 0.9044 - val_loss: 0.7499 - val_accuracy: 0.6843
# Epoch 41/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.8992
# Epoch 41: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2367 - accuracy: 0.8992 - val_loss: 1.1075 - val_accuracy: 0.6609
# Epoch 42/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.8992
# Epoch 42: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2314 - accuracy: 0.8992 - val_loss: 0.5439 - val_accuracy: 0.7273
# Epoch 43/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2162 - accuracy: 0.9062
# Epoch 43: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 89ms/step - loss: 0.2162 - accuracy: 0.9062 - val_loss: 0.1987 - val_accuracy: 0.9165
# Epoch 44/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9093
# Epoch 44: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2230 - accuracy: 0.9093 - val_loss: 0.4879 - val_accuracy: 0.7494
# Epoch 45/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.9022
# Epoch 45: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2306 - accuracy: 0.9022 - val_loss: 0.2144 - val_accuracy: 0.9214
# Epoch 46/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9035
# Epoch 46: val_loss did not improve from 0.19773
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2322 - accuracy: 0.9035 - val_loss: 0.2263 - val_accuracy: 0.9226
# Epoch 1/50
# 102/102 [==============================] - ETA: 0s - loss: 0.4488 - accuracy: 0.8392
# Epoch 1: val_loss improved from inf to 1.53078, saving model to ./model/L2C2_dynamic-01-1.5308.hdf5
# 102/102 [==============================] - 11s 91ms/step - loss: 0.4488 - accuracy: 0.8392 - val_loss: 1.5308 - val_accuracy: 0.3857
# Epoch 2/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2690 - accuracy: 0.8970
# Epoch 2: val_loss improved from 1.53078 to 1.33001, saving model to ./model/L2C2_dynamic-02-1.3300.hdf5
# 102/102 [==============================] - 9s 90ms/step - loss: 0.2690 - accuracy: 0.8970 - val_loss: 1.3300 - val_accuracy: 0.4779
# Epoch 3/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2573 - accuracy: 0.9004
# Epoch 3: val_loss improved from 1.33001 to 1.04159, saving model to ./model/L2C2_dynamic-03-1.0416.hdf5
# 102/102 [==============================] - 9s 90ms/step - loss: 0.2573 - accuracy: 0.9004 - val_loss: 1.0416 - val_accuracy: 0.6585
# Epoch 4/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2553 - accuracy: 0.8973
# Epoch 4: val_loss improved from 1.04159 to 0.69974, saving model to ./model/L2C2_dynamic-04-0.6997.hdf5
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2553 - accuracy: 0.8973 - val_loss: 0.6997 - val_accuracy: 0.8993
# Epoch 5/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9016
# Epoch 5: val_loss improved from 0.69974 to 0.37975, saving model to ./model/L2C2_dynamic-05-0.3797.hdf5
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2452 - accuracy: 0.9016 - val_loss: 0.3797 - val_accuracy: 0.8833
# Epoch 6/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2458 - accuracy: 0.8995
# Epoch 6: val_loss improved from 0.37975 to 0.26341, saving model to ./model/L2C2_dynamic-06-0.2634.hdf5
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2458 - accuracy: 0.8995 - val_loss: 0.2634 - val_accuracy: 0.8943
# Epoch 7/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.8982
# Epoch 7: val_loss did not improve from 0.26341
# 102/102 [==============================] - 9s 89ms/step - loss: 0.2484 - accuracy: 0.8982 - val_loss: 0.7400 - val_accuracy: 0.7187
# Epoch 8/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9019
# Epoch 8: val_loss improved from 0.26341 to 0.23903, saving model to ./model/L2C2_dynamic-08-0.2390.hdf5
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2445 - accuracy: 0.9019 - val_loss: 0.2390 - val_accuracy: 0.9017
# Epoch 9/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.8958
# Epoch 9: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 89ms/step - loss: 0.2445 - accuracy: 0.8958 - val_loss: 0.3332 - val_accuracy: 0.8612
# Epoch 10/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9019
# Epoch 10: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2355 - accuracy: 0.9019 - val_loss: 0.7020 - val_accuracy: 0.7764
# Epoch 11/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9044
# Epoch 11: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2398 - accuracy: 0.9044 - val_loss: 3.0132 - val_accuracy: 0.5602
# Epoch 12/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.8918
# Epoch 12: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2576 - accuracy: 0.8918 - val_loss: 6.2180 - val_accuracy: 0.3440
# Epoch 13/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.9010
# Epoch 13: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 89ms/step - loss: 0.2497 - accuracy: 0.9010 - val_loss: 1.1371 - val_accuracy: 0.6486
# Epoch 14/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9062
# Epoch 14: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 87ms/step - loss: 0.2357 - accuracy: 0.9062 - val_loss: 1.4072 - val_accuracy: 0.6314
# Epoch 15/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.8992
# Epoch 15: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 85ms/step - loss: 0.2485 - accuracy: 0.8992 - val_loss: 0.8160 - val_accuracy: 0.6241
# Epoch 16/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2355 - accuracy: 0.9019
# Epoch 16: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2355 - accuracy: 0.9019 - val_loss: 0.7572 - val_accuracy: 0.7088
# Epoch 17/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.9035
# Epoch 17: val_loss did not improve from 0.23903
# 102/102 [==============================] - 10s 95ms/step - loss: 0.2318 - accuracy: 0.9035 - val_loss: 0.7346 - val_accuracy: 0.6560
# Epoch 18/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9041
# Epoch 18: val_loss did not improve from 0.23903
# 102/102 [==============================] - 11s 104ms/step - loss: 0.2294 - accuracy: 0.9041 - val_loss: 1.1059 - val_accuracy: 0.6585
# Epoch 19/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9056
# Epoch 19: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 92ms/step - loss: 0.2226 - accuracy: 0.9056 - val_loss: 0.5662 - val_accuracy: 0.6978
# Epoch 20/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2274 - accuracy: 0.9019
# Epoch 20: val_loss did not improve from 0.23903
# 102/102 [==============================] - 10s 94ms/step - loss: 0.2274 - accuracy: 0.9019 - val_loss: 0.8395 - val_accuracy: 0.6646
# Epoch 21/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2434 - accuracy: 0.8955
# Epoch 21: val_loss did not improve from 0.23903
# 102/102 [==============================] - 10s 96ms/step - loss: 0.2434 - accuracy: 0.8955 - val_loss: 0.2865 - val_accuracy: 0.8796
# Epoch 22/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.9065
# Epoch 22: val_loss did not improve from 0.23903
# 102/102 [==============================] - 10s 98ms/step - loss: 0.2397 - accuracy: 0.9065 - val_loss: 0.6799 - val_accuracy: 0.6806
# Epoch 23/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9026
# Epoch 23: val_loss did not improve from 0.23903
# 102/102 [==============================] - 10s 94ms/step - loss: 0.2261 - accuracy: 0.9026 - val_loss: 0.4843 - val_accuracy: 0.7346
# Epoch 24/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9072
# Epoch 24: val_loss did not improve from 0.23903
# 102/102 [==============================] - 10s 96ms/step - loss: 0.2289 - accuracy: 0.9072 - val_loss: 0.7197 - val_accuracy: 0.6757
# Epoch 25/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9004
# Epoch 25: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 88ms/step - loss: 0.2357 - accuracy: 0.9004 - val_loss: 1.2045 - val_accuracy: 0.6450
# Epoch 26/50
# 102/102 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.8976
# Epoch 26: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 86ms/step - loss: 0.2387 - accuracy: 0.8976 - val_loss: 788275.0000 - val_accuracy: 0.3034
# Epoch 27/50
# 102/102 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.6954
# Epoch 27: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 87ms/step - loss: 0.6931 - accuracy: 0.6954 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 28/50
# 102/102 [==============================] - ETA: 0s - loss: 1.1082 - accuracy: 0.3378
# Epoch 28: val_loss did not improve from 0.23903
# 102/102 [==============================] - 9s 89ms/step - loss: 1.1082 - accuracy: 0.3378 - val_loss: nan - val_accuracy: 0.0000e+00

# %% [markdown]
# # Combined

# %%
def make_combined_history(model, filename):
    model_path = MODEL_SAVE_FOLDER_PATH + f'{filename}_combined' + '-{epoch:02d}-{val_loss:.4f}.hdf5'
    cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    cb_early_stopping = EarlyStopping(monitor='val_loss', patience=20)
    return model.fit(x=X_train_combined, y=y_train_combined_one_hot, epochs=50, batch_size=32, validation_data=(X_val_combined, y_val_combined_one_hot), callbacks=[cb_checkpoint, cb_early_stopping])

# %%
# fit network
L1C1_model_combined = L1C1(n_timesteps_combined, n_features_combined, n_outputs_combined)
L1C2_model_combined = L1C2(n_timesteps_combined, n_features_combined, n_outputs_combined)
L2C1_model_combined = L2C1(n_timesteps_combined, n_features_combined, n_outputs_combined)
L2C2_model_combined = L2C2(n_timesteps_combined, n_features_combined, n_outputs_combined)

L1C1_history_combined = make_combined_history(L1C1_model_combined, "L1C1")
L1C2_history_combined = make_combined_history(L1C2_model_combined, "L1C2")
L2C1_history_combined = make_combined_history(L2C1_model_combined, "L2C1")
L2C2_history_combined = make_combined_history(L2C2_model_combined, "L2C2")
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 128, 64)           18176
#
#  dropout_36 (Dropout)        (None, 128, 64)           0
#
#  conv1d_36 (Conv1D)          (None, 126, 64)           12352
#
#  global_average_pooling1d_24  (None, 64)               0
#   (GlobalAveragePooling1D)
#
#  batch_normalization_24 (Bat  (None, 64)               256
#  chNormalization)
#
#  dense_24 (Dense)            (None, 6)                 390
#
# =================================================================
# Total params: 31,174
# Trainable params: 31,046
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.7065 - accuracy: 0.7184
# Epoch 1: val_loss improved from inf to 1.68471, saving model to ./model/L1C1_combined-01-1.6847.hdf5
# 184/184 [==============================] - 9s 44ms/step - loss: 0.7052 - accuracy: 0.7189 - val_loss: 1.6847 - val_accuracy: 0.2944
# Epoch 2/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.4437 - accuracy: 0.8287
# Epoch 2: val_loss improved from 1.68471 to 1.44491, saving model to ./model/L1C1_combined-02-1.4449.hdf5
# 184/184 [==============================] - 8s 43ms/step - loss: 0.4433 - accuracy: 0.8291 - val_loss: 1.4449 - val_accuracy: 0.5085
# Epoch 3/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.3126 - accuracy: 0.8808
# Epoch 3: val_loss improved from 1.44491 to 1.07576, saving model to ./model/L1C1_combined-03-1.0758.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.3119 - accuracy: 0.8811 - val_loss: 1.0758 - val_accuracy: 0.5323
# Epoch 4/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.2550 - accuracy: 0.9008
# Epoch 4: val_loss improved from 1.07576 to 0.58988, saving model to ./model/L1C1_combined-04-0.5899.hdf5
# 184/184 [==============================] - 7s 41ms/step - loss: 0.2547 - accuracy: 0.9007 - val_loss: 0.5899 - val_accuracy: 0.7403
# Epoch 5/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9174
# Epoch 5: val_loss improved from 0.58988 to 0.45864, saving model to ./model/L1C1_combined-05-0.4586.hdf5
# 184/184 [==============================] - 7s 41ms/step - loss: 0.2138 - accuracy: 0.9174 - val_loss: 0.4586 - val_accuracy: 0.8103
# Epoch 6/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9186
# Epoch 6: val_loss improved from 0.45864 to 0.29438, saving model to ./model/L1C1_combined-06-0.2944.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1997 - accuracy: 0.9186 - val_loss: 0.2944 - val_accuracy: 0.8953
# Epoch 7/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.2077 - accuracy: 0.9179
# Epoch 7: val_loss did not improve from 0.29438
# 184/184 [==============================] - 7s 40ms/step - loss: 0.2073 - accuracy: 0.9180 - val_loss: 2.0974 - val_accuracy: 0.6458
# Epoch 8/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1903 - accuracy: 0.9259
# Epoch 8: val_loss improved from 0.29438 to 0.20075, saving model to ./model/L1C1_combined-08-0.2007.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1909 - accuracy: 0.9254 - val_loss: 0.2007 - val_accuracy: 0.9239
# Epoch 9/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9254
# Epoch 9: val_loss improved from 0.20075 to 0.19046, saving model to ./model/L1C1_combined-09-0.1905.hdf5
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1879 - accuracy: 0.9254 - val_loss: 0.1905 - val_accuracy: 0.9171
# Epoch 10/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9301
# Epoch 10: val_loss did not improve from 0.19046
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1749 - accuracy: 0.9301 - val_loss: 0.4181 - val_accuracy: 0.8144
# Epoch 11/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9298
# Epoch 11: val_loss did not improve from 0.19046
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1817 - accuracy: 0.9298 - val_loss: 0.7653 - val_accuracy: 0.7893
# Epoch 12/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1748 - accuracy: 0.9274
# Epoch 12: val_loss improved from 0.19046 to 0.18565, saving model to ./model/L1C1_combined-12-0.1856.hdf5
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1755 - accuracy: 0.9272 - val_loss: 0.1856 - val_accuracy: 0.9286
# Epoch 13/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1644 - accuracy: 0.9334
# Epoch 13: val_loss did not improve from 0.18565
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1642 - accuracy: 0.9333 - val_loss: 0.2366 - val_accuracy: 0.8946
# Epoch 14/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9364
# Epoch 14: val_loss did not improve from 0.18565
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1555 - accuracy: 0.9364 - val_loss: 0.5582 - val_accuracy: 0.7138
# Epoch 15/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1851 - accuracy: 0.9247
# Epoch 15: val_loss did not improve from 0.18565
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1849 - accuracy: 0.9247 - val_loss: 0.8183 - val_accuracy: 0.7852
# Epoch 16/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1508 - accuracy: 0.9378
# Epoch 16: val_loss did not improve from 0.18565
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1504 - accuracy: 0.9381 - val_loss: 0.1995 - val_accuracy: 0.9150
# Epoch 17/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9395
# Epoch 17: val_loss did not improve from 0.18565
# 184/184 [==============================] - 7s 39ms/step - loss: 0.1449 - accuracy: 0.9395 - val_loss: 0.2106 - val_accuracy: 0.9109
# Epoch 18/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1544 - accuracy: 0.9370
# Epoch 18: val_loss improved from 0.18565 to 0.14684, saving model to ./model/L1C1_combined-18-0.1468.hdf5
# 184/184 [==============================] - 7s 41ms/step - loss: 0.1542 - accuracy: 0.9369 - val_loss: 0.1468 - val_accuracy: 0.9320
# Epoch 19/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1440 - accuracy: 0.9417
# Epoch 19: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1440 - accuracy: 0.9417 - val_loss: 1.2977 - val_accuracy: 0.6438
# Epoch 20/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1595 - accuracy: 0.9349
# Epoch 20: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 41ms/step - loss: 0.1595 - accuracy: 0.9349 - val_loss: 0.3092 - val_accuracy: 0.8838
# Epoch 21/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1778 - accuracy: 0.9269
# Epoch 21: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1773 - accuracy: 0.9271 - val_loss: 0.2937 - val_accuracy: 0.8933
# Epoch 22/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1491 - accuracy: 0.9399
# Epoch 22: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1489 - accuracy: 0.9400 - val_loss: 0.3677 - val_accuracy: 0.8647
# Epoch 23/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1507 - accuracy: 0.9394
# Epoch 23: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1511 - accuracy: 0.9393 - val_loss: 0.2636 - val_accuracy: 0.8939
# Epoch 24/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9426
# Epoch 24: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1411 - accuracy: 0.9429 - val_loss: 0.3920 - val_accuracy: 0.8566
# Epoch 25/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1432 - accuracy: 0.9402
# Epoch 25: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1435 - accuracy: 0.9401 - val_loss: 0.3340 - val_accuracy: 0.8715
# Epoch 26/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9447
# Epoch 26: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1377 - accuracy: 0.9447 - val_loss: 0.4902 - val_accuracy: 0.8103
# Epoch 27/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1407 - accuracy: 0.9418
# Epoch 27: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 41ms/step - loss: 0.1406 - accuracy: 0.9418 - val_loss: 0.4674 - val_accuracy: 0.8205
# Epoch 28/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9434
# Epoch 28: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1347 - accuracy: 0.9434 - val_loss: 2.0474 - val_accuracy: 0.6315
# Epoch 29/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9424
# Epoch 29: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1418 - accuracy: 0.9424 - val_loss: 0.2744 - val_accuracy: 0.9007
# Epoch 30/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9468
# Epoch 30: val_loss did not improve from 0.14684
# 184/184 [==============================] - 7s 40ms/step - loss: 0.1299 - accuracy: 0.9468 - val_loss: 0.1505 - val_accuracy: 0.9313
# Epoch 31/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1406 - accuracy: 0.9419
# Epoch 31: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1408 - accuracy: 0.9418 - val_loss: 0.4092 - val_accuracy: 0.8674
# Epoch 32/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9434
# Epoch 32: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1371 - accuracy: 0.9434 - val_loss: 0.3034 - val_accuracy: 0.8926
# Epoch 33/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9452
# Epoch 33: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1347 - accuracy: 0.9452 - val_loss: 0.1928 - val_accuracy: 0.9137
# Epoch 34/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9447
# Epoch 34: val_loss did not improve from 0.14684
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1325 - accuracy: 0.9449 - val_loss: 0.1498 - val_accuracy: 0.9245
# Epoch 35/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1275 - accuracy: 0.9459
# Epoch 35: val_loss did not improve from 0.14684
# 184/184 [==============================] - 8s 45ms/step - loss: 0.1274 - accuracy: 0.9459 - val_loss: 0.1969 - val_accuracy: 0.9164
# Epoch 36/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1340 - accuracy: 0.9447
# Epoch 36: val_loss improved from 0.14684 to 0.13035, saving model to ./model/L1C1_combined-36-0.1303.hdf5
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1348 - accuracy: 0.9444 - val_loss: 0.1303 - val_accuracy: 0.9524
# Epoch 37/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9429
# Epoch 37: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1389 - accuracy: 0.9429 - val_loss: 0.1568 - val_accuracy: 0.9320
# Epoch 38/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1479 - accuracy: 0.9390
# Epoch 38: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1476 - accuracy: 0.9393 - val_loss: 0.4286 - val_accuracy: 0.8545
# Epoch 39/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9412
# Epoch 39: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1386 - accuracy: 0.9412 - val_loss: 0.3527 - val_accuracy: 0.8980
# Epoch 40/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1403 - accuracy: 0.9397
# Epoch 40: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1405 - accuracy: 0.9396 - val_loss: 0.1599 - val_accuracy: 0.9245
# Epoch 41/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9464
# Epoch 41: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1288 - accuracy: 0.9464 - val_loss: 0.1797 - val_accuracy: 0.9184
# Epoch 42/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.9472
# Epoch 42: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1265 - accuracy: 0.9473 - val_loss: 0.2080 - val_accuracy: 0.9143
# Epoch 43/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1219 - accuracy: 0.9500
# Epoch 43: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1218 - accuracy: 0.9500 - val_loss: 0.1927 - val_accuracy: 0.9082
# Epoch 44/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1266 - accuracy: 0.9484
# Epoch 44: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1263 - accuracy: 0.9485 - val_loss: 0.1760 - val_accuracy: 0.9205
# Epoch 45/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1284 - accuracy: 0.9467
# Epoch 45: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 41ms/step - loss: 0.1281 - accuracy: 0.9469 - val_loss: 0.1898 - val_accuracy: 0.9259
# Epoch 46/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9459
# Epoch 46: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1340 - accuracy: 0.9459 - val_loss: 0.1632 - val_accuracy: 0.9381
# Epoch 47/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9474
# Epoch 47: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1280 - accuracy: 0.9473 - val_loss: 0.1530 - val_accuracy: 0.9293
# Epoch 48/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1347 - accuracy: 0.9420
# Epoch 48: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1347 - accuracy: 0.9420 - val_loss: 0.5646 - val_accuracy: 0.8001
# Epoch 49/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9429
# Epoch 49: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1313 - accuracy: 0.9429 - val_loss: 3.0957 - val_accuracy: 0.5262
# Epoch 50/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9442
# Epoch 50: val_loss did not improve from 0.13035
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1321 - accuracy: 0.9444 - val_loss: 0.2073 - val_accuracy: 0.9116
# Epoch 1/50
# 184/184 [==============================] - ETA: 0s - loss: 0.7033 - accuracy: 0.7284
# Epoch 1: val_loss improved from inf to 1.65359, saving model to ./model/L1C2_combined-01-1.6536.hdf5
# 184/184 [==============================] - 10s 47ms/step - loss: 0.7033 - accuracy: 0.7284 - val_loss: 1.6536 - val_accuracy: 0.1652
# Epoch 2/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.3963 - accuracy: 0.8516
# Epoch 2: val_loss improved from 1.65359 to 1.46817, saving model to ./model/L1C2_combined-02-1.4682.hdf5
# 184/184 [==============================] - 8s 45ms/step - loss: 0.3957 - accuracy: 0.8522 - val_loss: 1.4682 - val_accuracy: 0.4092
# Epoch 3/50
# 184/184 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.8709
# Epoch 3: val_loss improved from 1.46817 to 1.10487, saving model to ./model/L1C2_combined-03-1.1049.hdf5
# 184/184 [==============================] - 8s 45ms/step - loss: 0.3319 - accuracy: 0.8709 - val_loss: 1.1049 - val_accuracy: 0.6125
# Epoch 4/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.2805 - accuracy: 0.8875
# Epoch 4: val_loss improved from 1.10487 to 0.81005, saving model to ./model/L1C2_combined-04-0.8101.hdf5
# 184/184 [==============================] - 9s 47ms/step - loss: 0.2812 - accuracy: 0.8871 - val_loss: 0.8101 - val_accuracy: 0.7403
# Epoch 5/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2497 - accuracy: 0.9066
# Epoch 5: val_loss improved from 0.81005 to 0.54883, saving model to ./model/L1C2_combined-05-0.5488.hdf5
# 184/184 [==============================] - 9s 50ms/step - loss: 0.2497 - accuracy: 0.9066 - val_loss: 0.5488 - val_accuracy: 0.8321
# Epoch 6/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9121
# Epoch 6: val_loss did not improve from 0.54883
# 184/184 [==============================] - 8s 45ms/step - loss: 0.2270 - accuracy: 0.9121 - val_loss: 0.7467 - val_accuracy: 0.7145
# Epoch 7/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.2019 - accuracy: 0.9199
# Epoch 7: val_loss did not improve from 0.54883
# 184/184 [==============================] - 9s 48ms/step - loss: 0.2014 - accuracy: 0.9203 - val_loss: 0.6059 - val_accuracy: 0.7988
# Epoch 8/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.2492 - accuracy: 0.9042
# Epoch 8: val_loss improved from 0.54883 to 0.39398, saving model to ./model/L1C2_combined-08-0.3940.hdf5
# 184/184 [==============================] - 9s 49ms/step - loss: 0.2497 - accuracy: 0.9041 - val_loss: 0.3940 - val_accuracy: 0.8185
# Epoch 9/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9206
# Epoch 9: val_loss improved from 0.39398 to 0.37533, saving model to ./model/L1C2_combined-09-0.3753.hdf5
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1973 - accuracy: 0.9206 - val_loss: 0.3753 - val_accuracy: 0.8600
# Epoch 10/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9203
# Epoch 10: val_loss did not improve from 0.37533
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1974 - accuracy: 0.9203 - val_loss: 2.7133 - val_accuracy: 0.5350
# Epoch 11/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.2125 - accuracy: 0.9129
# Epoch 11: val_loss improved from 0.37533 to 0.35103, saving model to ./model/L1C2_combined-11-0.3510.hdf5
# 184/184 [==============================] - 8s 44ms/step - loss: 0.2119 - accuracy: 0.9133 - val_loss: 0.3510 - val_accuracy: 0.8511
# Epoch 12/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1797 - accuracy: 0.9290
# Epoch 12: val_loss did not improve from 0.35103
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1793 - accuracy: 0.9291 - val_loss: 0.3825 - val_accuracy: 0.8382
# Epoch 13/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1643 - accuracy: 0.9339
# Epoch 13: val_loss did not improve from 0.35103
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1648 - accuracy: 0.9337 - val_loss: 0.3883 - val_accuracy: 0.8368
# Epoch 14/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1676 - accuracy: 0.9340
# Epoch 14: val_loss improved from 0.35103 to 0.28089, saving model to ./model/L1C2_combined-14-0.2809.hdf5
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1676 - accuracy: 0.9340 - val_loss: 0.2809 - val_accuracy: 0.8858
# Epoch 15/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1729 - accuracy: 0.9317
# Epoch 15: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1725 - accuracy: 0.9320 - val_loss: 0.5413 - val_accuracy: 0.8131
# Epoch 16/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9366
# Epoch 16: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1541 - accuracy: 0.9366 - val_loss: 0.3113 - val_accuracy: 0.8702
# Epoch 17/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9403
# Epoch 17: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1439 - accuracy: 0.9403 - val_loss: 0.6493 - val_accuracy: 0.7913
# Epoch 18/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1525 - accuracy: 0.9358
# Epoch 18: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1522 - accuracy: 0.9359 - val_loss: 0.6950 - val_accuracy: 0.7097
# Epoch 19/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1455 - accuracy: 0.9419
# Epoch 19: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1459 - accuracy: 0.9418 - val_loss: 0.6688 - val_accuracy: 0.7920
# Epoch 20/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1403 - accuracy: 0.9425
# Epoch 20: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1403 - accuracy: 0.9424 - val_loss: 0.2887 - val_accuracy: 0.8919
# Epoch 21/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1600 - accuracy: 0.9348
# Epoch 21: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1595 - accuracy: 0.9350 - val_loss: 0.3367 - val_accuracy: 0.8634
# Epoch 22/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9394
# Epoch 22: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1449 - accuracy: 0.9395 - val_loss: 0.3019 - val_accuracy: 0.8912
# Epoch 23/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1445 - accuracy: 0.9399
# Epoch 23: val_loss did not improve from 0.28089
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1446 - accuracy: 0.9396 - val_loss: 0.4497 - val_accuracy: 0.8035
# Epoch 24/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9426
# Epoch 24: val_loss improved from 0.28089 to 0.25461, saving model to ./model/L1C2_combined-24-0.2546.hdf5
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1414 - accuracy: 0.9427 - val_loss: 0.2546 - val_accuracy: 0.8681
# Epoch 25/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1361 - accuracy: 0.9438
# Epoch 25: val_loss did not improve from 0.25461
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1359 - accuracy: 0.9441 - val_loss: 0.5431 - val_accuracy: 0.8355
# Epoch 26/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1311 - accuracy: 0.9447
# Epoch 26: val_loss improved from 0.25461 to 0.21697, saving model to ./model/L1C2_combined-26-0.2170.hdf5
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1325 - accuracy: 0.9442 - val_loss: 0.2170 - val_accuracy: 0.9123
# Epoch 27/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9412
# Epoch 27: val_loss did not improve from 0.21697
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1443 - accuracy: 0.9412 - val_loss: 0.5469 - val_accuracy: 0.8042
# Epoch 28/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1419 - accuracy: 0.9392
# Epoch 28: val_loss improved from 0.21697 to 0.15543, saving model to ./model/L1C2_combined-28-0.1554.hdf5
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1422 - accuracy: 0.9390 - val_loss: 0.1554 - val_accuracy: 0.9252
# Epoch 29/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9430
# Epoch 29: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 42ms/step - loss: 0.1420 - accuracy: 0.9430 - val_loss: 0.2023 - val_accuracy: 0.9252
# Epoch 30/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9430
# Epoch 30: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 45ms/step - loss: 0.1410 - accuracy: 0.9430 - val_loss: 0.2852 - val_accuracy: 0.8722
# Epoch 31/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1346 - accuracy: 0.9421
# Epoch 31: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1344 - accuracy: 0.9422 - val_loss: 0.4180 - val_accuracy: 0.8348
# Epoch 32/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1387 - accuracy: 0.9426
# Epoch 32: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1384 - accuracy: 0.9427 - val_loss: 0.4860 - val_accuracy: 0.8525
# Epoch 33/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9429
# Epoch 33: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1380 - accuracy: 0.9429 - val_loss: 0.3344 - val_accuracy: 0.8579
# Epoch 34/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1389 - accuracy: 0.9438
# Epoch 34: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1385 - accuracy: 0.9441 - val_loss: 0.3820 - val_accuracy: 0.8430
# Epoch 35/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1347 - accuracy: 0.9421
# Epoch 35: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1346 - accuracy: 0.9422 - val_loss: 0.2166 - val_accuracy: 0.9130
# Epoch 36/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9469
# Epoch 36: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1272 - accuracy: 0.9469 - val_loss: 1.8112 - val_accuracy: 0.5826
# Epoch 37/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.9428
# Epoch 37: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1446 - accuracy: 0.9427 - val_loss: 0.2122 - val_accuracy: 0.9137
# Epoch 38/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1390 - accuracy: 0.9413
# Epoch 38: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1390 - accuracy: 0.9412 - val_loss: 0.3737 - val_accuracy: 0.8613
# Epoch 39/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1313 - accuracy: 0.9430
# Epoch 39: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1313 - accuracy: 0.9430 - val_loss: 0.1568 - val_accuracy: 0.9293
# Epoch 40/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9488
# Epoch 40: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1202 - accuracy: 0.9488 - val_loss: 0.2598 - val_accuracy: 0.8973
# Epoch 41/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9447
# Epoch 41: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1335 - accuracy: 0.9447 - val_loss: 0.1939 - val_accuracy: 0.9048
# Epoch 42/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1268 - accuracy: 0.9481
# Epoch 42: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 43ms/step - loss: 0.1269 - accuracy: 0.9481 - val_loss: 0.4426 - val_accuracy: 0.8538
# Epoch 43/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1352 - accuracy: 0.9423
# Epoch 43: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 44ms/step - loss: 0.1349 - accuracy: 0.9425 - val_loss: 0.1660 - val_accuracy: 0.9409
# Epoch 44/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9441
# Epoch 44: val_loss did not improve from 0.15543
# 184/184 [==============================] - 9s 49ms/step - loss: 0.1343 - accuracy: 0.9441 - val_loss: 0.1830 - val_accuracy: 0.9164
# Epoch 45/50
# 183/184 [============================>.] - ETA: 0s - loss: 0.1250 - accuracy: 0.9459
# Epoch 45: val_loss did not improve from 0.15543
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1251 - accuracy: 0.9458 - val_loss: 0.1656 - val_accuracy: 0.9300
# Epoch 46/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9458
# Epoch 46: val_loss did not improve from 0.15543
# 184/184 [==============================] - 9s 50ms/step - loss: 0.1269 - accuracy: 0.9458 - val_loss: 0.1962 - val_accuracy: 0.9069
# Epoch 47/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1251 - accuracy: 0.9503
# Epoch 47: val_loss did not improve from 0.15543
# 184/184 [==============================] - 9s 47ms/step - loss: 0.1251 - accuracy: 0.9503 - val_loss: 0.2167 - val_accuracy: 0.8960
# Epoch 48/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9480
# Epoch 48: val_loss did not improve from 0.15543
# 184/184 [==============================] - 8s 46ms/step - loss: 0.1295 - accuracy: 0.9480 - val_loss: 0.2560 - val_accuracy: 0.8899
# Epoch 1/50
# 184/184 [==============================] - ETA: 0s - loss: 0.6867 - accuracy: 0.7300
# Epoch 1: val_loss improved from inf to 1.68217, saving model to ./model/L2C1_combined-01-1.6822.hdf5
# 184/184 [==============================] - 19s 92ms/step - loss: 0.6867 - accuracy: 0.7300 - val_loss: 1.6822 - val_accuracy: 0.1706
# Epoch 2/50
# 184/184 [==============================] - ETA: 0s - loss: 0.3844 - accuracy: 0.8453
# Epoch 2: val_loss improved from 1.68217 to 1.50569, saving model to ./model/L2C1_combined-02-1.5057.hdf5
# 184/184 [==============================] - 17s 93ms/step - loss: 0.3844 - accuracy: 0.8453 - val_loss: 1.5057 - val_accuracy: 0.4555
# Epoch 3/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.8878
# Epoch 3: val_loss improved from 1.50569 to 0.94658, saving model to ./model/L2C1_combined-03-0.9466.hdf5
# 184/184 [==============================] - 19s 102ms/step - loss: 0.2822 - accuracy: 0.8878 - val_loss: 0.9466 - val_accuracy: 0.7627
# Epoch 4/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.8908
# Epoch 4: val_loss improved from 0.94658 to 0.64566, saving model to ./model/L2C1_combined-04-0.6457.hdf5
# 184/184 [==============================] - 16s 89ms/step - loss: 0.2695 - accuracy: 0.8908 - val_loss: 0.6457 - val_accuracy: 0.7104
# Epoch 5/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9100
# Epoch 5: val_loss did not improve from 0.64566
# 184/184 [==============================] - 16s 88ms/step - loss: 0.2269 - accuracy: 0.9100 - val_loss: 0.6460 - val_accuracy: 0.7213
# Epoch 6/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9158
# Epoch 6: val_loss improved from 0.64566 to 0.33706, saving model to ./model/L2C1_combined-06-0.3371.hdf5
# 184/184 [==============================] - 16s 85ms/step - loss: 0.2097 - accuracy: 0.9158 - val_loss: 0.3371 - val_accuracy: 0.8355
# Epoch 7/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9157
# Epoch 7: val_loss improved from 0.33706 to 0.15691, saving model to ./model/L2C1_combined-07-0.1569.hdf5
# 184/184 [==============================] - 16s 85ms/step - loss: 0.2027 - accuracy: 0.9157 - val_loss: 0.1569 - val_accuracy: 0.9252
# Epoch 8/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9204
# Epoch 8: val_loss did not improve from 0.15691
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1967 - accuracy: 0.9204 - val_loss: 0.2338 - val_accuracy: 0.9055
# Epoch 9/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 0.9209
# Epoch 9: val_loss did not improve from 0.15691
# 184/184 [==============================] - 16s 88ms/step - loss: 0.2002 - accuracy: 0.9209 - val_loss: 0.3570 - val_accuracy: 0.8681
# Epoch 10/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9296
# Epoch 10: val_loss did not improve from 0.15691
# 184/184 [==============================] - 17s 92ms/step - loss: 0.1723 - accuracy: 0.9296 - val_loss: 0.1609 - val_accuracy: 0.9354
# Epoch 11/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1896 - accuracy: 0.9209
# Epoch 11: val_loss did not improve from 0.15691
# 184/184 [==============================] - 18s 95ms/step - loss: 0.1896 - accuracy: 0.9209 - val_loss: 0.1981 - val_accuracy: 0.9150
# Epoch 12/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9318
# Epoch 12: val_loss improved from 0.15691 to 0.15447, saving model to ./model/L2C1_combined-12-0.1545.hdf5
# 184/184 [==============================] - 17s 92ms/step - loss: 0.1656 - accuracy: 0.9318 - val_loss: 0.1545 - val_accuracy: 0.9252
# Epoch 13/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9328
# Epoch 13: val_loss did not improve from 0.15447
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1709 - accuracy: 0.9328 - val_loss: 0.5051 - val_accuracy: 0.7675
# Epoch 14/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9299
# Epoch 14: val_loss did not improve from 0.15447
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1666 - accuracy: 0.9299 - val_loss: 0.3002 - val_accuracy: 0.8851
# Epoch 15/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1713 - accuracy: 0.9272
# Epoch 15: val_loss did not improve from 0.15447
# 184/184 [==============================] - 16s 86ms/step - loss: 0.1713 - accuracy: 0.9272 - val_loss: 0.2635 - val_accuracy: 0.8899
# Epoch 16/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9396
# Epoch 16: val_loss did not improve from 0.15447
# 184/184 [==============================] - 16s 86ms/step - loss: 0.1532 - accuracy: 0.9396 - val_loss: 0.2095 - val_accuracy: 0.9130
# Epoch 17/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9391
# Epoch 17: val_loss did not improve from 0.15447
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1479 - accuracy: 0.9391 - val_loss: 0.2211 - val_accuracy: 0.9028
# Epoch 18/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9339
# Epoch 18: val_loss did not improve from 0.15447
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1616 - accuracy: 0.9339 - val_loss: 0.7157 - val_accuracy: 0.7301
# Epoch 19/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9359
# Epoch 19: val_loss improved from 0.15447 to 0.14067, saving model to ./model/L2C1_combined-19-0.1407.hdf5
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1501 - accuracy: 0.9359 - val_loss: 0.1407 - val_accuracy: 0.9375
# Epoch 20/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9405
# Epoch 20: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 85ms/step - loss: 0.1495 - accuracy: 0.9405 - val_loss: 0.1527 - val_accuracy: 0.9375
# Epoch 21/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9323
# Epoch 21: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 86ms/step - loss: 0.1644 - accuracy: 0.9323 - val_loss: 0.2427 - val_accuracy: 0.9198
# Epoch 22/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9345
# Epoch 22: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 84ms/step - loss: 0.1569 - accuracy: 0.9345 - val_loss: 0.1864 - val_accuracy: 0.9191
# Epoch 23/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1353 - accuracy: 0.9429
# Epoch 23: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 84ms/step - loss: 0.1353 - accuracy: 0.9429 - val_loss: 0.2150 - val_accuracy: 0.9137
# Epoch 24/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9415
# Epoch 24: val_loss did not improve from 0.14067
# 184/184 [==============================] - 17s 90ms/step - loss: 0.1373 - accuracy: 0.9415 - val_loss: 0.1679 - val_accuracy: 0.9245
# Epoch 25/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9422
# Epoch 25: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 86ms/step - loss: 0.1408 - accuracy: 0.9422 - val_loss: 0.6298 - val_accuracy: 0.7288
# Epoch 26/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1641 - accuracy: 0.9347
# Epoch 26: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1641 - accuracy: 0.9347 - val_loss: 0.1758 - val_accuracy: 0.9347
# Epoch 27/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9386
# Epoch 27: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1463 - accuracy: 0.9386 - val_loss: 0.5002 - val_accuracy: 0.8151
# Epoch 28/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9386
# Epoch 28: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1472 - accuracy: 0.9386 - val_loss: 0.3649 - val_accuracy: 0.8729
# Epoch 29/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9407
# Epoch 29: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1425 - accuracy: 0.9407 - val_loss: 1.2117 - val_accuracy: 0.6751
# Epoch 30/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9434
# Epoch 30: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1424 - accuracy: 0.9434 - val_loss: 0.1704 - val_accuracy: 0.9232
# Epoch 31/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9447
# Epoch 31: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1299 - accuracy: 0.9447 - val_loss: 0.1978 - val_accuracy: 0.9286
# Epoch 32/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9463
# Epoch 32: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1316 - accuracy: 0.9463 - val_loss: 0.1570 - val_accuracy: 0.9286
# Epoch 33/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9441
# Epoch 33: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1372 - accuracy: 0.9441 - val_loss: 0.2037 - val_accuracy: 0.9273
# Epoch 34/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1301 - accuracy: 0.9481
# Epoch 34: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 90ms/step - loss: 0.1301 - accuracy: 0.9481 - val_loss: 0.1415 - val_accuracy: 0.9422
# Epoch 35/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9390
# Epoch 35: val_loss did not improve from 0.14067
# 184/184 [==============================] - 17s 91ms/step - loss: 0.1459 - accuracy: 0.9390 - val_loss: 0.1881 - val_accuracy: 0.9130
# Epoch 36/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9437
# Epoch 36: val_loss did not improve from 0.14067
# 184/184 [==============================] - 17s 95ms/step - loss: 0.1396 - accuracy: 0.9437 - val_loss: 0.2151 - val_accuracy: 0.8987
# Epoch 37/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9447
# Epoch 37: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1352 - accuracy: 0.9447 - val_loss: 0.1637 - val_accuracy: 0.9320
# Epoch 38/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1437 - accuracy: 0.9412
# Epoch 38: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 86ms/step - loss: 0.1437 - accuracy: 0.9412 - val_loss: 0.3765 - val_accuracy: 0.8824
# Epoch 39/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9418
# Epoch 39: val_loss did not improve from 0.14067
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1367 - accuracy: 0.9418 - val_loss: 0.3551 - val_accuracy: 0.8600
# Epoch 1/50
# 184/184 [==============================] - ETA: 0s - loss: 0.7047 - accuracy: 0.7198
# Epoch 1: val_loss improved from inf to 1.72449, saving model to ./model/L2C2_combined-01-1.7245.hdf5
# 184/184 [==============================] - 18s 90ms/step - loss: 0.7047 - accuracy: 0.7198 - val_loss: 1.7245 - val_accuracy: 0.1659
# Epoch 2/50
# 184/184 [==============================] - ETA: 0s - loss: 0.3907 - accuracy: 0.8531
# Epoch 2: val_loss improved from 1.72449 to 1.66845, saving model to ./model/L2C2_combined-02-1.6684.hdf5
# 184/184 [==============================] - 16s 90ms/step - loss: 0.3907 - accuracy: 0.8531 - val_loss: 1.6684 - val_accuracy: 0.1713
# Epoch 3/50
# 184/184 [==============================] - ETA: 0s - loss: 0.3131 - accuracy: 0.8801
# Epoch 3: val_loss improved from 1.66845 to 1.10110, saving model to ./model/L2C2_combined-03-1.1011.hdf5
# 184/184 [==============================] - 16s 89ms/step - loss: 0.3131 - accuracy: 0.8801 - val_loss: 1.1011 - val_accuracy: 0.5377
# Epoch 4/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.8988
# Epoch 4: val_loss improved from 1.10110 to 0.98036, saving model to ./model/L2C2_combined-04-0.9804.hdf5
# 184/184 [==============================] - 16s 87ms/step - loss: 0.2642 - accuracy: 0.8988 - val_loss: 0.9804 - val_accuracy: 0.5241
# Epoch 5/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9133
# Epoch 5: val_loss did not improve from 0.98036
# 184/184 [==============================] - 17s 93ms/step - loss: 0.2238 - accuracy: 0.9133 - val_loss: 3.0141 - val_accuracy: 0.4188
# Epoch 6/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9201
# Epoch 6: val_loss improved from 0.98036 to 0.27477, saving model to ./model/L2C2_combined-06-0.2748.hdf5
# 184/184 [==============================] - 16s 89ms/step - loss: 0.2088 - accuracy: 0.9201 - val_loss: 0.2748 - val_accuracy: 0.8892
# Epoch 7/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9252
# Epoch 7: val_loss did not improve from 0.27477
# 184/184 [==============================] - 17s 94ms/step - loss: 0.1885 - accuracy: 0.9252 - val_loss: 0.3572 - val_accuracy: 0.8838
# Epoch 8/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9254
# Epoch 8: val_loss did not improve from 0.27477
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1854 - accuracy: 0.9254 - val_loss: 0.5392 - val_accuracy: 0.8232
# Epoch 9/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9260
# Epoch 9: val_loss did not improve from 0.27477
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1930 - accuracy: 0.9260 - val_loss: 1.2840 - val_accuracy: 0.6798
# Epoch 10/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9289
# Epoch 10: val_loss improved from 0.27477 to 0.26545, saving model to ./model/L2C2_combined-10-0.2655.hdf5
# 184/184 [==============================] - 15s 84ms/step - loss: 0.1748 - accuracy: 0.9289 - val_loss: 0.2655 - val_accuracy: 0.9014
# Epoch 11/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9294
# Epoch 11: val_loss did not improve from 0.26545
# 184/184 [==============================] - 15s 84ms/step - loss: 0.1745 - accuracy: 0.9294 - val_loss: 1.7218 - val_accuracy: 0.5411
# Epoch 12/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9347
# Epoch 12: val_loss did not improve from 0.26545
# 184/184 [==============================] - 15s 83ms/step - loss: 0.1597 - accuracy: 0.9347 - val_loss: 0.2877 - val_accuracy: 0.8674
# Epoch 13/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9313
# Epoch 13: val_loss improved from 0.26545 to 0.19110, saving model to ./model/L2C2_combined-13-0.1911.hdf5
# 184/184 [==============================] - 15s 83ms/step - loss: 0.1717 - accuracy: 0.9313 - val_loss: 0.1911 - val_accuracy: 0.9150
# Epoch 14/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9282
# Epoch 14: val_loss improved from 0.19110 to 0.17748, saving model to ./model/L2C2_combined-14-0.1775.hdf5
# 184/184 [==============================] - 16s 85ms/step - loss: 0.1786 - accuracy: 0.9282 - val_loss: 0.1775 - val_accuracy: 0.9184
# Epoch 15/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9357
# Epoch 15: val_loss did not improve from 0.17748
# 184/184 [==============================] - 15s 83ms/step - loss: 0.1625 - accuracy: 0.9357 - val_loss: 0.2441 - val_accuracy: 0.9116
# Epoch 16/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1546 - accuracy: 0.9345
# Epoch 16: val_loss did not improve from 0.17748
# 184/184 [==============================] - 15s 83ms/step - loss: 0.1546 - accuracy: 0.9345 - val_loss: 0.2791 - val_accuracy: 0.8987
# Epoch 17/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9403
# Epoch 17: val_loss did not improve from 0.17748
# 184/184 [==============================] - 16s 85ms/step - loss: 0.1454 - accuracy: 0.9403 - val_loss: 0.2743 - val_accuracy: 0.9075
# Epoch 18/50
# 184/184 [==============================] - ETA: 0s - loss: 0.2082 - accuracy: 0.9150
# Epoch 18: val_loss did not improve from 0.17748
# 184/184 [==============================] - 16s 87ms/step - loss: 0.2082 - accuracy: 0.9150 - val_loss: 0.3761 - val_accuracy: 0.8586
# Epoch 19/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9381
# Epoch 19: val_loss improved from 0.17748 to 0.17182, saving model to ./model/L2C2_combined-19-0.1718.hdf5
# 184/184 [==============================] - 16s 89ms/step - loss: 0.1501 - accuracy: 0.9381 - val_loss: 0.1718 - val_accuracy: 0.9368
# Epoch 20/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9400
# Epoch 20: val_loss did not improve from 0.17182
# 184/184 [==============================] - 18s 97ms/step - loss: 0.1502 - accuracy: 0.9400 - val_loss: 1.0839 - val_accuracy: 0.6608
# Epoch 21/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1515 - accuracy: 0.9378
# Epoch 21: val_loss did not improve from 0.17182
# 184/184 [==============================] - 18s 99ms/step - loss: 0.1515 - accuracy: 0.9378 - val_loss: 0.2510 - val_accuracy: 0.8987
# Epoch 22/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9379
# Epoch 22: val_loss did not improve from 0.17182
# 184/184 [==============================] - 17s 92ms/step - loss: 0.1479 - accuracy: 0.9379 - val_loss: 1.6805 - val_accuracy: 0.5595
# Epoch 23/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9359
# Epoch 23: val_loss did not improve from 0.17182
# 184/184 [==============================] - 17s 92ms/step - loss: 0.1523 - accuracy: 0.9359 - val_loss: 0.7235 - val_accuracy: 0.7634
# Epoch 24/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9434
# Epoch 24: val_loss improved from 0.17182 to 0.15934, saving model to ./model/L2C2_combined-24-0.1593.hdf5
# 184/184 [==============================] - 16s 86ms/step - loss: 0.1370 - accuracy: 0.9434 - val_loss: 0.1593 - val_accuracy: 0.9402
# Epoch 25/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9340
# Epoch 25: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 85ms/step - loss: 0.1539 - accuracy: 0.9340 - val_loss: 0.3481 - val_accuracy: 0.8661
# Epoch 26/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9420
# Epoch 26: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1434 - accuracy: 0.9420 - val_loss: 0.2465 - val_accuracy: 0.8926
# Epoch 27/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9362
# Epoch 27: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 88ms/step - loss: 0.1482 - accuracy: 0.9362 - val_loss: 0.3945 - val_accuracy: 0.8477
# Epoch 28/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9403
# Epoch 28: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1402 - accuracy: 0.9403 - val_loss: 0.3270 - val_accuracy: 0.9137
# Epoch 29/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9427
# Epoch 29: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 87ms/step - loss: 0.1408 - accuracy: 0.9427 - val_loss: 0.4872 - val_accuracy: 0.8389
# Epoch 30/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1542 - accuracy: 0.9393
# Epoch 30: val_loss did not improve from 0.15934
# 184/184 [==============================] - 23s 128ms/step - loss: 0.1542 - accuracy: 0.9393 - val_loss: 0.3177 - val_accuracy: 0.9266
# Epoch 31/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9425
# Epoch 31: val_loss did not improve from 0.15934
# 184/184 [==============================] - 23s 124ms/step - loss: 0.1357 - accuracy: 0.9425 - val_loss: 0.4026 - val_accuracy: 0.8511
# Epoch 32/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9442
# Epoch 32: val_loss did not improve from 0.15934
# 184/184 [==============================] - 24s 130ms/step - loss: 0.1361 - accuracy: 0.9442 - val_loss: 0.2728 - val_accuracy: 0.9184
# Epoch 33/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9451
# Epoch 33: val_loss did not improve from 0.15934
# 184/184 [==============================] - 24s 128ms/step - loss: 0.1351 - accuracy: 0.9451 - val_loss: 0.5639 - val_accuracy: 0.7281
# Epoch 34/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 0.9381
# Epoch 34: val_loss did not improve from 0.15934
# 184/184 [==============================] - 22s 118ms/step - loss: 0.1449 - accuracy: 0.9381 - val_loss: 0.3087 - val_accuracy: 0.8511
# Epoch 35/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1479 - accuracy: 0.9413
# Epoch 35: val_loss did not improve from 0.15934
# 184/184 [==============================] - 21s 115ms/step - loss: 0.1479 - accuracy: 0.9413 - val_loss: 0.3722 - val_accuracy: 0.8736
# Epoch 36/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9429
# Epoch 36: val_loss did not improve from 0.15934
# 184/184 [==============================] - 21s 114ms/step - loss: 0.1373 - accuracy: 0.9429 - val_loss: 1.8158 - val_accuracy: 0.5738
# Epoch 37/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9481
# Epoch 37: val_loss did not improve from 0.15934
# 184/184 [==============================] - 19s 104ms/step - loss: 0.1300 - accuracy: 0.9481 - val_loss: 0.5866 - val_accuracy: 0.7920
# Epoch 38/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9446
# Epoch 38: val_loss did not improve from 0.15934
# 184/184 [==============================] - 18s 96ms/step - loss: 0.1396 - accuracy: 0.9446 - val_loss: 0.5629 - val_accuracy: 0.7872
# Epoch 39/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9425
# Epoch 39: val_loss did not improve from 0.15934
# 184/184 [==============================] - 18s 96ms/step - loss: 0.1363 - accuracy: 0.9425 - val_loss: 0.5502 - val_accuracy: 0.8232
# Epoch 40/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9415
# Epoch 40: val_loss did not improve from 0.15934
# 184/184 [==============================] - 17s 92ms/step - loss: 0.1341 - accuracy: 0.9415 - val_loss: 0.3112 - val_accuracy: 0.8715
# Epoch 41/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9480
# Epoch 41: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 90ms/step - loss: 0.1275 - accuracy: 0.9480 - val_loss: 1.0289 - val_accuracy: 0.5296
# Epoch 42/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9364
# Epoch 42: val_loss did not improve from 0.15934
# 184/184 [==============================] - 18s 95ms/step - loss: 0.1518 - accuracy: 0.9364 - val_loss: 0.3506 - val_accuracy: 0.9164
# Epoch 43/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9471
# Epoch 43: val_loss did not improve from 0.15934
# 184/184 [==============================] - 18s 96ms/step - loss: 0.1268 - accuracy: 0.9471 - val_loss: 0.2265 - val_accuracy: 0.9157
# Epoch 44/50
# 184/184 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9441
# Epoch 44: val_loss did not improve from 0.15934
# 184/184 [==============================] - 16s 90ms/step - loss: 0.1360 - accuracy: 0.9441 - val_loss: 0.3530 - val_accuracy: 0.8933

# %% [markdown]
# # Result

# %%
def view_loss(model_static_history, model_dynamic_history, model_combined_history, name):
    loss_static = model_static_history.history['loss']
    loss_dynamic = model_dynamic_history.history['loss']
    loss_combined = model_combined_history.history['loss']
    epochs = range(1, len(loss_static) + 1)
    plt.plot(epochs, loss_static, 'y', label='STATIC Training loss')
    plt.plot(epochs, loss_dynamic, 'b', label='DYNAMIC Training loss')
    plt.plot(epochs, loss_combined, color='violet', label='COMBINED Training loss')
    plt.title(f'{name} Training loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
def view_val_acc(model_static_history, model_dynamic_history, model_combined_history, name):
    val_acc_static = model_static_history.history['accuracy']
    val_acc_dynamic = model_dynamic_history.history['accuracy']
    val_acc_combined = model_combined_history.history['accuracy']
    epochs = range(1, len(val_acc_static) + 1)
    plt.plot(epochs, val_acc_static, 'y', label='STATIC Training loss')
    plt.plot(epochs, val_acc_dynamic, 'b', label='DYNAMIC Training loss')
    plt.plot(epochs, val_acc_combined, color='violet', label='COMBINED Training loss')
    plt.title(f'{name} Validation Acc')
    plt.xlabel('Epochs')
    plt.ylabel('Acc')
    plt.legend()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

view_loss(L1C1_history_static, L1C1_history_dynamic, L1C1_history_combined, "L1C1")
view_loss(L1C2_history_static, L1C2_history_dynamic, L1C2_history_combined, "L1C2")
view_loss(L2C1_history_static, L2C1_history_dynamic, L2C1_history_combined, "L2C1")
view_loss(L2C2_history_static, L2C2_history_dynamic, L2C2_history_combined, "L2C2")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

view_val_acc(L1C1_history_static, L1C1_history_dynamic, L1C1_history_combined, "L1C1")
view_val_acc(L1C2_history_static, L1C2_history_dynamic, L1C2_history_combined, "L1C2")
view_val_acc(L2C1_history_static, L2C1_history_dynamic, L2C1_history_combined, "L2C1")
view_val_acc(L2C2_history_static, L2C2_history_dynamic, L2C2_history_combined, "L2C2")

# %%
def heatmap_static(model):
    from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
    pred_static = model.predict(testX_static)
    pred_static = np.argmax(pred_static, axis=-1)
    cm_static=confusion_matrix(testy_static,pred_static)
    print(cm_static)
    print(accuracy_score(testy_static,pred_static))
    print(classification_report(testy_static,pred_static))
    sns.heatmap(cm_static, annot=True, fmt = '.2f')

# %%
heatmap_static(L1C1_model_dynamic)

# %%
def eval(model_static, model_dynamic, model_combined, x_static, y_static, x_dynamic, y_dynamic, x_combined, y_combined):
    score_static = model_static.evaluate(x_static, y_static)
    score_dynamic = model_dynamic.evaluate(x_dynamic, y_dynamic)
    score_combined = model_combined.evaluate(x_combined, y_combined)

    return score_static[1], score_dynamic[1], score_combined[1]

# %%
eval(L1C1_model_static, L1C1_model_dynamic, L1C1_model_combined, testX_static, testy_static_one_hot, testX_dynamic, testy_dynamic_one_hot, testX_combined, testy_combined_one_hot)
eval(L1C2_model_static, L1C2_model_dynamic, L1C2_model_combined, testX_static, testy_static_one_hot, testX_dynamic, testy_dynamic_one_hot, testX_combined, testy_combined_one_hot)
eval(L2C1_model_static, L2C1_model_dynamic, L2C1_model_combined, testX_static, testy_static_one_hot, testX_dynamic, testy_dynamic_one_hot, testX_combined, testy_combined_one_hot)
eval(L2C2_model_static, L2C2_model_dynamic, L2C2_model_combined, testX_static, testy_static_one_hot, testX_dynamic, testy_dynamic_one_hot, testX_combined, testy_combined_one_hot)

# %% [markdown]
# # Accuracy
# ### Static + Dynamic : 0.8941
# ### Static : 0.9611
# ### Dynamic : 0.8449

# %%
static_ratio = testX_static.shape[0] / testX.shape[0]
dynamic_ratio = testX_dynamic.shape[0] / testX.shape[0]

testX_static.shape[0], testX_dynamic.shape[0]

# %% [markdown]
# ### Accuracy

# %%
mod_acc = static_ratio * score_static[1] + dynamic_ratio * score_dynamic[1]
mod_acc

# %% [markdown]
# # Load Saved Model

# %%
from keras.models import load_model

# %%
L1C1_static = load_model('./HAR_LSTM-CNN_extended_model/L1C1_static-44-0.0163.hdf5')
L1C1_dynamic = load_model('./HAR_LSTM-CNN_extended_model/L1C1_dynamic-10-0.2147.hdf5')
L1C1_combined = load_model('./HAR_LSTM-CNN_extended_model/L1C1_combined-36-0.1303.hdf5')
L1C2_static = load_model('./HAR_LSTM-CNN_extended_model/L1C2_static-28-0.1600.hdf5')
L1C2_dynamic = load_model('./HAR_LSTM-CNN_extended_model/L1C2_dynamic-10-0.2201.hdf5')
L1C2_combined = load_model('./HAR_LSTM-CNN_extended_model/L1C2_combined-28-0.1554.hdf5')
L2C1_static = load_model('./HAR_LSTM-CNN_extended_model/L2C1_static-35-0.0124.hdf5')
L2C1_dynamic = load_model('./HAR_LSTM-CNN_extended_model/L2C1_dynamic-26-0.1977.hdf5')
L2C1_combined = load_model('./HAR_LSTM-CNN_extended_model/L2C1_combined-19-0.1407.hdf5')
L2C2_static = load_model('./HAR_LSTM-CNN_extended_model/L2C2_static-33-0.0275.hdf5')
L2C2_dynamic = load_model('./HAR_LSTM-CNN_extended_model/L2C2_dynamic-08-0.2390.hdf5')
L2C2_combined = load_model('./HAR_LSTM-CNN_extended_model/L2C2_combined-24-0.1593.hdf5')

# %%
L1C1_static.evaluate(testX_static, testy_static_one_hot)
L1C1_dynamic.evaluate(testX_dynamic, testy_dynamic_one_hot)
L1C1_combined.evaluate(testX_combined, testy_combined_one_hot)
L1C2_static.evaluate(testX_static, testy_static_one_hot)
L1C2_dynamic.evaluate(testX_dynamic, testy_dynamic_one_hot)
L1C2_combined.evaluate(testX_combined, testy_combined_one_hot)
L2C1_static.evaluate(testX_static, testy_static_one_hot)
L2C1_dynamic.evaluate(testX_dynamic, testy_dynamic_one_hot)
L2C1_combined.evaluate(testX_combined, testy_combined_one_hot)
L2C2_static.evaluate(testX_static, testy_static_one_hot)
L2C2_dynamic.evaluate(testX_dynamic, testy_dynamic_one_hot)
L2C2_combined.evaluate(testX_combined, testy_combined_one_hot)
# Out:
# 44/44 [==============================] - 2s 15ms/step - loss: 0.4780 - accuracy: 0.9185
# 49/49 [==============================] - 1s 14ms/step - loss: 0.3088 - accuracy: 0.8737
# 93/93 [==============================] - 2s 16ms/step - loss: 0.3441 - accuracy: 0.8965
# 44/44 [==============================] - 1s 15ms/step - loss: 0.2573 - accuracy: 0.9301
# 49/49 [==============================] - 1s 15ms/step - loss: 0.3487 - accuracy: 0.8660
# 93/93 [==============================] - 2s 14ms/step - loss: 0.3544 - accuracy: 0.8985
# 44/44 [==============================] - 2s 29ms/step - loss: 0.3564 - accuracy: 0.9445
# 49/49 [==============================] - 2s 28ms/step - loss: 0.3851 - accuracy: 0.8590
# 93/93 [==============================] - 3s 30ms/step - loss: 0.3852 - accuracy: 0.8887
# 44/44 [==============================] - 2s 30ms/step - loss: 0.2991 - accuracy: 0.9329
# 49/49 [==============================] - 2s 29ms/step - loss: 0.3312 - accuracy: 0.8885
# 93/93 [==============================] - 3s 27ms/step - loss: 0.5135 - accuracy: 0.8782
# [0.5135178565979004, 0.8781812191009521]
