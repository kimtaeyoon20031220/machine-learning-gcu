# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPool1D

# %%
df = pd.read_csv('./dataset/power_consumption.csv')

df
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# 2                      0.062          0.100               29128.10127
# 3                      0.091          0.096               28228.86076
# 4                      0.048          0.085               27335.69620
# ...                      ...            ...                       ...
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption
# 0                    16128.87538                20240.96386
# 1                    19375.07599                20131.08434
# 2                    19006.68693                19668.43373
# 3                    18361.09422                18899.27711
# 4                    17872.34043                18442.40964
# ...                          ...                        ...
# 52411                26857.31820                14780.31212
# 52412                26124.57809                14428.81152
# 52413                25277.69254                13806.48259
# 52414                24692.23688                13512.60504
# 52415                24055.23167                13345.49820
#
# [52416 rows x 9 columns]

# %%
X = df.iloc[:, 1:6]
y = df.iloc[:, 6]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=False)

df
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# 2                      0.062          0.100               29128.10127
# 3                      0.091          0.096               28228.86076
# 4                      0.048          0.085               27335.69620
# ...                      ...            ...                       ...
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption
# 0                    16128.87538                20240.96386
# 1                    19375.07599                20131.08434
# 2                    19006.68693                19668.43373
# 3                    18361.09422                18899.27711
# 4                    17872.34043                18442.40964
# ...                          ...                        ...
# 52411                26857.31820                14780.31212
# 52412                26124.57809                14428.81152
# 52413                25277.69254                13806.48259
# 52414                24692.23688                13512.60504
# 52415                24055.23167                13345.49820
#
# [52416 rows x 9 columns]

# %%
model = Sequential([
    Conv1D(input_shape=(X_train.shape[1], 1), filters=64, kernel_size=3, activation='relu'),
    Conv1D(filters=32, kernel_size=2, activation='relu'),
    MaxPool1D(),
    Flatten(),
    Dense(64, activation='relu'),    
    Dense(1)
])

model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 3, 64)             256
#
#  conv1d_3 (Conv1D)           (None, 2, 32)             4128
#
#  max_pooling1d_1 (MaxPooling  (None, 1, 32)            0
#  1D)
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 6,561
# Trainable params: 6,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.33, batch_size=32)
# Out:
# Epoch 1/100
# 736/736 [==============================] - 1s 1ms/step - loss: 251000240.0000 - val_loss: 92354952.0000
# Epoch 2/100
# 736/736 [==============================] - 1s 1ms/step - loss: 68333336.0000 - val_loss: 80785864.0000
# Epoch 3/100
# 736/736 [==============================] - 1s 1ms/step - loss: 61585804.0000 - val_loss: 64156740.0000
# Epoch 4/100
# 736/736 [==============================] - 1s 1ms/step - loss: 54937868.0000 - val_loss: 64651848.0000
# Epoch 5/100
# 736/736 [==============================] - 1s 1ms/step - loss: 52382240.0000 - val_loss: 65777712.0000
# Epoch 6/100
# 736/736 [==============================] - 1s 1ms/step - loss: 51407140.0000 - val_loss: 65769964.0000
# Epoch 7/100
# 736/736 [==============================] - 1s 1ms/step - loss: 50478996.0000 - val_loss: 86518336.0000
# Epoch 8/100
# 736/736 [==============================] - 1s 1ms/step - loss: 49767996.0000 - val_loss: 74679896.0000
# Epoch 9/100
# 736/736 [==============================] - 1s 1ms/step - loss: 49038056.0000 - val_loss: 86738360.0000
# Epoch 10/100
# 736/736 [==============================] - 1s 1ms/step - loss: 48513704.0000 - val_loss: 65443768.0000
# Epoch 11/100
# 736/736 [==============================] - 1s 1ms/step - loss: 47800124.0000 - val_loss: 92839304.0000
# Epoch 12/100
# 736/736 [==============================] - 1s 1ms/step - loss: 47154184.0000 - val_loss: 74337368.0000
# Epoch 13/100
# 736/736 [==============================] - 1s 1ms/step - loss: 46446932.0000 - val_loss: 61727904.0000
# Epoch 14/100
# 736/736 [==============================] - 1s 1ms/step - loss: 45740468.0000 - val_loss: 67077444.0000
# Epoch 15/100
# 736/736 [==============================] - 1s 1ms/step - loss: 44722084.0000 - val_loss: 72384824.0000
# Epoch 16/100
# 736/736 [==============================] - 1s 1ms/step - loss: 43995264.0000 - val_loss: 62355884.0000
# Epoch 17/100
# 736/736 [==============================] - 1s 1ms/step - loss: 42923948.0000 - val_loss: 59028144.0000
# Epoch 18/100
# 736/736 [==============================] - 1s 1ms/step - loss: 42164628.0000 - val_loss: 53729164.0000
# Epoch 19/100
# 736/736 [==============================] - 1s 1ms/step - loss: 41394064.0000 - val_loss: 58674896.0000
# Epoch 20/100
# 736/736 [==============================] - 1s 1ms/step - loss: 40727036.0000 - val_loss: 44431040.0000
# Epoch 21/100
# 736/736 [==============================] - 1s 1ms/step - loss: 40330056.0000 - val_loss: 50171304.0000
# Epoch 22/100
# 736/736 [==============================] - 1s 1ms/step - loss: 40136344.0000 - val_loss: 48831632.0000
# Epoch 23/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39778584.0000 - val_loss: 48262128.0000
# Epoch 24/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39416668.0000 - val_loss: 47184332.0000
# Epoch 25/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39453324.0000 - val_loss: 49536664.0000
# Epoch 26/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39511528.0000 - val_loss: 50565352.0000
# Epoch 27/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39411296.0000 - val_loss: 46687872.0000
# Epoch 28/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39536344.0000 - val_loss: 46218792.0000
# Epoch 29/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39481312.0000 - val_loss: 45770648.0000
# Epoch 30/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39443428.0000 - val_loss: 46159944.0000
# Epoch 31/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39229636.0000 - val_loss: 43830024.0000
# Epoch 32/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39390164.0000 - val_loss: 46575196.0000
# Epoch 33/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39445496.0000 - val_loss: 47482756.0000
# Epoch 34/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39377776.0000 - val_loss: 48410456.0000
# Epoch 35/100
# 736/736 [==============================] - 1s 996us/step - loss: 39384672.0000 - val_loss: 46463084.0000
# Epoch 36/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39228280.0000 - val_loss: 45007940.0000
# Epoch 37/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39304376.0000 - val_loss: 47087852.0000
# Epoch 38/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39295752.0000 - val_loss: 48699988.0000
# Epoch 39/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39416588.0000 - val_loss: 50335272.0000
# Epoch 40/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39473424.0000 - val_loss: 47279068.0000
# Epoch 41/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39145188.0000 - val_loss: 47405992.0000
# Epoch 42/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39463728.0000 - val_loss: 44019912.0000
# Epoch 43/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39176176.0000 - val_loss: 43793988.0000
# Epoch 44/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39253592.0000 - val_loss: 46638124.0000
# Epoch 45/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39215244.0000 - val_loss: 48523760.0000
# Epoch 46/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39422180.0000 - val_loss: 50326812.0000
# Epoch 47/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39285024.0000 - val_loss: 45932252.0000
# Epoch 48/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39140592.0000 - val_loss: 46823852.0000
# Epoch 49/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39108916.0000 - val_loss: 44852072.0000
# Epoch 50/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39199412.0000 - val_loss: 46046848.0000
# Epoch 51/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39289916.0000 - val_loss: 45264872.0000
# Epoch 52/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39171896.0000 - val_loss: 45952636.0000
# Epoch 53/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39123132.0000 - val_loss: 46418888.0000
# Epoch 54/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39350124.0000 - val_loss: 45308060.0000
# Epoch 55/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39154696.0000 - val_loss: 47614208.0000
# Epoch 56/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39244504.0000 - val_loss: 48396688.0000
# Epoch 57/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39200072.0000 - val_loss: 48001724.0000
# Epoch 58/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39160024.0000 - val_loss: 50235704.0000
# Epoch 59/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39208548.0000 - val_loss: 43630372.0000
# Epoch 60/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39155956.0000 - val_loss: 47397936.0000
# Epoch 61/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39159376.0000 - val_loss: 48670192.0000
# Epoch 62/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39155884.0000 - val_loss: 49500192.0000
# Epoch 63/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39173464.0000 - val_loss: 46304104.0000
# Epoch 64/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39076296.0000 - val_loss: 44638092.0000
# Epoch 65/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39106312.0000 - val_loss: 45982152.0000
# Epoch 66/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39092784.0000 - val_loss: 44885460.0000
# Epoch 67/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39108352.0000 - val_loss: 46012680.0000
# Epoch 68/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39102084.0000 - val_loss: 44188796.0000
# Epoch 69/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39012084.0000 - val_loss: 46963756.0000
# Epoch 70/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39007036.0000 - val_loss: 45472084.0000
# Epoch 71/100
# 736/736 [==============================] - 1s 1ms/step - loss: 39090592.0000 - val_loss: 45235372.0000
# Epoch 72/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38911076.0000 - val_loss: 44163712.0000
# Epoch 73/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38887696.0000 - val_loss: 43309644.0000
# Epoch 74/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38975268.0000 - val_loss: 45282196.0000
# Epoch 75/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38950032.0000 - val_loss: 44839156.0000
# Epoch 76/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38953256.0000 - val_loss: 44938140.0000
# Epoch 77/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38797648.0000 - val_loss: 44751544.0000
# Epoch 78/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38816024.0000 - val_loss: 45754236.0000
# Epoch 79/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38901308.0000 - val_loss: 46015644.0000
# Epoch 80/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38834336.0000 - val_loss: 44212648.0000
# Epoch 81/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38788432.0000 - val_loss: 45924532.0000
# Epoch 82/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38654552.0000 - val_loss: 44289464.0000
# Epoch 83/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38931096.0000 - val_loss: 44622828.0000
# Epoch 84/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38717240.0000 - val_loss: 43764280.0000
# Epoch 85/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38712620.0000 - val_loss: 43072128.0000
# Epoch 86/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38709336.0000 - val_loss: 44015208.0000
# Epoch 87/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38768820.0000 - val_loss: 42967256.0000
# Epoch 88/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38670620.0000 - val_loss: 48558092.0000
# Epoch 89/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38524632.0000 - val_loss: 44910332.0000
# Epoch 90/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38541108.0000 - val_loss: 44760416.0000
# Epoch 91/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38639248.0000 - val_loss: 45152120.0000
# Epoch 92/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38669876.0000 - val_loss: 44736172.0000
# Epoch 93/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38574284.0000 - val_loss: 44075672.0000
# Epoch 94/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38403384.0000 - val_loss: 43210020.0000
# Epoch 95/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38552372.0000 - val_loss: 44058456.0000
# Epoch 96/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38533732.0000 - val_loss: 45160036.0000
# Epoch 97/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38751148.0000 - val_loss: 45505456.0000
# Epoch 98/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38513592.0000 - val_loss: 46832292.0000
# Epoch 99/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38407496.0000 - val_loss: 50592812.0000
# Epoch 100/100
# 736/736 [==============================] - 1s 1ms/step - loss: 38450256.0000 - val_loss: 46695188.0000

# %%
y_pred = model.predict(X_test)
# Out:
# 541/541 [==============================] - 0s 481us/step

# %%
for i in range(len(y_pred)):
    print(f"{i + 1}번 데이터의 예측차 : {y_pred[i] - np.array(y_test)[i]}")
# Out:
# 1번 데이터의 예측차 : [-2534.1055]
# 2번 데이터의 예측차 : [-2422.2031]
# 3번 데이터의 예측차 : [-2286.5586]
# 4번 데이터의 예측차 : [-2125.4062]
# 5번 데이터의 예측차 : [-2030.1055]
# 6번 데이터의 예측차 : [-1910.168]
# 7번 데이터의 예측차 : [-1741.4062]
# 8번 데이터의 예측차 : [-1433.0586]
# 9번 데이터의 예측차 : [-939.0547]
# 10번 데이터의 예측차 : [-383.15234]
# 11번 데이터의 예측차 : [118.921875]
# 12번 데이터의 예측차 : [685.6875]
# 13번 데이터의 예측차 : [1319.8438]
# 14번 데이터의 예측차 : [1840.3242]
# 15번 데이터의 예측차 : [2473.0547]
# 16번 데이터의 예측차 : [3166.2578]
# 17번 데이터의 예측차 : [3718.4062]
# 18번 데이터의 예측차 : [4342.383]
# 19번 데이터의 예측차 : [5020.957]
# 20번 데이터의 예측차 : [5860.4043]
# 21번 데이터의 예측차 : [6688.6094]
# 22번 데이터의 예측차 : [7194.451]
# 23번 데이터의 예측차 : [7813.668]
# 24번 데이터의 예측차 : [8487.072]
# 25번 데이터의 예측차 : [8907.502]
# 26번 데이터의 예측차 : [9449.395]
# 27번 데이터의 예측차 : [9908.203]
# 28번 데이터의 예측차 : [10445.3125]
# 29번 데이터의 예측차 : [10664.254]
# 30번 데이터의 예측차 : [10872.521]
# 31번 데이터의 예측차 : [11139.594]
# 32번 데이터의 예측차 : [11447.453]
# 33번 데이터의 예측차 : [11561.711]
# 34번 데이터의 예측차 : [11714.891]
# 35번 데이터의 예측차 : [11731.395]
# 36번 데이터의 예측차 : [11905.582]
# 37번 데이터의 예측차 : [12103.729]
# 38번 데이터의 예측차 : [12202.697]
# 39번 데이터의 예측차 : [12257.916]
# 40번 데이터의 예측차 : [12210.662]
# 41번 데이터의 예측차 : [12226.035]
# 42번 데이터의 예측차 : [12369.668]
# 43번 데이터의 예측차 : [12348.521]
# 44번 데이터의 예측차 : [12286.955]
# 45번 데이터의 예측차 : [11787.211]
# 46번 데이터의 예측차 : [11876.18]
# 47번 데이터의 예측차 : [12008.738]
# 48번 데이터의 예측차 : [12126.23]
# 49번 데이터의 예측차 : [12446.432]
# 50번 데이터의 예측차 : [13084.525]
# 51번 데이터의 예측차 : [14426.826]
# 52번 데이터의 예측차 : [15993.098]
# 53번 데이터의 예측차 : [16663.22]
# 54번 데이터의 예측차 : [17072.77]
# 55번 데이터의 예측차 : [17299.28]
# 56번 데이터의 예측차 : [17592.254]
# 57번 데이터의 예측차 : [17279.867]
# 58번 데이터의 예측차 : [17616.854]
# 59번 데이터의 예측차 : [17644.256]
# 60번 데이터의 예측차 : [17368.705]
# 61번 데이터의 예측차 : [16719.488]
# 62번 데이터의 예측차 : [15996.225]
# 63번 데이터의 예측차 : [15863.256]
# 64번 데이터의 예측차 : [14802.723]
# 65번 데이터의 예측차 : [13803.627]
# 66번 데이터의 예측차 : [13001.484]
# 67번 데이터의 예측차 : [12811.244]
# 68번 데이터의 예측차 : [11795.471]
# 69번 데이터의 예측차 : [11097.451]
# 70번 데이터의 예측차 : [10380.189]
# 71번 데이터의 예측차 : [9988.463]
# 72번 데이터의 예측차 : [9409.768]
# 73번 데이터의 예측차 : [8906.643]
# 74번 데이터의 예측차 : [8440.217]
# 75번 데이터의 예측차 : [7787.615]
# 76번 데이터의 예측차 : [7252.207]
# 77번 데이터의 예측차 : [6614.047]
# 78번 데이터의 예측차 : [5965.297]
# 79번 데이터의 예측차 : [5596.6074]
# 80번 데이터의 예측차 : [5174.252]
# 81번 데이터의 예측차 : [5046.422]
# 82번 데이터의 예측차 : [4957.2793]
# 83번 데이터의 예측차 : [4704.615]
# 84번 데이터의 예측차 : [4488.1465]
# 85번 데이터의 예측차 : [4151.174]
# 86번 데이터의 예측차 : [3993.3242]
# 87번 데이터의 예측차 : [3767.6523]
# 88번 데이터의 예측차 : [3492.0234]
# 89번 데이터의 예측차 : [3152.6777]
# 90번 데이터의 예측차 : [2830.83]
# 91번 데이터의 예측차 : [2729.5176]
# 92번 데이터의 예측차 : [2464.627]
# 93번 데이터의 예측차 : [2399.0293]
# 94번 데이터의 예측차 : [2152.3164]
# 95번 데이터의 예측차 : [1970.4434]
# 96번 데이터의 예측차 : [1411.7148]
# 97번 데이터의 예측차 : [1215.3047]
# 98번 데이터의 예측차 : [1065.1367]
# 99번 데이터의 예측차 : [849.7871]
# 100번 데이터의 예측차 : [815.9375]
# 101번 데이터의 예측차 : [923.1953]
# 102번 데이터의 예측차 : [937.2207]
# 103번 데이터의 예측차 : [1074.7461]
# 104번 데이터의 예측차 : [1067.4375]
# 105번 데이터의 예측차 : [1137.4277]
# 106번 데이터의 예측차 : [1152.5176]
# 107번 데이터의 예측차 : [1104.5]
# 108번 데이터의 예측차 : [1125.0352]
# 109번 데이터의 예측차 : [1133.5293]
# 110번 데이터의 예측차 : [1300.9062]
# 111번 데이터의 예측차 : [1413.1641]
# 112번 데이터의 예측차 : [1773.1875]
# 113번 데이터의 예측차 : [1683.2207]
# 114번 데이터의 예측차 : [1675.5586]
# 115번 데이터의 예측차 : [2042.5723]
# 116번 데이터의 예측차 : [2252.084]
# 117번 데이터의 예측차 : [2462.7734]
# 118번 데이터의 예측차 : [2617.334]
# 119번 데이터의 예측차 : [2839.3887]
# 120번 데이터의 예측차 : [2963.1582]
# 121번 데이터의 예측차 : [2926.92]
# 122번 데이터의 예측차 : [3189.045]
# 123번 데이터의 예측차 : [3489.4375]
# 124번 데이터의 예측차 : [3746.8926]
# 125번 데이터의 예측차 : [3586.6738]
# 126번 데이터의 예측차 : [3626.293]
# 127번 데이터의 예측차 : [4082.9336]
# 128번 데이터의 예측차 : [3617.5293]
# 129번 데이터의 예측차 : [2247.4668]
# 130번 데이터의 예측차 : [2727.9883]
# 131번 데이터의 예측차 : [2604.6953]
# 132번 데이터의 예측차 : [1127.7266]
# 133번 데이터의 예측차 : [-1465.6719]
# 134번 데이터의 예측차 : [-2074.0898]
# 135번 데이터의 예측차 : [-2709.7188]
# 136번 데이터의 예측차 : [-3789.125]
# 137번 데이터의 예측차 : [-4315.9883]
# 138번 데이터의 예측차 : [-4439.5703]
# 139번 데이터의 예측차 : [-4695.922]
# 140번 데이터의 예측차 : [-4891.707]
# 141번 데이터의 예측차 : [-4899.3047]
# 142번 데이터의 예측차 : [-4806.035]
# 143번 데이터의 예측차 : [-5301.711]
# 144번 데이터의 예측차 : [-5654.168]
# 145번 데이터의 예측차 : [-5929.3906]
# 146번 데이터의 예측차 : [-5987.8945]
# 147번 데이터의 예측차 : [-5863.8867]
# 148번 데이터의 예측차 : [-5797.7812]
# 149번 데이터의 예측차 : [-5618.715]
# 150번 데이터의 예측차 : [-5543.41]
# 151번 데이터의 예측차 : [-5525.453]
# 152번 데이터의 예측차 : [-5315.008]
# 153번 데이터의 예측차 : [-4904.7344]
# 154번 데이터의 예측차 : [-4322.676]
# 155번 데이터의 예측차 : [-3458.8477]
# 156번 데이터의 예측차 : [-2975.6758]
# 157번 데이터의 예측차 : [-2343.0508]
# 158번 데이터의 예측차 : [-1865.3086]
# 159번 데이터의 예측차 : [-769.83594]
# 160번 데이터의 예측차 : [-469.1289]
# 161번 데이터의 예측차 : [154.625]
# 162번 데이터의 예측차 : [870.16406]
# 163번 데이터의 예측차 : [1428.2227]
# 164번 데이터의 예측차 : [2550.8984]
# 165번 데이터의 예측차 : [3741.1445]
# 166번 데이터의 예측차 : [4115.2656]
# 167번 데이터의 예측차 : [4396.8594]
# 168번 데이터의 예측차 : [5000.713]
# 169번 데이터의 예측차 : [5599.787]
# 170번 데이터의 예측차 : [5942.914]
# 171번 데이터의 예측차 : [6082.0664]
# 172번 데이터의 예측차 : [6522.756]
# 173번 데이터의 예측차 : [6910.135]
# 174번 데이터의 예측차 : [7498.408]
# 175번 데이터의 예측차 : [7748.713]
# 176번 데이터의 예측차 : [8173.8223]
# 177번 데이터의 예측차 : [8541.559]
# 178번 데이터의 예측차 : [9096.018]
# 179번 데이터의 예측차 : [9467.082]
# 180번 데이터의 예측차 : [9386.6]
# 181번 데이터의 예측차 : [9274.586]
# 182번 데이터의 예측차 : [9468.422]
# 183번 데이터의 예측차 : [9675.771]
# 184번 데이터의 예측차 : [10103.252]
# 185번 데이터의 예측차 : [9861.305]
# 186번 데이터의 예측차 : [9723.572]
# 187번 데이터의 예측차 : [9929.934]
# 188번 데이터의 예측차 : [9910.445]
# 189번 데이터의 예측차 : [9564.746]
# 190번 데이터의 예측차 : [9514.213]
# 191번 데이터의 예측차 : [10161.201]
# 192번 데이터의 예측차 : [10458.0625]
# 193번 데이터의 예측차 : [10679.205]
# 194번 데이터의 예측차 : [10978.596]
# 195번 데이터의 예측차 : [12365.574]
# 196번 데이터의 예측차 : [13222.139]
# 197번 데이터의 예측차 : [13803.428]
# 198번 데이터의 예측차 : [14607.471]
# 199번 데이터의 예측차 : [15070.682]
# 200번 데이터의 예측차 : [15203.762]
# 201번 데이터의 예측차 : [15191.77]
# 202번 데이터의 예측차 : [15296.406]
# 203번 데이터의 예측차 : [15459.604]
# 204번 데이터의 예측차 : [15423.824]
# 205번 데이터의 예측차 : [15183.336]
# 206번 데이터의 예측차 : [14207.578]
# 207번 데이터의 예측차 : [13778.287]
# 208번 데이터의 예측차 : [12608.883]
# 209번 데이터의 예측차 : [11501.273]
# 210번 데이터의 예측차 : [11298.1]
# 211번 데이터의 예측차 : [10875.914]
# 212번 데이터의 예측차 : [9964.814]
# 213번 데이터의 예측차 : [9853.566]
# 214번 데이터의 예측차 : [10120.398]
# 215번 데이터의 예측차 : [8725.291]
# 216번 데이터의 예측차 : [8154.6133]
# 217번 데이터의 예측차 : [6874.8438]
# 218번 데이터의 예측차 : [6961.59]
# 219번 데이터의 예측차 : [6516.879]
# 220번 데이터의 예측차 : [5681.588]
# 221번 데이터의 예측차 : [4461.0215]
# 222번 데이터의 예측차 : [3959.6387]
# 223번 데이터의 예측차 : [2935.836]
# 224번 데이터의 예측차 : [3176.6973]
# 225번 데이터의 예측차 : [2939.871]
# 226번 데이터의 예측차 : [2220.4844]
# 227번 데이터의 예측차 : [1973.123]
# 228번 데이터의 예측차 : [1370.6797]
# 229번 데이터의 예측차 : [1114.666]
# 230번 데이터의 예측차 : [816.05664]
# 231번 데이터의 예측차 : [252.20312]
# 232번 데이터의 예측차 : [300.7832]
# 233번 데이터의 예측차 : [322.07422]
# 234번 데이터의 예측차 : [620.4668]
# 235번 데이터의 예측차 : [-209.7539]
# 236번 데이터의 예측차 : [-214.56836]
# 237번 데이터의 예측차 : [-470.64258]
# 238번 데이터의 예측차 : [-598.9043]
# 239번 데이터의 예측차 : [321.73047]
# 240번 데이터의 예측차 : [-517.41797]
# 241번 데이터의 예측차 : [-558.5469]
# 242번 데이터의 예측차 : [-554.4492]
# 243번 데이터의 예측차 : [-408.2461]
# 244번 데이터의 예측차 : [-447.28906]
# 245번 데이터의 예측차 : [-212.10156]
# 246번 데이터의 예측차 : [-220.60938]
# 247번 데이터의 예측차 : [-95.76953]
# 248번 데이터의 예측차 : [8.]
# 249번 데이터의 예측차 : [292.73047]
# 250번 데이터의 예측차 : [533.6699]
# 251번 데이터의 예측차 : [618.666]
# 252번 데이터의 예측차 : [1039.1055]
# 253번 데이터의 예측차 : [1772.5527]
# 254번 데이터의 예측차 : [1955.0859]
# 255번 데이터의 예측차 : [2313.1328]
# 256번 데이터의 예측차 : [2554.4297]
# 257번 데이터의 예측차 : [2657.838]
# 258번 데이터의 예측차 : [2832.461]
# 259번 데이터의 예측차 : [3053.543]
# 260번 데이터의 예측차 : [3634.043]
# 261번 데이터의 예측차 : [4026.8848]
# 262번 데이터의 예측차 : [4254.574]
# 263번 데이터의 예측차 : [4436.3145]
# 264번 데이터의 예측차 : [4305.8613]
# 265번 데이터의 예측차 : [4511.375]
# 266번 데이터의 예측차 : [4414.455]
# 267번 데이터의 예측차 : [5093.383]
# 268번 데이터의 예측차 : [4943.3984]
# 269번 데이터의 예측차 : [5378.2676]
# 270번 데이터의 예측차 : [5443.4395]
# 271번 데이터의 예측차 : [6331.1387]
# 272번 데이터의 예측차 : [5899.334]
# 273번 데이터의 예측차 : [6051.5527]
# 274번 데이터의 예측차 : [4091.6328]
# 275번 데이터의 예측차 : [3247.004]
# 276번 데이터의 예측차 : [493.35156]
# 277번 데이터의 예측차 : [-906.1914]
# 278번 데이터의 예측차 : [-525.83594]
# 279번 데이터의 예측차 : [-1113.9062]
# 280번 데이터의 예측차 : [-1466.6875]
# 281번 데이터의 예측차 : [-2161.8008]
# 282번 데이터의 예측차 : [-2714.1133]
# 283번 데이터의 예측차 : [-3074.1758]
# 284번 데이터의 예측차 : [-3147.0898]
# 285번 데이터의 예측차 : [-3374.082]
# 286번 데이터의 예측차 : [-3414.2578]
# 287번 데이터의 예측차 : [-3618.9023]
# 288번 데이터의 예측차 : [-3910.8984]
# 289번 데이터의 예측차 : [-4127.]
# 290번 데이터의 예측차 : [-4079.5547]
# 291번 데이터의 예측차 : [-4196.371]
# 292번 데이터의 예측차 : [-4437.215]
# 293번 데이터의 예측차 : [-4384.379]
# 294번 데이터의 예측차 : [-4159.051]
# 295번 데이터의 예측차 : [-3873.4805]
# 296번 데이터의 예측차 : [-3289.543]
# 297번 데이터의 예측차 : [-3007.0898]
# 298번 데이터의 예측차 : [-2612.4805]
# 299번 데이터의 예측차 : [-2150.1758]
# 300번 데이터의 예측차 : [-1574.1719]
# 301번 데이터의 예측차 : [-1159.4297]
# 302번 데이터의 예측차 : [-173.66797]
# 303번 데이터의 예측차 : [953.21875]
# 304번 데이터의 예측차 : [1740.7656]
# 305번 데이터의 예측차 : [2248.3047]
# 306번 데이터의 예측차 : [2978.8477]
# 307번 데이터의 예측차 : [3878.8691]
# 308번 데이터의 예측차 : [4332.965]
# 309번 데이터의 예측차 : [4739.5664]
# 310번 데이터의 예측차 : [5392.7305]
# 311번 데이터의 예측차 : [6028.217]
# 312번 데이터의 예측차 : [6811.211]
# 313번 데이터의 예측차 : [7278.086]
# 314번 데이터의 예측차 : [7976.6445]
# 315번 데이터의 예측차 : [8367.256]
# 316번 데이터의 예측차 : [8956.65]
# 317번 데이터의 예측차 : [9113.332]
# 318번 데이터의 예측차 : [9131.648]
# 319번 데이터의 예측차 : [9468.404]
# 320번 데이터의 예측차 : [9546.139]
# 321번 데이터의 예측차 : [9697.881]
# 322번 데이터의 예측차 : [10021.379]
# 323번 데이터의 예측차 : [9819.539]
# 324번 데이터의 예측차 : [9606.424]
# 325번 데이터의 예측차 : [9777.283]
# 326번 데이터의 예측차 : [9924.924]
# 327번 데이터의 예측차 : [9940.52]
# 328번 데이터의 예측차 : [9922.516]
# 329번 데이터의 예측차 : [9773.195]
# 330번 데이터의 예측차 : [9764.1875]
# 331번 데이터의 예측차 : [10022.242]
# 332번 데이터의 예측차 : [10282.16]
# 333번 데이터의 예측차 : [10171.656]
# 334번 데이터의 예측차 : [10245.996]
# 335번 데이터의 예측차 : [10856.623]
# 336번 데이터의 예측차 : [11403.59]
# 337번 데이터의 예측차 : [11146.658]
# 338번 데이터의 예측차 : [11304.549]
# 339번 데이터의 예측차 : [12121.678]
# 340번 데이터의 예측차 : [13210.391]
# 341번 데이터의 예측차 : [13745.5625]
# 342번 데이터의 예측차 : [14111.986]
# 343번 데이터의 예측차 : [14301.453]
# 344번 데이터의 예측차 : [14250.273]
# 345번 데이터의 예측차 : [14161.057]
# 346번 데이터의 예측차 : [14129.617]
# 347번 데이터의 예측차 : [14001.949]
# 348번 데이터의 예측차 : [14158.793]
# 349번 데이터의 예측차 : [13276.736]
# 350번 데이터의 예측차 : [11160.316]
# 351번 데이터의 예측차 : [11532.291]
# 352번 데이터의 예측차 : [10996.893]
# 353번 데이터의 예측차 : [10208.348]
# 354번 데이터의 예측차 : [8513.998]
# 355번 데이터의 예측차 : [7180.2715]
# 356번 데이터의 예측차 : [5909.6094]
# 357번 데이터의 예측차 : [6035.4004]
# 358번 데이터의 예측차 : [5668.248]
# 359번 데이터의 예측차 : [5516.5547]
# 360번 데이터의 예측차 : [5169.0684]
# 361번 데이터의 예측차 : [4717.416]
# 362번 데이터의 예측차 : [3823.082]
# 363번 데이터의 예측차 : [3550.2441]
# 364번 데이터의 예측차 : [2945.1309]
# 365번 데이터의 예측차 : [2344.1543]
# 366번 데이터의 예측차 : [1243.6621]
# 367번 데이터의 예측차 : [684.041]
# 368번 데이터의 예측차 : [556.60156]
# 369번 데이터의 예측차 : [7.5898438]
# 370번 데이터의 예측차 : [-477.39844]
# 371번 데이터의 예측차 : [-575.6738]
# 372번 데이터의 예측차 : [-819.40625]
# 373번 데이터의 예측차 : [-966.13477]
# 374번 데이터의 예측차 : [-1361.6875]
# 375번 데이터의 예측차 : [-1262.8027]
# 376번 데이터의 예측차 : [-1416.6992]
# 377번 데이터의 예측차 : [-1977.7637]
# 378번 데이터의 예측차 : [-2062.7734]
# 379번 데이터의 예측차 : [-2059.0938]
# 380번 데이터의 예측차 : [-2420.164]
# 381번 데이터의 예측차 : [-2534.7031]
# 382번 데이터의 예측차 : [-2165.8555]
# 383번 데이터의 예측차 : [-2294.0469]
# 384번 데이터의 예측차 : [-2179.5312]
# 385번 데이터의 예측차 : [-2815.7578]
# 386번 데이터의 예측차 : [-2792.4844]
# 387번 데이터의 예측차 : [-3015.0664]
# 388번 데이터의 예측차 : [-3066.8516]
# 389번 데이터의 예측차 : [-2871.8672]
# 390번 데이터의 예측차 : [-2443.461]
# 391번 데이터의 예측차 : [-2273.787]
# 392번 데이터의 예측차 : [-2050.0293]
# 393번 데이터의 예측차 : [-1867.8867]
# 394번 데이터의 예측차 : [-1162.4609]
# 395번 데이터의 예측차 : [-558.8711]
# 396번 데이터의 예측차 : [-539.0742]
# 397번 데이터의 예측차 : [43.253906]
# 398번 데이터의 예측차 : [114.15234]
# 399번 데이터의 예측차 : [178.93555]
# 400번 데이터의 예측차 : [589.4961]
# 401번 데이터의 예측차 : [639.5762]
# 402번 데이터의 예측차 : [1141.623]
# 403번 데이터의 예측차 : [1472.0352]
# 404번 데이터의 예측차 : [1625.2852]
# 405번 데이터의 예측차 : [1702.9453]
# 406번 데이터의 예측차 : [2098.5098]
# 407번 데이터의 예측차 : [2501.0918]
# 408번 데이터의 예측차 : [3079.2832]
# 409번 데이터의 예측차 : [2986.4805]
# 410번 데이터의 예측차 : [3065.0098]
# 411번 데이터의 예측차 : [3583.7656]
# 412번 데이터의 예측차 : [3704.1387]
# 413번 데이터의 예측차 : [4316.1543]
# 414번 데이터의 예측차 : [4338.9473]
# 415번 데이터의 예측차 : [3876.1602]
# 416번 데이터의 예측차 : [3148.7559]
# 417번 데이터의 예측차 : [2340.9727]
# 418번 데이터의 예측차 : [2164.2617]
# 419번 데이터의 예측차 : [4975.8047]
# 420번 데이터의 예측차 : [2691.6836]
# 421번 데이터의 예측차 : [631.22266]
# 422번 데이터의 예측차 : [-769.8125]
# 423번 데이터의 예측차 : [-1131.3125]
# 424번 데이터의 예측차 : [-1375.4727]
# 425번 데이터의 예측차 : [-1837.8594]
# 426번 데이터의 예측차 : [-2016.9336]
# 427번 데이터의 예측차 : [-1662.5938]
# 428번 데이터의 예측차 : [-3646.1953]
# 429번 데이터의 예측차 : [-3891.6367]
# 430번 데이터의 예측차 : [-3669.7852]
# 431번 데이터의 예측차 : [-4174.172]
# 432번 데이터의 예측차 : [-3584.0117]
# 433번 데이터의 예측차 : [-3692.4531]
# 434번 데이터의 예측차 : [-3620.7852]
# 435번 데이터의 예측차 : [-3650.625]
# 436번 데이터의 예측차 : [-3677.1523]
# 437번 데이터의 예측차 : [-3480.25]
# 438번 데이터의 예측차 : [-3089.793]
# 439번 데이터의 예측차 : [-2576.629]
# 440번 데이터의 예측차 : [-2368.5938]
# 441번 데이터의 예측차 : [-1961.5234]
# 442번 데이터의 예측차 : [-1516.6875]
# 443번 데이터의 예측차 : [-983.9922]
# 444번 데이터의 예측차 : [-1402.7773]
# 445번 데이터의 예측차 : [-1543.9062]
# 446번 데이터의 예측차 : [-688.0781]
# 447번 데이터의 예측차 : [-101.01953]
# 448번 데이터의 예측차 : [578.6094]
# 449번 데이터의 예측차 : [1145.9922]
# 450번 데이터의 예측차 : [1914.6406]
# 451번 데이터의 예측차 : [2622.9297]
# 452번 데이터의 예측차 : [3742.377]
# 453번 데이터의 예측차 : [4236.92]
# 454번 데이터의 예측차 : [4780.213]
# 455번 데이터의 예측차 : [5427.3633]
# 456번 데이터의 예측차 : [5830.5723]
# 457번 데이터의 예측차 : [6761.5312]
# 458번 데이터의 예측차 : [6432.799]
# 459번 데이터의 예측차 : [6472.7305]
# 460번 데이터의 예측차 : [6717.4023]
# 461번 데이터의 예측차 : [6817.3516]
# 462번 데이터의 예측차 : [7032.8887]
# 463번 데이터의 예측차 : [7166.842]
# 464번 데이터의 예측차 : [7406.9824]
# 465번 데이터의 예측차 : [7635.414]
# 466번 데이터의 예측차 : [7549.4297]
# 467번 데이터의 예측차 : [7273.8203]
# 468번 데이터의 예측차 : [7552.9805]
# 469번 데이터의 예측차 : [7711.9688]
# 470번 데이터의 예측차 : [8006.342]
# 471번 데이터의 예측차 : [7747.121]
# 472번 데이터의 예측차 : [7514.8438]
# 473번 데이터의 예측차 : [7423.8047]
# 474번 데이터의 예측차 : [7508.242]
# 475번 데이터의 예측차 : [7679.834]
# 476번 데이터의 예측차 : [7692.416]
# 477번 데이터의 예측차 : [7242.4785]
# 478번 데이터의 예측차 : [7130.2812]
# 479번 데이터의 예측차 : [7308.1035]
# 480번 데이터의 예측차 : [7676.959]
# 481번 데이터의 예측차 : [7612.9844]
# 482번 데이터의 예측차 : [7837.3184]
# 483번 데이터의 예측차 : [8548.047]
# 484번 데이터의 예측차 : [9801.5]
# 485번 데이터의 예측차 : [11224.496]
# 486번 데이터의 예측차 : [12161.625]
# 487번 데이터의 예측차 : [12569.143]
# 488번 데이터의 예측차 : [12415.018]
# 489번 데이터의 예측차 : [12246.537]
# 490번 데이터의 예측차 : [12413.762]
# 491번 데이터의 예측차 : [12590.113]
# 492번 데이터의 예측차 : [12360.727]
# 493번 데이터의 예측차 : [11878.492]
# 494번 데이터의 예측차 : [11795.809]
# 495번 데이터의 예측차 : [11277.543]
# 496번 데이터의 예측차 : [10512.332]
# 497번 데이터의 예측차 : [9907.752]
# 498번 데이터의 예측차 : [8476.164]
# 499번 데이터의 예측차 : [7026.586]
# 500번 데이터의 예측차 : [6053.922]
# 501번 데이터의 예측차 : [6284.3633]
# 502번 데이터의 예측차 : [5949.5723]
# 503번 데이터의 예측차 : [4636.9297]
# 504번 데이터의 예측차 : [4295.369]
# 505번 데이터의 예측차 : [3782.83]
# 506번 데이터의 예측차 : [3343.373]
# 507번 데이터의 예측차 : [3019.5625]
# 508번 데이터의 예측차 : [2776.8633]
# 509번 데이터의 예측차 : [1593.3086]
# 510번 데이터의 예측차 : [573.9199]
# 511번 데이터의 예측차 : [256.69922]
# 512번 데이터의 예측차 : [-97.84375]
# 513번 데이터의 예측차 : [-350.1289]
# 514번 데이터의 예측차 : [-1333.3516]
# 515번 데이터의 예측차 : [-2480.246]
# 516번 데이터의 예측차 : [-2730.795]
# 517번 데이터의 예측차 : [-2971.4727]
# 518번 데이터의 예측차 : [-3443.4473]
# 519번 데이터의 예측차 : [-3593.4277]
# 520번 데이터의 예측차 : [-4136.461]
# 521번 데이터의 예측차 : [-4172.4004]
# 522번 데이터의 예측차 : [-4389.961]
# 523번 데이터의 예측차 : [-4402.3574]
# 524번 데이터의 예측차 : [-4324.3867]
# 525번 데이터의 예측차 : [-4428.8594]
# 526번 데이터의 예측차 : [-4395.168]
# 527번 데이터의 예측차 : [-4605.1367]
# 528번 데이터의 예측차 : [-4162.4414]
# 529번 데이터의 예측차 : [-3982.0508]
# 530번 데이터의 예측차 : [-4206.6133]
# 531번 데이터의 예측차 : [-4121.133]
# 532번 데이터의 예측차 : [-4207.6016]
# 533번 데이터의 예측차 : [-4145.871]
# 534번 데이터의 예측차 : [-4143.617]
# 535번 데이터의 예측차 : [-3505.6484]
# 536번 데이터의 예측차 : [-3383.8906]
# 537번 데이터의 예측차 : [-3044.3516]
# 538번 데이터의 예측차 : [-2894.9922]
# 539번 데이터의 예측차 : [-2895.1484]
# 540번 데이터의 예측차 : [-2697.3594]
# 541번 데이터의 예측차 : [-2070.1992]
# 542번 데이터의 예측차 : [-1874.0312]
# 543번 데이터의 예측차 : [-1573.9062]
# 544번 데이터의 예측차 : [-1100.6094]
# 545번 데이터의 예측차 : [-712.71875]
# 546번 데이터의 예측차 : [-572.5508]
# 547번 데이터의 예측차 : [-170.6836]
# 548번 데이터의 예측차 : [301.09375]
# 549번 데이터의 예측차 : [238.16016]
# 550번 데이터의 예측차 : [412.59766]
# 551번 데이터의 예측차 : [797.9297]
# 552번 데이터의 예측차 : [1095.2812]
# 553번 데이터의 예측차 : [1270.2227]
# 554번 데이터의 예측차 : [1125.5547]
# 555번 데이터의 예측차 : [1328.0117]
# 556번 데이터의 예측차 : [2975.961]
# 557번 데이터의 예측차 : [2003.2578]
# 558번 데이터의 예측차 : [2271.4648]
# 559번 데이터의 예측차 : [2899.2812]
# 560번 데이터의 예측차 : [2771.7656]
# 561번 데이터의 예측차 : [2602.0234]
# 562번 데이터의 예측차 : [1576.8164]
# 563번 데이터의 예측차 : [895.84766]
# 564번 데이터의 예측차 : [-1176.7148]
# 565번 데이터의 예측차 : [-3332.3516]
# 566번 데이터의 예측차 : [-4504.8164]
# 567번 데이터의 예측차 : [-5147.3633]
# 568번 데이터의 예측차 : [-5579.133]
# 569번 데이터의 예측차 : [-6184.5703]
# 570번 데이터의 예측차 : [-6324.8477]
# 571번 데이터의 예측차 : [-6394.4062]
# 572번 데이터의 예측차 : [-6347.207]
# 573번 데이터의 예측차 : [-6239.867]
# 574번 데이터의 예측차 : [-6032.9727]
# 575번 데이터의 예측차 : [-5958.922]
# 576번 데이터의 예측차 : [-6026.086]
# 577번 데이터의 예측차 : [-6213.211]
# 578번 데이터의 예측차 : [-6322.4805]
# 579번 데이터의 예측차 : [-6280.918]
# 580번 데이터의 예측차 : [-6085.297]
# 581번 데이터의 예측차 : [-5593.1914]
# 582번 데이터의 예측차 : [-5506.3984]
# 583번 데이터의 예측차 : [-5333.16]
# 584번 데이터의 예측차 : [-4850.1016]
# 585번 데이터의 예측차 : [-4234.6016]
# 586번 데이터의 예측차 : [-3392.293]
# 587번 데이터의 예측차 : [-2953.8281]
# 588번 데이터의 예측차 : [-3246.3516]
# 589번 데이터의 예측차 : [-2598.3516]
# 590번 데이터의 예측차 : [-1651.6367]
# 591번 데이터의 예측차 : [924.9922]
# 592번 데이터의 예측차 : [2566.168]
# 593번 데이터의 예측차 : [2889.668]
# 594번 데이터의 예측차 : [3795.629]
# 595번 데이터의 예측차 : [5514.953]
# 596번 데이터의 예측차 : [6241.1484]
# 597번 데이터의 예측차 : [6930.6426]
# 598번 데이터의 예측차 : [7759.332]
# 599번 데이터의 예측차 : [8292.418]
# 600번 데이터의 예측차 : [8905.002]
# 601번 데이터의 예측차 : [9480.426]
# 602번 데이터의 예측차 : [9882.795]
# 603번 데이터의 예측차 : [10241.799]
# 604번 데이터의 예측차 : [10490.502]
# 605번 데이터의 예측차 : [10723.695]
# 606번 데이터의 예측차 : [10893.326]
# 607번 데이터의 예측차 : [11416.736]
# 608번 데이터의 예측차 : [11279.732]
# 609번 데이터의 예측차 : [11092.137]
# 610번 데이터의 예측차 : [11019.996]
# 611번 데이터의 예측차 : [10876.869]
# 612번 데이터의 예측차 : [10455.588]
# 613번 데이터의 예측차 : [10646.662]
# 614번 데이터의 예측차 : [10763.15]
# 615번 데이터의 예측차 : [10949.273]
# 616번 데이터의 예측차 : [10255.76]
# 617번 데이터의 예측차 : [10484.129]
# 618번 데이터의 예측차 : [10907.055]
# 619번 데이터의 예측차 : [11296.879]
# 620번 데이터의 예측차 : [11303.924]
# 621번 데이터의 예측차 : [10778.33]
# 622번 데이터의 예측차 : [10529.479]
# 623번 데이터의 예측차 : [10326.059]
# 624번 데이터의 예측차 : [10166.951]
# 625번 데이터의 예측차 : [9912.102]
# 626번 데이터의 예측차 : [9967.738]
# 627번 데이터의 예측차 : [10852.029]
# 628번 데이터의 예측차 : [11601.691]
# 629번 데이터의 예측차 : [11991.344]
# 630번 데이터의 예측차 : [12567.348]
# 631번 데이터의 예측차 : [12448.951]
# 632번 데이터의 예측차 : [11328.994]
# 633번 데이터의 예측차 : [10894.012]
# 634번 데이터의 예측차 : [10919.908]
# 635번 데이터의 예측차 : [10690.445]
# 636번 데이터의 예측차 : [10695.957]
# 637번 데이터의 예측차 : [10383.822]
# 638번 데이터의 예측차 : [8883.344]
# 639번 데이터의 예측차 : [7452.211]
# 640번 데이터의 예측차 : [11183.463]
# 641번 데이터의 예측차 : [11054.686]
# 642번 데이터의 예측차 : [10056.795]
# 643번 데이터의 예측차 : [8611.955]
# 644번 데이터의 예측차 : [8412.607]
# 645번 데이터의 예측차 : [7286.5215]
# 646번 데이터의 예측차 : [7567.2285]
# 647번 데이터의 예측차 : [7677.625]
# 648번 데이터의 예측차 : [7369.619]
# 649번 데이터의 예측차 : [6935.84]
# 650번 데이터의 예측차 : [6343.1387]
# 651번 데이터의 예측차 : [6524.365]
# 652번 데이터의 예측차 : [6237.9004]
# 653번 데이터의 예측차 : [5351.949]
# 654번 데이터의 예측차 : [5144.533]
# 655번 데이터의 예측차 : [4334.5293]
# 656번 데이터의 예측차 : [3323.2773]
# 657번 데이터의 예측차 : [3390.9805]
# 658번 데이터의 예측차 : [3506.461]
# 659번 데이터의 예측차 : [2943.2695]
# 660번 데이터의 예측차 : [2855.836]
# 661번 데이터의 예측차 : [1755.9785]
# 662번 데이터의 예측차 : [1453.6562]
# 663번 데이터의 예측차 : [1021.65234]
# 664번 데이터의 예측차 : [-39.617188]
# 665번 데이터의 예측차 : [471.95703]
# 666번 데이터의 예측차 : [-117.61328]
# 667번 데이터의 예측차 : [417.45703]
# 668번 데이터의 예측차 : [-286.78516]
# 669번 데이터의 예측차 : [-735.84375]
# 670번 데이터의 예측차 : [-204.64453]
# 671번 데이터의 예측차 : [-439.35938]
# 672번 데이터의 예측차 : [-844.41797]
# 673번 데이터의 예측차 : [-769.54297]
# 674번 데이터의 예측차 : [-1020.08984]
# 675번 데이터의 예측차 : [-907.4453]
# 676번 데이터의 예측차 : [-603.3086]
# 677번 데이터의 예측차 : [-436.6914]
# 678번 데이터의 예측차 : [-575.60156]
# 679번 데이터의 예측차 : [216.23047]
# 680번 데이터의 예측차 : [201.63281]
# 681번 데이터의 예측차 : [315.42188]
# 682번 데이터의 예측차 : [385.36328]
# 683번 데이터의 예측차 : [568.9922]
# 684번 데이터의 예측차 : [899.0117]
# 685번 데이터의 예측차 : [953.5254]
# 686번 데이터의 예측차 : [1435.2363]
# 687번 데이터의 예측차 : [1518.3457]
# 688번 데이터의 예측차 : [1833.0996]
# 689번 데이터의 예측차 : [2200.2617]
# 690번 데이터의 예측차 : [2637.459]
# 691번 데이터의 예측차 : [3213.75]
# 692번 데이터의 예측차 : [2712.7422]
# 693번 데이터의 예측차 : [2764.8945]
# 694번 데이터의 예측차 : [3061.1152]
# 695번 데이터의 예측차 : [3294.5996]
# 696번 데이터의 예측차 : [3555.7207]
# 697번 데이터의 예측차 : [3105.248]
# 698번 데이터의 예측차 : [2991.082]
# 699번 데이터의 예측차 : [3039.8691]
# 700번 데이터의 예측차 : [3225.6758]
# 701번 데이터의 예측차 : [3384.9316]
# 702번 데이터의 예측차 : [2781.1797]
# 703번 데이터의 예측차 : [2069.3125]
# 704번 데이터의 예측차 : [1693.9727]
# 705번 데이터의 예측차 : [1913.4961]
# 706번 데이터의 예측차 : [818.1953]
# 707번 데이터의 예측차 : [-1594.625]
# 708번 데이터의 예측차 : [-3429.8555]
# 709번 데이터의 예측차 : [-4930.7344]
# 710번 데이터의 예측차 : [-5897.4727]
# 711번 데이터의 예측차 : [-5845.6055]
# 712번 데이터의 예측차 : [-6802.1836]
# 713번 데이터의 예측차 : [-7529.2812]
# 714번 데이터의 예측차 : [-7638.4805]
# 715번 데이터의 예측차 : [-7618.199]
# 716번 데이터의 예측차 : [-7649.1133]
# 717번 데이터의 예측차 : [-8014.3203]
# 718번 데이터의 예측차 : [-8272.379]
# 719번 데이터의 예측차 : [-7996.758]
# 720번 데이터의 예측차 : [-7859.5977]
# 721번 데이터의 예측차 : [-7755.4844]
# 722번 데이터의 예측차 : [-7576.1953]
# 723번 데이터의 예측차 : [-7372.09]
# 724번 데이터의 예측차 : [-7177.203]
# 725번 데이터의 예측차 : [-6803.8477]
# 726번 데이터의 예측차 : [-6178.5312]
# 727번 데이터의 예측차 : [-5395.461]
# 728번 데이터의 예측차 : [-4932.426]
# 729번 데이터의 예측차 : [-4213.008]
# 730번 데이터의 예측차 : [-3370.8047]
# 731번 데이터의 예측차 : [-3048.0352]
# 732번 데이터의 예측차 : [-1788.1133]
# 733번 데이터의 예측차 : [-778.3906]
# 734번 데이터의 예측차 : [-432.8828]
# 735번 데이터의 예측차 : [273.20312]
# 736번 데이터의 예측차 : [1048.043]
# 737번 데이터의 예측차 : [1830.0469]
# 738번 데이터의 예측차 : [3114.5117]
# 739번 데이터의 예측차 : [3184.9102]
# 740번 데이터의 예측차 : [3773.9023]
# 741번 데이터의 예측차 : [4372.705]
# 742번 데이터의 예측차 : [4785.006]
# 743번 데이터의 예측차 : [5684.551]
# 744번 데이터의 예측차 : [6192.6465]
# 745번 데이터의 예측차 : [6335.3184]
# 746번 데이터의 예측차 : [6575.5684]
# 747번 데이터의 예측차 : [6740.0547]
# 748번 데이터의 예측차 : [7144.367]
# 749번 데이터의 예측차 : [7327.0723]
# 750번 데이터의 예측차 : [7459.5117]
# 751번 데이터의 예측차 : [7653.541]
# 752번 데이터의 예측차 : [7480.1973]
# 753번 데이터의 예측차 : [7805.457]
# 754번 데이터의 예측차 : [7885.047]
# 755번 데이터의 예측차 : [7884.0605]
# 756번 데이터의 예측차 : [8144.9023]
# 757번 데이터의 예측차 : [8105.625]
# 758번 데이터의 예측차 : [8115.3105]
# 759번 데이터의 예측차 : [8125.3457]
# 760번 데이터의 예측차 : [8226.357]
# 761번 데이터의 예측차 : [8143.371]
# 762번 데이터의 예측차 : [8297.705]
# 763번 데이터의 예측차 : [8213.822]
# 764번 데이터의 예측차 : [8205.791]
# 765번 데이터의 예측차 : [7645.5137]
# 766번 데이터의 예측차 : [7338.9785]
# 767번 데이터의 예측차 : [7450.158]
# 768번 데이터의 예측차 : [7474.4688]
# 769번 데이터의 예측차 : [7414.6973]
# 770번 데이터의 예측차 : [7811.0195]
# 771번 데이터의 예측차 : [8985.0625]
# 772번 데이터의 예측차 : [10306.6875]
# 773번 데이터의 예측차 : [10718.266]
# 774번 데이터의 예측차 : [11211.223]
# 775번 데이터의 예측차 : [10764.869]
# 776번 데이터의 예측차 : [10421.252]
# 777번 데이터의 예측차 : [10178.059]
# 778번 데이터의 예측차 : [9881.016]
# 779번 데이터의 예측차 : [9615.039]
# 780번 데이터의 예측차 : [10038.529]
# 781번 데이터의 예측차 : [9599.838]
# 782번 데이터의 예측차 : [9249.018]
# 783번 데이터의 예측차 : [9073.383]
# 784번 데이터의 예측차 : [8659.012]
# 785번 데이터의 예측차 : [8688.68]
# 786번 데이터의 예측차 : [5054.7773]
# 787번 데이터의 예측차 : [5822.8633]
# 788번 데이터의 예측차 : [5477.3887]
# 789번 데이터의 예측차 : [3807.6445]
# 790번 데이터의 예측차 : [2507.3008]
# 791번 데이터의 예측차 : [3477.002]
# 792번 데이터의 예측차 : [4169.215]
# 793번 데이터의 예측차 : [3214.0098]
# 794번 데이터의 예측차 : [775.38086]
# 795번 데이터의 예측차 : [-87.73828]
# 796번 데이터의 예측차 : [936.0469]
# 797번 데이터의 예측차 : [647.90625]
# 798번 데이터의 예측차 : [-1844.4316]
# 799번 데이터의 예측차 : [278.6875]
# 800번 데이터의 예측차 : [-2463.2266]
# 801번 데이터의 예측차 : [-1267.8633]
# 802번 데이터의 예측차 : [-1727.4531]
# 803번 데이터의 예측차 : [-2739.5234]
# 804번 데이터의 예측차 : [-1815.4414]
# 805번 데이터의 예측차 : [-2893.9844]
# 806번 데이터의 예측차 : [-3814.711]
# 807번 데이터의 예측차 : [-3178.379]
# 808번 데이터의 예측차 : [-3966.8086]
# 809번 데이터의 예측차 : [-3873.3242]
# 810번 데이터의 예측차 : [-3743.4922]
# 811번 데이터의 예측차 : [-4020.9375]
# 812번 데이터의 예측차 : [-4041.5625]
# 813번 데이터의 예측차 : [-3385.5586]
# 814번 데이터의 예측차 : [-3057.1953]
# 815번 데이터의 예측차 : [-3120.6445]
# 816번 데이터의 예측차 : [-2640.6562]
# 817번 데이터의 예측차 : [-3316.3164]
# 818번 데이터의 예측차 : [-3666.4883]
# 819번 데이터의 예측차 : [-3820.1602]
# 820번 데이터의 예측차 : [-3796.0898]
# 821번 데이터의 예측차 : [-3684.2852]
# 822번 데이터의 예측차 : [-3515.6367]
# 823번 데이터의 예측차 : [-3101.457]
# 824번 데이터의 예측차 : [-2735.8438]
# 825번 데이터의 예측차 : [-3292.4219]
# 826번 데이터의 예측차 : [-3082.1055]
# 827번 데이터의 예측차 : [-2706.4336]
# 828번 데이터의 예측차 : [-2945.3008]
# 829번 데이터의 예측차 : [-2543.0508]
# 830번 데이터의 예측차 : [-2510.5742]
# 831번 데이터의 예측차 : [-2424.6172]
# 832번 데이터의 예측차 : [-1985.457]
# 833번 데이터의 예측차 : [-1877.8633]
# 834번 데이터의 예측차 : [-1791.9258]
# 835번 데이터의 예측차 : [-1364.75]
# 836번 데이터의 예측차 : [-545.2422]
# 837번 데이터의 예측차 : [-170.625]
# 838번 데이터의 예측차 : [-143.57031]
# 839번 데이터의 예측차 : [221.125]
# 840번 데이터의 예측차 : [-77.91016]
# 841번 데이터의 예측차 : [100.78906]
# 842번 데이터의 예측차 : [331.51172]
# 843번 데이터의 예측차 : [370.8789]
# 844번 데이터의 예측차 : [864.78516]
# 845번 데이터의 예측차 : [978.9414]
# 846번 데이터의 예측차 : [408.57422]
# 847번 데이터의 예측차 : [-165.21875]
# 848번 데이터의 예측차 : [-735.22656]
# 849번 데이터의 예측차 : [-1845.0078]
# 850번 데이터의 예측차 : [-2435.4492]
# 851번 데이터의 예측차 : [810.03125]
# 852번 데이터의 예측차 : [-1897.1367]
# 853번 데이터의 예측차 : [-4008.3398]
# 854번 데이터의 예측차 : [-5811.7227]
# 855번 데이터의 예측차 : [-5880.2383]
# 856번 데이터의 예측차 : [-6226.3477]
# 857번 데이터의 예측차 : [-6524.6367]
# 858번 데이터의 예측차 : [-6863.9336]
# 859번 데이터의 예측차 : [-6820.492]
# 860번 데이터의 예측차 : [-6774.543]
# 861번 데이터의 예측차 : [-6912.5273]
# 862번 데이터의 예측차 : [-6801.547]
# 863번 데이터의 예측차 : [-6932.7656]
# 864번 데이터의 예측차 : [-7219.668]
# 865번 데이터의 예측차 : [-7030.926]
# 866번 데이터의 예측차 : [-6729.074]
# 867번 데이터의 예측차 : [-6825.1484]
# 868번 데이터의 예측차 : [-6707.426]
# 869번 데이터의 예측차 : [-6510.1836]
# 870번 데이터의 예측차 : [-6259.375]
# 871번 데이터의 예측차 : [-5661.5273]
# 872번 데이터의 예측차 : [-5022.4805]
# 873번 데이터의 예측차 : [-4806.2695]
# 874번 데이터의 예측차 : [-4676.621]
# 875번 데이터의 예측차 : [-4099.8203]
# 876번 데이터의 예측차 : [-3244.8477]
# 877번 데이터의 예측차 : [-1641.8789]
# 878번 데이터의 예측차 : [-993.97656]
# 879번 데이터의 예측차 : [437.33984]
# 880번 데이터의 예측차 : [874.1094]
# 881번 데이터의 예측차 : [1189.0938]
# 882번 데이터의 예측차 : [1449.2109]
# 883번 데이터의 예측차 : [1642.0273]
# 884번 데이터의 예측차 : [2238.1055]
# 885번 데이터의 예측차 : [3062.129]
# 886번 데이터의 예측차 : [3674.6309]
# 887번 데이터의 예측차 : [4158.5117]
# 888번 데이터의 예측차 : [4857.252]
# 889번 데이터의 예측차 : [4999.4473]
# 890번 데이터의 예측차 : [5332.078]
# 891번 데이터의 예측차 : [5187.3438]
# 892번 데이터의 예측차 : [5284.203]
# 893번 데이터의 예측차 : [5639.291]
# 894번 데이터의 예측차 : [6272.037]
# 895번 데이터의 예측차 : [6066.699]
# 896번 데이터의 예측차 : [5956.785]
# 897번 데이터의 예측차 : [6044.535]
# 898번 데이터의 예측차 : [5950.1895]
# 899번 데이터의 예측차 : [6480.662]
# 900번 데이터의 예측차 : [6904.8203]
# 901번 데이터의 예측차 : [6822.8066]
# 902번 데이터의 예측차 : [6647.953]
# 903번 데이터의 예측차 : [7054.6406]
# 904번 데이터의 예측차 : [6601.918]
# 905번 데이터의 예측차 : [6384.992]
# 906번 데이터의 예측차 : [6318.8203]
# 907번 데이터의 예측차 : [6425.9824]
# 908번 데이터의 예측차 : [5969.074]
# 909번 데이터의 예측차 : [5397.4395]
# 910번 데이터의 예측차 : [5353.5195]
# 911번 데이터의 예측차 : [5564.5]
# 912번 데이터의 예측차 : [5659.301]
# 913번 데이터의 예측차 : [5678.6426]
# 914번 데이터의 예측차 : [5949.6523]
# 915번 데이터의 예측차 : [6857.8867]
# 916번 데이터의 예측차 : [7700.6504]
# 917번 데이터의 예측차 : [8289.094]
# 918번 데이터의 예측차 : [8494.479]
# 919번 데이터의 예측차 : [8616.053]
# 920번 데이터의 예측차 : [8185.0664]
# 921번 데이터의 예측차 : [7764.4062]
# 922번 데이터의 예측차 : [7700.4746]
# 923번 데이터의 예측차 : [7679.621]
# 924번 데이터의 예측차 : [7512.0176]
# 925번 데이터의 예측차 : [7738.506]
# 926번 데이터의 예측차 : [6228.9004]
# 927번 데이터의 예측차 : [5142.924]
# 928번 데이터의 예측차 : [4766.172]
# 929번 데이터의 예측차 : [3380.5977]
# 930번 데이터의 예측차 : [2350.9922]
# 931번 데이터의 예측차 : [2752.0488]
# 932번 데이터의 예측차 : [3308.58]
# 933번 데이터의 예측차 : [3248.3418]
# 934번 데이터의 예측차 : [3480.92]
# 935번 데이터의 예측차 : [3693.5898]
# 936번 데이터의 예측차 : [3608.334]
# 937번 데이터의 예측차 : [3143.8945]
# 938번 데이터의 예측차 : [2631.7402]
# 939번 데이터의 예측차 : [1654.8984]
# 940번 데이터의 예측차 : [959.02734]
# 941번 데이터의 예측차 : [475.83594]
# 942번 데이터의 예측차 : [-52.285156]
# 943번 데이터의 예측차 : [-0.1328125]
# 944번 데이터의 예측차 : [-323.21484]
# 945번 데이터의 예측차 : [-1122.9453]
# 946번 데이터의 예측차 : [-1723.6406]
# 947번 데이터의 예측차 : [-1751.4297]
# 948번 데이터의 예측차 : [-1719.9531]
# 949번 데이터의 예측차 : [-2066.5938]
# 950번 데이터의 예측차 : [-2754.1133]
# 951번 데이터의 예측차 : [-3805.8203]
# 952번 데이터의 예측차 : [-4059.6172]
# 953번 데이터의 예측차 : [-4025.6602]
# 954번 데이터의 예측차 : [-4358.449]
# 955번 데이터의 예측차 : [-4119.6953]
# 956번 데이터의 예측차 : [-3654.1602]
# 957번 데이터의 예측차 : [-3267.625]
# 958번 데이터의 예측차 : [-3030.5195]
# 959번 데이터의 예측차 : [-3069.3086]
# 960번 데이터의 예측차 : [-2908.5625]
# 961번 데이터의 예측차 : [-2839.746]
# 962번 데이터의 예측차 : [-2938.6406]
# 963번 데이터의 예측차 : [-3288.0977]
# 964번 데이터의 예측차 : [-3423.4648]
# 965번 데이터의 예측차 : [-3265.4844]
# 966번 데이터의 예측차 : [-3145.5078]
# 967번 데이터의 예측차 : [-2999.2695]
# 968번 데이터의 예측차 : [-2931.9414]
# 969번 데이터의 예측차 : [-2706.9375]
# 970번 데이터의 예측차 : [-2592.3516]
# 971번 데이터의 예측차 : [-2509.5938]
# 972번 데이터의 예측차 : [-2257.2383]
# 973번 데이터의 예측차 : [-1929.6406]
# 974번 데이터의 예측차 : [-1663.6719]
# 975번 데이터의 예측차 : [-1814.6016]
# 976번 데이터의 예측차 : [-1499.8906]
# 977번 데이터의 예측차 : [-1616.625]
# 978번 데이터의 예측차 : [-777.28125]
# 979번 데이터의 예측차 : [-456.73047]
# 980번 데이터의 예측차 : [-450.26953]
# 981번 데이터의 예측차 : [-999.5625]
# 982번 데이터의 예측차 : [-617.5]
# 983번 데이터의 예측차 : [-270.48828]
# 984번 데이터의 예측차 : [-142.21094]
# 985번 데이터의 예측차 : [183.71094]
# 986번 데이터의 예측차 : [183.75]
# 987번 데이터의 예측차 : [-0.1953125]
# 988번 데이터의 예측차 : [329.76953]
# 989번 데이터의 예측차 : [528.6367]
# 990번 데이터의 예측차 : [461.08203]
# 991번 데이터의 예측차 : [444.23047]
# 992번 데이터의 예측차 : [61.03125]
# 993번 데이터의 예측차 : [-373.59375]
# 994번 데이터의 예측차 : [-2063.4805]
# 995번 데이터의 예측차 : [514.41016]
# 996번 데이터의 예측차 : [-1923.0664]
# 997번 데이터의 예측차 : [-3243.6133]
# 998번 데이터의 예측차 : [-4284.0586]
# 999번 데이터의 예측차 : [-5730.754]
# 1000번 데이터의 예측차 : [-6168.6094]
# 1001번 데이터의 예측차 : [-6957.9688]
# 1002번 데이터의 예측차 : [-6979.4414]
# 1003번 데이터의 예측차 : [-6597.1562]
# 1004번 데이터의 예측차 : [-6655.1016]
# 1005번 데이터의 예측차 : [-6754.586]
# 1006번 데이터의 예측차 : [-6931.965]
# 1007번 데이터의 예측차 : [-6970.3086]
# 1008번 데이터의 예측차 : [-7134.7773]
# 1009번 데이터의 예측차 : [-7168.0625]
# 1010번 데이터의 예측차 : [-6975.883]
# 1011번 데이터의 예측차 : [-7276.742]
# 1012번 데이터의 예측차 : [-7047.051]
# 1013번 데이터의 예측차 : [-6765.5938]
# 1014번 데이터의 예측차 : [-6449.5703]
# 1015번 데이터의 예측차 : [-6444.746]
# 1016번 데이터의 예측차 : [-5960.707]
# 1017번 데이터의 예측차 : [-5153.1484]
# 1018번 데이터의 예측차 : [-4363.918]
# 1019번 데이터의 예측차 : [-3620.918]
# 1020번 데이터의 예측차 : [-2646.0664]
# 1021번 데이터의 예측차 : [-1851.0977]
# 1022번 데이터의 예측차 : [-1297.0039]
# 1023번 데이터의 예측차 : [-840.5039]
# 1024번 데이터의 예측차 : [-514.0703]
# 1025번 데이터의 예측차 : [-358.90625]
# 1026번 데이터의 예측차 : [269.5703]
# 1027번 데이터의 예측차 : [1271.4805]
# 1028번 데이터의 예측차 : [1878.4961]
# 1029번 데이터의 예측차 : [2233.3633]
# 1030번 데이터의 예측차 : [2853.1953]
# 1031번 데이터의 예측차 : [3200.5781]
# 1032번 데이터의 예측차 : [3622.3008]
# 1033번 데이터의 예측차 : [3968.1172]
# 1034번 데이터의 예측차 : [3947.2383]
# 1035번 데이터의 예측차 : [3978.791]
# 1036번 데이터의 예측차 : [4276.088]
# 1037번 데이터의 예측차 : [4638.289]
# 1038번 데이터의 예측차 : [4574.592]
# 1039번 데이터의 예측차 : [4388.004]
# 1040번 데이터의 예측차 : [4696.533]
# 1041번 데이터의 예측차 : [4795.6113]
# 1042번 데이터의 예측차 : [4635.047]
# 1043번 데이터의 예측차 : [4674.873]
# 1044번 데이터의 예측차 : [5289.3906]
# 1045번 데이터의 예측차 : [5466.5312]
# 1046번 데이터의 예측차 : [5718.371]
# 1047번 데이터의 예측차 : [5741.2793]
# 1048번 데이터의 예측차 : [5408.092]
# 1049번 데이터의 예측차 : [5389.576]
# 1050번 데이터의 예측차 : [5277.541]
# 1051번 데이터의 예측차 : [5188.465]
# 1052번 데이터의 예측차 : [5013.0273]
# 1053번 데이터의 예측차 : [4965.1484]
# 1054번 데이터의 예측차 : [4445.5566]
# 1055번 데이터의 예측차 : [4921.576]
# 1056번 데이터의 예측차 : [5427.0117]
# 1057번 데이터의 예측차 : [5351.795]
# 1058번 데이터의 예측차 : [5570.3867]
# 1059번 데이터의 예측차 : [6525.4004]
# 1060번 데이터의 예측차 : [8114.3633]
# 1061번 데이터의 예측차 : [8852.141]
# 1062번 데이터의 예측차 : [9570.48]
# 1063번 데이터의 예측차 : [9598.781]
# 1064번 데이터의 예측차 : [9651.625]
# 1065번 데이터의 예측차 : [9753.703]
# 1066번 데이터의 예측차 : [9866.291]
# 1067번 데이터의 예측차 : [9744.424]
# 1068번 데이터의 예측차 : [9649.305]
# 1069번 데이터의 예측차 : [9705.666]
# 1070번 데이터의 예측차 : [9508.92]
# 1071번 데이터의 예측차 : [9013.]
# 1072번 데이터의 예측차 : [8109.998]
# 1073번 데이터의 예측차 : [7644.8086]
# 1074번 데이터의 예측차 : [7108.578]
# 1075번 데이터의 예측차 : [6540.8887]
# 1076번 데이터의 예측차 : [5904.707]
# 1077번 데이터의 예측차 : [5583.0938]
# 1078번 데이터의 예측차 : [4686.4688]
# 1079번 데이터의 예측차 : [3677.2012]
# 1080번 데이터의 예측차 : [3647.7656]
# 1081번 데이터의 예측차 : [3737.6602]
# 1082번 데이터의 예측차 : [3035.6523]
# 1083번 데이터의 예측차 : [2956.1602]
# 1084번 데이터의 예측차 : [2785.8613]
# 1085번 데이터의 예측차 : [1731.1699]
# 1086번 데이터의 예측차 : [1632.3066]
# 1087번 데이터의 예측차 : [818.2031]
# 1088번 데이터의 예측차 : [118.82422]
# 1089번 데이터의 예측차 : [-174.22266]
# 1090번 데이터의 예측차 : [-742.83984]
# 1091번 데이터의 예측차 : [-924.39844]
# 1092번 데이터의 예측차 : [-1477.9141]
# 1093번 데이터의 예측차 : [-1509.4727]
# 1094번 데이터의 예측차 : [-1494.543]
# 1095번 데이터의 예측차 : [-1606.2422]
# 1096번 데이터의 예측차 : [-2137.2344]
# 1097번 데이터의 예측차 : [-2324.9922]
# 1098번 데이터의 예측차 : [-2384.1484]
# 1099번 데이터의 예측차 : [-2604.3672]
# 1100번 데이터의 예측차 : [-2861.4219]
# 1101번 데이터의 예측차 : [-2907.1523]
# 1102번 데이터의 예측차 : [-2780.168]
# 1103번 데이터의 예측차 : [-2749.2266]
# 1104번 데이터의 예측차 : [-2891.7695]
# 1105번 데이터의 예측차 : [-3140.6797]
# 1106번 데이터의 예측차 : [-3380.789]
# 1107번 데이터의 예측차 : [-3149.9805]
# 1108번 데이터의 예측차 : [-3112.543]
# 1109번 데이터의 예측차 : [-2890.4219]
# 1110번 데이터의 예측차 : [-2807.4531]
# 1111번 데이터의 예측차 : [-2804.0195]
# 1112번 데이터의 예측차 : [-2310.9102]
# 1113번 데이터의 예측차 : [-2273.75]
# 1114번 데이터의 예측차 : [-1952.8164]
# 1115번 데이터의 예측차 : [-1795.6523]
# 1116번 데이터의 예측차 : [-1483.6484]
# 1117번 데이터의 예측차 : [-1453.9805]
# 1118번 데이터의 예측차 : [-1211.5312]
# 1119번 데이터의 예측차 : [-831.8906]
# 1120번 데이터의 예측차 : [-378.96484]
# 1121번 데이터의 예측차 : [-323.4414]
# 1122번 데이터의 예측차 : [-69.02344]
# 1123번 데이터의 예측차 : [264.8203]
# 1124번 데이터의 예측차 : [357.66797]
# 1125번 데이터의 예측차 : [615.14453]
# 1126번 데이터의 예측차 : [640.4961]
# 1127번 데이터의 예측차 : [449.8828]
# 1128번 데이터의 예측차 : [835.9844]
# 1129번 데이터의 예측차 : [801.9336]
# 1130번 데이터의 예측차 : [1632.6641]
# 1131번 데이터의 예측차 : [2065.0938]
# 1132번 데이터의 예측차 : [2355.3047]
# 1133번 데이터의 예측차 : [2167.0312]
# 1134번 데이터의 예측차 : [2118.0273]
# 1135번 데이터의 예측차 : [1719.6719]
# 1136번 데이터의 예측차 : [1238.2969]
# 1137번 데이터의 예측차 : [718.0078]
# 1138번 데이터의 예측차 : [-789.60156]
# 1139번 데이터의 예측차 : [-1206.5938]
# 1140번 데이터의 예측차 : [-2291.871]
# 1141번 데이터의 예측차 : [-3233.5508]
# 1142번 데이터의 예측차 : [-4224.7812]
# 1143번 데이터의 예측차 : [-5254.8125]
# 1144번 데이터의 예측차 : [-5449.6133]
# 1145번 데이터의 예측차 : [-5914.4805]
# 1146번 데이터의 예측차 : [-5944.7656]
# 1147번 데이터의 예측차 : [-5443.629]
# 1148번 데이터의 예측차 : [-5551.578]
# 1149번 데이터의 예측차 : [-5758.6953]
# 1150번 데이터의 예측차 : [-6147.6562]
# 1151번 데이터의 예측차 : [-5813.5]
# 1152번 데이터의 예측차 : [-5093.0156]
# 1153번 데이터의 예측차 : [-4526.5664]
# 1154번 데이터의 예측차 : [-4020.164]
# 1155번 데이터의 예측차 : [-3881.6914]
# 1156번 데이터의 예측차 : [-3297.6602]
# 1157번 데이터의 예측차 : [-2462.7656]
# 1158번 데이터의 예측차 : [-2420.332]
# 1159번 데이터의 예측차 : [-1857.4375]
# 1160번 데이터의 예측차 : [-1180.1914]
# 1161번 데이터의 예측차 : [-137.26172]
# 1162번 데이터의 예측차 : [708.97266]
# 1163번 데이터의 예측차 : [1169.7461]
# 1164번 데이터의 예측차 : [1830.1289]
# 1165번 데이터의 예측차 : [2692.4336]
# 1166번 데이터의 예측차 : [3446.4727]
# 1167번 데이터의 예측차 : [4324.3867]
# 1168번 데이터의 예측차 : [4758.7188]
# 1169번 데이터의 예측차 : [5625.3906]
# 1170번 데이터의 예측차 : [6432.004]
# 1171번 데이터의 예측차 : [7009.508]
# 1172번 데이터의 예측차 : [7774.129]
# 1173번 데이터의 예측차 : [8277.275]
# 1174번 데이터의 예측차 : [8778.186]
# 1175번 데이터의 예측차 : [9184.506]
# 1176번 데이터의 예측차 : [9595.277]
# 1177번 데이터의 예측차 : [9954.281]
# 1178번 데이터의 예측차 : [10161.574]
# 1179번 데이터의 예측차 : [10347.787]
# 1180번 데이터의 예측차 : [10958.127]
# 1181번 데이터의 예측차 : [10677.818]
# 1182번 데이터의 예측차 : [10644.852]
# 1183번 데이터의 예측차 : [10849.965]
# 1184번 데이터의 예측차 : [11224.035]
# 1185번 데이터의 예측차 : [11471.777]
# 1186번 데이터의 예측차 : [11691.908]
# 1187번 데이터의 예측차 : [11750.652]
# 1188번 데이터의 예측차 : [12051.287]
# 1189번 데이터의 예측차 : [11820.104]
# 1190번 데이터의 예측차 : [11725.727]
# 1191번 데이터의 예측차 : [11837.068]
# 1192번 데이터의 예측차 : [11851.988]
# 1193번 데이터의 예측차 : [11819.105]
# 1194번 데이터의 예측차 : [11674.334]
# 1195번 데이터의 예측차 : [11838.342]
# 1196번 데이터의 예측차 : [11300.773]
# 1197번 데이터의 예측차 : [10503.453]
# 1198번 데이터의 예측차 : [9612.73]
# 1199번 데이터의 예측차 : [9816.357]
# 1200번 데이터의 예측차 : [10303.738]
# 1201번 데이터의 예측차 : [10562.193]
# 1202번 데이터의 예측차 : [11110.365]
# 1203번 데이터의 예측차 : [12066.225]
# 1204번 데이터의 예측차 : [13185.748]
# 1205번 데이터의 예측차 : [13939.74]
# 1206번 데이터의 예측차 : [14823.289]
# 1207번 데이터의 예측차 : [15352.42]
# 1208번 데이터의 예측차 : [14734.801]
# 1209번 데이터의 예측차 : [14426.3125]
# 1210번 데이터의 예측차 : [14314.566]
# 1211번 데이터의 예측차 : [13917.311]
# 1212번 데이터의 예측차 : [14026.355]
# 1213번 데이터의 예측차 : [14116.725]
# 1214번 데이터의 예측차 : [12199.107]
# 1215번 데이터의 예측차 : [11565.326]
# 1216번 데이터의 예측차 : [11344.832]
# 1217번 데이터의 예측차 : [11007.797]
# 1218번 데이터의 예측차 : [9554.]
# 1219번 데이터의 예측차 : [9305.76]
# 1220번 데이터의 예측차 : [7896.3477]
# 1221번 데이터의 예측차 : [7644.5664]
# 1222번 데이터의 예측차 : [8013.043]
# 1223번 데이터의 예측차 : [7165.7676]
# 1224번 데이터의 예측차 : [7267.049]
# 1225번 데이터의 예측차 : [6672.4414]
# 1226번 데이터의 예측차 : [6511.2793]
# 1227번 데이터의 예측차 : [5537.7285]
# 1228번 데이터의 예측차 : [5049.4688]
# 1229번 데이터의 예측차 : [4726.133]
# 1230번 데이터의 예측차 : [3976.4219]
# 1231번 데이터의 예측차 : [3672.9238]
# 1232번 데이터의 예측차 : [2824.1738]
# 1233번 데이터의 예측차 : [2209.4844]
# 1234번 데이터의 예측차 : [1744.3301]
# 1235번 데이터의 예측차 : [1558.7051]
# 1236번 데이터의 예측차 : [1416.7598]
# 1237번 데이터의 예측차 : [1238.5859]
# 1238번 데이터의 예측차 : [1439.6543]
# 1239번 데이터의 예측차 : [463.75]
# 1240번 데이터의 예측차 : [121.39844]
# 1241번 데이터의 예측차 : [-51.359375]
# 1242번 데이터의 예측차 : [-528.21875]
# 1243번 데이터의 예측차 : [-630.3281]
# 1244번 데이터의 예측차 : [-747.22266]
# 1245번 데이터의 예측차 : [-1094.3008]
# 1246번 데이터의 예측차 : [-1066.3242]
# 1247번 데이터의 예측차 : [-1233.1562]
# 1248번 데이터의 예측차 : [-1053.0039]
# 1249번 데이터의 예측차 : [-1626.3516]
# 1250번 데이터의 예측차 : [-1708.8047]
# 1251번 데이터의 예측차 : [-1708.2461]
# 1252번 데이터의 예측차 : [-1949.3574]
# 1253번 데이터의 예측차 : [-1430.168]
# 1254번 데이터의 예측차 : [-189.65234]
# 1255번 데이터의 예측차 : [-497.88672]
# 1256번 데이터의 예측차 : [-599.51953]
# 1257번 데이터의 예측차 : [-1083.6016]
# 1258번 데이터의 예측차 : [-448.2578]
# 1259번 데이터의 예측차 : [292.6797]
# 1260번 데이터의 예측차 : [-295.38672]
# 1261번 데이터의 예측차 : [413.51172]
# 1262번 데이터의 예측차 : [482.3203]
# 1263번 데이터의 예측차 : [1230.9922]
# 1264번 데이터의 예측차 : [1521.6836]
# 1265번 데이터의 예측차 : [818.2422]
# 1266번 데이터의 예측차 : [985.43945]
# 1267번 데이터의 예측차 : [1915.6367]
# 1268번 데이터의 예측차 : [2121.209]
# 1269번 데이터의 예측차 : [2973.2031]
# 1270번 데이터의 예측차 : [2077.205]
# 1271번 데이터의 예측차 : [2105.0352]
# 1272번 데이터의 예측차 : [2556.9863]
# 1273번 데이터의 예측차 : [2285.996]
# 1274번 데이터의 예측차 : [2568.9395]
# 1275번 데이터의 예측차 : [3371.4707]
# 1276번 데이터의 예측차 : [3841.3008]
# 1277번 데이터의 예측차 : [2714.205]
# 1278번 데이터의 예측차 : [2753.6113]
# 1279번 데이터의 예측차 : [2965.541]
# 1280번 데이터의 예측차 : [2293.7852]
# 1281번 데이터의 예측차 : [2326.6992]
# 1282번 데이터의 예측차 : [1336.4219]
# 1283번 데이터의 예측차 : [-356.29688]
# 1284번 데이터의 예측차 : [-1649.0664]
# 1285번 데이터의 예측차 : [-2563.586]
# 1286번 데이터의 예측차 : [-3777.3008]
# 1287번 데이터의 예측차 : [-4924.8984]
# 1288번 데이터의 예측차 : [-5857.617]
# 1289번 데이터의 예측차 : [-6363.965]
# 1290번 데이터의 예측차 : [-6461.082]
# 1291번 데이터의 예측차 : [-6685.793]
# 1292번 데이터의 예측차 : [-6903.16]
# 1293번 데이터의 예측차 : [-7240.5234]
# 1294번 데이터의 예측차 : [-7556.621]
# 1295번 데이터의 예측차 : [-7606.8125]
# 1296번 데이터의 예측차 : [-7774.25]
# 1297번 데이터의 예측차 : [-7952.8203]
# 1298번 데이터의 예측차 : [-8006.4062]
# 1299번 데이터의 예측차 : [-8015.422]
# 1300번 데이터의 예측차 : [-7754.035]
# 1301번 데이터의 예측차 : [-7540.3633]
# 1302번 데이터의 예측차 : [-6944.6445]
# 1303번 데이터의 예측차 : [-6542.8086]
# 1304번 데이터의 예측차 : [-5753.3516]
# 1305번 데이터의 예측차 : [-4996.004]
# 1306번 데이터의 예측차 : [-4330.082]
# 1307번 데이터의 예측차 : [-3410.7734]
# 1308번 데이터의 예측차 : [-2863.6172]
# 1309번 데이터의 예측차 : [-1997.0234]
# 1310번 데이터의 예측차 : [-1194.5859]
# 1311번 데이터의 예측차 : [-234.26562]
# 1312번 데이터의 예측차 : [381.54297]
# 1313번 데이터의 예측차 : [1191.0938]
# 1314번 데이터의 예측차 : [2032.6172]
# 1315번 데이터의 예측차 : [2822.1426]
# 1316번 데이터의 예측차 : [3231.7168]
# 1317번 데이터의 예측차 : [3981.4414]
# 1318번 데이터의 예측차 : [4903.873]
# 1319번 데이터의 예측차 : [5010.496]
# 1320번 데이터의 예측차 : [5091.379]
# 1321번 데이터의 예측차 : [5373.625]
# 1322번 데이터의 예측차 : [5615.133]
# 1323번 데이터의 예측차 : [6257.6465]
# 1324번 데이터의 예측차 : [6242.4844]
# 1325번 데이터의 예측차 : [6573.498]
# 1326번 데이터의 예측차 : [7001.9766]
# 1327번 데이터의 예측차 : [7178.8164]
# 1328번 데이터의 예측차 : [7342.0977]
# 1329번 데이터의 예측차 : [7164.1094]
# 1330번 데이터의 예측차 : [7240.3574]
# 1331번 데이터의 예측차 : [7245.0234]
# 1332번 데이터의 예측차 : [7370.199]
# 1333번 데이터의 예측차 : [7286.576]
# 1334번 데이터의 예측차 : [7523.162]
# 1335번 데이터의 예측차 : [7305.2793]
# 1336번 데이터의 예측차 : [7388.658]
# 1337번 데이터의 예측차 : [8157.5156]
# 1338번 데이터의 예측차 : [8900.066]
# 1339번 데이터의 예측차 : [9288.365]
# 1340번 데이터의 예측차 : [9819.615]
# 1341번 데이터의 예측차 : [9653.604]
# 1342번 데이터의 예측차 : [9005.314]
# 1343번 데이터의 예측차 : [9245.732]
# 1344번 데이터의 예측차 : [9810.154]
# 1345번 데이터의 예측차 : [9571.449]
# 1346번 데이터의 예측차 : [9579.717]
# 1347번 데이터의 예측차 : [10328.141]
# 1348번 데이터의 예측차 : [11375.162]
# 1349번 데이터의 예측차 : [11692.5]
# 1350번 데이터의 예측차 : [11851.703]
# 1351번 데이터의 예측차 : [11558.957]
# 1352번 데이터의 예측차 : [11500.82]
# 1353번 데이터의 예측차 : [11349.32]
# 1354번 데이터의 예측차 : [11149.59]
# 1355번 데이터의 예측차 : [11181.689]
# 1356번 데이터의 예측차 : [11060.01]
# 1357번 데이터의 예측차 : [10849.301]
# 1358번 데이터의 예측차 : [10520.805]
# 1359번 데이터의 예측차 : [9865.363]
# 1360번 데이터의 예측차 : [8590.832]
# 1361번 데이터의 예측차 : [7598.076]
# 1362번 데이터의 예측차 : [7166.211]
# 1363번 데이터의 예측차 : [6224.926]
# 1364번 데이터의 예측차 : [4013.7324]
# 1365번 데이터의 예측차 : [3754.4941]
# 1366번 데이터의 예측차 : [3580.5684]
# 1367번 데이터의 예측차 : [3893.4707]
# 1368번 데이터의 예측차 : [3889.127]
# 1369번 데이터의 예측차 : [2944.8906]
# 1370번 데이터의 예측차 : [2975.3672]
# 1371번 데이터의 예측차 : [2271.3223]
# 1372번 데이터의 예측차 : [1472.082]
# 1373번 데이터의 예측차 : [1159.1328]
# 1374번 데이터의 예측차 : [879.0508]
# 1375번 데이터의 예측차 : [288.0586]
# 1376번 데이터의 예측차 : [-986.7383]
# 1377번 데이터의 예측차 : [-1484.4062]
# 1378번 데이터의 예측차 : [-1462.8867]
# 1379번 데이터의 예측차 : [-718.5156]
# 1380번 데이터의 예측차 : [-1284.0508]
# 1381번 데이터의 예측차 : [-2284.0898]
# 1382번 데이터의 예측차 : [-1656.0781]
# 1383번 데이터의 예측차 : [-2276.0117]
# 1384번 데이터의 예측차 : [-2675.1797]
# 1385번 데이터의 예측차 : [-2497.2852]
# 1386번 데이터의 예측차 : [-3138.7969]
# 1387번 데이터의 예측차 : [-3805.9414]
# 1388번 데이터의 예측차 : [-3500.3203]
# 1389번 데이터의 예측차 : [-4130.3516]
# 1390번 데이터의 예측차 : [-4040.6914]
# 1391번 데이터의 예측차 : [-4458.162]
# 1392번 데이터의 예측차 : [-4119.414]
# 1393번 데이터의 예측차 : [-5054.7363]
# 1394번 데이터의 예측차 : [-5055.84]
# 1395번 데이터의 예측차 : [-4833.3203]
# 1396번 데이터의 예측차 : [-5040.949]
# 1397번 데이터의 예측차 : [-4955.0645]
# 1398번 데이터의 예측차 : [-4300.8203]
# 1399번 데이터의 예측차 : [-3601.9238]
# 1400번 데이터의 예측차 : [-3357.7422]
# 1401번 데이터의 예측차 : [-3320.8828]
# 1402번 데이터의 예측차 : [-3722.0938]
# 1403번 데이터의 예측차 : [-3256.875]
# 1404번 데이터의 예측차 : [-2996.5977]
# 1405번 데이터의 예측차 : [-2617.8672]
# 1406번 데이터의 예측차 : [-2244.914]
# 1407번 데이터의 예측차 : [-2249.4688]
# 1408번 데이터의 예측차 : [-2090.3867]
# 1409번 데이터의 예측차 : [-1621.8594]
# 1410번 데이터의 예측차 : [-1200.7969]
# 1411번 데이터의 예측차 : [-606.54297]
# 1412번 데이터의 예측차 : [-354.5625]
# 1413번 데이터의 예측차 : [-311.44922]
# 1414번 데이터의 예측차 : [-338.8672]
# 1415번 데이터의 예측차 : [-158.98828]
# 1416번 데이터의 예측차 : [-139.59766]
# 1417번 데이터의 예측차 : [31.8125]
# 1418번 데이터의 예측차 : [244.30469]
# 1419번 데이터의 예측차 : [273.3828]
# 1420번 데이터의 예측차 : [237.19922]
# 1421번 데이터의 예측차 : [316.27344]
# 1422번 데이터의 예측차 : [461.15234]
# 1423번 데이터의 예측차 : [819.3203]
# 1424번 데이터의 예측차 : [769.0078]
# 1425번 데이터의 예측차 : [-909.66406]
# 1426번 데이터의 예측차 : [-2716.3672]
# 1427번 데이터의 예측차 : [-5772.496]
# 1428번 데이터의 예측차 : [-7025.5664]
# 1429번 데이터의 예측차 : [-5435.7383]
# 1430번 데이터의 예측차 : [-5627.91]
# 1431번 데이터의 예측차 : [-6515.449]
# 1432번 데이터의 예측차 : [-6741.4883]
# 1433번 데이터의 예측차 : [-7246.6016]
# 1434번 데이터의 예측차 : [-7300.9766]
# 1435번 데이터의 예측차 : [-7152.211]
# 1436번 데이터의 예측차 : [-7367.0664]
# 1437번 데이터의 예측차 : [-7301.547]
# 1438번 데이터의 예측차 : [-6938.8047]
# 1439번 데이터의 예측차 : [-6983.035]
# 1440번 데이터의 예측차 : [-6917.551]
# 1441번 데이터의 예측차 : [-6379.5547]
# 1442번 데이터의 예측차 : [-5870.297]
# 1443번 데이터의 예측차 : [-5501.164]
# 1444번 데이터의 예측차 : [-5072.715]
# 1445번 데이터의 예측차 : [-4636.4727]
# 1446번 데이터의 예측차 : [-4168.699]
# 1447번 데이터의 예측차 : [-3383.9648]
# 1448번 데이터의 예측차 : [-2545.9414]
# 1449번 데이터의 예측차 : [-1857.957]
# 1450번 데이터의 예측차 : [-1192.9141]
# 1451번 데이터의 예측차 : [-253.42578]
# 1452번 데이터의 예측차 : [900.4961]
# 1453번 데이터의 예측차 : [1828.4023]
# 1454번 데이터의 예측차 : [2299.5273]
# 1455번 데이터의 예측차 : [3226.664]
# 1456번 데이터의 예측차 : [4185.703]
# 1457번 데이터의 예측차 : [4010.4688]
# 1458번 데이터의 예측차 : [4705.1094]
# 1459번 데이터의 예측차 : [5424.0605]
# 1460번 데이터의 예측차 : [6439.504]
# 1461번 데이터의 예측차 : [6962.5293]
# 1462번 데이터의 예측차 : [7617.6074]
# 1463번 데이터의 예측차 : [8099.049]
# 1464번 데이터의 예측차 : [8452.4375]
# 1465번 데이터의 예측차 : [8868.723]
# 1466번 데이터의 예측차 : [9125.947]
# 1467번 데이터의 예측차 : [9396.961]
# 1468번 데이터의 예측차 : [9535.043]
# 1469번 데이터의 예측차 : [10029.037]
# 1470번 데이터의 예측차 : [10206.787]
# 1471번 데이터의 예측차 : [10546.227]
# 1472번 데이터의 예측차 : [10707.865]
# 1473번 데이터의 예측차 : [10968.561]
# 1474번 데이터의 예측차 : [10972.33]
# 1475번 데이터의 예측차 : [11103.072]
# 1476번 데이터의 예측차 : [11458.539]
# 1477번 데이터의 예측차 : [11431.566]
# 1478번 데이터의 예측차 : [11265.91]
# 1479번 데이터의 예측차 : [11388.832]
# 1480번 데이터의 예측차 : [11430.357]
# 1481번 데이터의 예측차 : [11487.514]
# 1482번 데이터의 예측차 : [11308.645]
# 1483번 데이터의 예측차 : [10877.877]
# 1484번 데이터의 예측차 : [10854.557]
# 1485번 데이터의 예측차 : [10358.721]
# 1486번 데이터의 예측차 : [9728.783]
# 1487번 데이터의 예측차 : [9733.586]
# 1488번 데이터의 예측차 : [10419.174]
# 1489번 데이터의 예측차 : [10256.818]
# 1490번 데이터의 예측차 : [10563.748]
# 1491번 데이터의 예측차 : [11499.541]
# 1492번 데이터의 예측차 : [12524.002]
# 1493번 데이터의 예측차 : [12551.971]
# 1494번 데이터의 예측차 : [12424.336]
# 1495번 데이터의 예측차 : [12725.973]
# 1496번 데이터의 예측차 : [12447.256]
# 1497번 데이터의 예측차 : [12366.529]
# 1498번 데이터의 예측차 : [12170.414]
# 1499번 데이터의 예측차 : [12099.686]
# 1500번 데이터의 예측차 : [11746.309]
# 1501번 데이터의 예측차 : [10909.143]
# 1502번 데이터의 예측차 : [9730.355]
# 1503번 데이터의 예측차 : [8868.662]
# 1504번 데이터의 예측차 : [8272.799]
# 1505번 데이터의 예측차 : [6618.4336]
# 1506번 데이터의 예측차 : [6385.2637]
# 1507번 데이터의 예측차 : [5060.3945]
# 1508번 데이터의 예측차 : [3277.8945]
# 1509번 데이터의 예측차 : [3662.9746]
# 1510번 데이터의 예측차 : [2781.4512]
# 1511번 데이터의 예측차 : [2807.5156]
# 1512번 데이터의 예측차 : [2197.6172]
# 1513번 데이터의 예측차 : [1679.2109]
# 1514번 데이터의 예측차 : [1478.5977]
# 1515번 데이터의 예측차 : [90.12109]
# 1516번 데이터의 예측차 : [-512.28516]
# 1517번 데이터의 예측차 : [-972.08594]
# 1518번 데이터의 예측차 : [-1371.5469]
# 1519번 데이터의 예측차 : [-1621.3594]
# 1520번 데이터의 예측차 : [-2519.8555]
# 1521번 데이터의 예측차 : [-2813.3984]
# 1522번 데이터의 예측차 : [-3431.0703]
# 1523번 데이터의 예측차 : [-3901.039]
# 1524번 데이터의 예측차 : [-3774.5273]
# 1525번 데이터의 예측차 : [-4185.871]
# 1526번 데이터의 예측차 : [-4519.996]
# 1527번 데이터의 예측차 : [-4925.461]
# 1528번 데이터의 예측차 : [-5192.758]
# 1529번 데이터의 예측차 : [-5222.754]
# 1530번 데이터의 예측차 : [-5477.832]
# 1531번 데이터의 예측차 : [-5491.4727]
# 1532번 데이터의 예측차 : [-5690.8047]
# 1533번 데이터의 예측차 : [-6090.1914]
# 1534번 데이터의 예측차 : [-5900.246]
# 1535번 데이터의 예측차 : [-5859.0996]
# 1536번 데이터의 예측차 : [-5870.4453]
# 1537번 데이터의 예측차 : [-5859.0684]
# 1538번 데이터의 예측차 : [-5483.7617]
# 1539번 데이터의 예측차 : [-5568.117]
# 1540번 데이터의 예측차 : [-5434.994]
# 1541번 데이터의 예측차 : [-5479.578]
# 1542번 데이터의 예측차 : [-5561.422]
# 1543번 데이터의 예측차 : [-5670.6465]
# 1544번 데이터의 예측차 : [-5643.008]
# 1545번 데이터의 예측차 : [-5120.7227]
# 1546번 데이터의 예측차 : [-5083.5117]
# 1547번 데이터의 예측차 : [-4802.9688]
# 1548번 데이터의 예측차 : [-5005.7773]
# 1549번 데이터의 예측차 : [-4534.879]
# 1550번 데이터의 예측차 : [-4920.326]
# 1551번 데이터의 예측차 : [-4964.7227]
# 1552번 데이터의 예측차 : [-4303.84]
# 1553번 데이터의 예측차 : [-3534.0312]
# 1554번 데이터의 예측차 : [-3180.4023]
# 1555번 데이터의 예측차 : [-2669.5234]
# 1556번 데이터의 예측차 : [-2400.4375]
# 1557번 데이터의 예측차 : [-2534.3008]
# 1558번 데이터의 예측차 : [-2129.086]
# 1559번 데이터의 예측차 : [-2036.2695]
# 1560번 데이터의 예측차 : [-2209.0469]
# 1561번 데이터의 예측차 : [-1907.5938]
# 1562번 데이터의 예측차 : [-1859.0312]
# 1563번 데이터의 예측차 : [-1721.6875]
# 1564번 데이터의 예측차 : [-1645.0898]
# 1565번 데이터의 예측차 : [-1830.7305]
# 1566번 데이터의 예측차 : [-1976.4727]
# 1567번 데이터의 예측차 : [-2003.5625]
# 1568번 데이터의 예측차 : [-2206.1758]
# 1569번 데이터의 예측차 : [-2616.3281]
# 1570번 데이터의 예측차 : [-3621.914]
# 1571번 데이터의 예측차 : [-7913.215]
# 1572번 데이터의 예측차 : [-9545.574]
# 1573번 데이터의 예측차 : [-6220.1406]
# 1574번 데이터의 예측차 : [-6789.7656]
# 1575번 데이터의 예측차 : [-8095.199]
# 1576번 데이터의 예측차 : [-8311.828]
# 1577번 데이터의 예측차 : [-8745.934]
# 1578번 데이터의 예측차 : [-8851.094]
# 1579번 데이터의 예측차 : [-8708.363]
# 1580번 데이터의 예측차 : [-9055.168]
# 1581번 데이터의 예측차 : [-8943.117]
# 1582번 데이터의 예측차 : [-8733.84]
# 1583번 데이터의 예측차 : [-8717.602]
# 1584번 데이터의 예측차 : [-8374.102]
# 1585번 데이터의 예측차 : [-7633.453]
# 1586번 데이터의 예측차 : [-7559.2617]
# 1587번 데이터의 예측차 : [-7407.672]
# 1588번 데이터의 예측차 : [-6863.6445]
# 1589번 데이터의 예측차 : [-6009.3906]
# 1590번 데이터의 예측차 : [-5625.004]
# 1591번 데이터의 예측차 : [-5346.6523]
# 1592번 데이터의 예측차 : [-4281.289]
# 1593번 데이터의 예측차 : [-3584.3516]
# 1594번 데이터의 예측차 : [-2764.1016]
# 1595번 데이터의 예측차 : [-1929.5977]
# 1596번 데이터의 예측차 : [-801.66797]
# 1597번 데이터의 예측차 : [244.44922]
# 1598번 데이터의 예측차 : [1126.6172]
# 1599번 데이터의 예측차 : [1912.1523]
# 1600번 데이터의 예측차 : [2741.6055]
# 1601번 데이터의 예측차 : [3416.7578]
# 1602번 데이터의 예측차 : [4279.6797]
# 1603번 데이터의 예측차 : [4902.715]
# 1604번 데이터의 예측차 : [5680.3223]
# 1605번 데이터의 예측차 : [6149.4766]
# 1606번 데이터의 예측차 : [6823.883]
# 1607번 데이터의 예측차 : [7507.621]
# 1608번 데이터의 예측차 : [7811.41]
# 1609번 데이터의 예측차 : [7973.242]
# 1610번 데이터의 예측차 : [8595.17]
# 1611번 데이터의 예측차 : [9393.91]
# 1612번 데이터의 예측차 : [9382.643]
# 1613번 데이터의 예측차 : [9803.994]
# 1614번 데이터의 예측차 : [9591.422]
# 1615번 데이터의 예측차 : [9915.363]
# 1616번 데이터의 예측차 : [10253.701]
# 1617번 데이터의 예측차 : [10342.047]
# 1618번 데이터의 예측차 : [10529.682]
# 1619번 데이터의 예측차 : [10688.195]
# 1620번 데이터의 예측차 : [10775.584]
# 1621번 데이터의 예측차 : [10664.109]
# 1622번 데이터의 예측차 : [10739.193]
# 1623번 데이터의 예측차 : [10898.789]
# 1624번 데이터의 예측차 : [10677.951]
# 1625번 데이터의 예측차 : [10501.732]
# 1626번 데이터의 예측차 : [10686.934]
# 1627번 데이터의 예측차 : [10713.094]
# 1628번 데이터의 예측차 : [10783.965]
# 1629번 데이터의 예측차 : [10759.078]
# 1630번 데이터의 예측차 : [10230.799]
# 1631번 데이터의 예측차 : [10278.277]
# 1632번 데이터의 예측차 : [10478.174]
# 1633번 데이터의 예측차 : [10597.58]
# 1634번 데이터의 예측차 : [10518.848]
# 1635번 데이터의 예측차 : [10880.305]
# 1636번 데이터의 예측차 : [12221.709]
# 1637번 데이터의 예측차 : [13163.455]
# 1638번 데이터의 예측차 : [13378.656]
# 1639번 데이터의 예측차 : [12680.508]
# 1640번 데이터의 예측차 : [12099.375]
# 1641번 데이터의 예측차 : [12121.58]
# 1642번 데이터의 예측차 : [12072.715]
# 1643번 데이터의 예측차 : [12058.436]
# 1644번 데이터의 예측차 : [12408.926]
# 1645번 데이터의 예측차 : [11842.191]
# 1646번 데이터의 예측차 : [9843.035]
# 1647번 데이터의 예측차 : [9503.377]
# 1648번 데이터의 예측차 : [9609.775]
# 1649번 데이터의 예측차 : [8861.148]
# 1650번 데이터의 예측차 : [7236.4414]
# 1651번 데이터의 예측차 : [4376.328]
# 1652번 데이터의 예측차 : [3593.2637]
# 1653번 데이터의 예측차 : [3278.9043]
# 1654번 데이터의 예측차 : [2661.539]
# 1655번 데이터의 예측차 : [2116.42]
# 1656번 데이터의 예측차 : [1688.0254]
# 1657번 데이터의 예측차 : [1161.875]
# 1658번 데이터의 예측차 : [745.5156]
# 1659번 데이터의 예측차 : [-342.11328]
# 1660번 데이터의 예측차 : [-1131.625]
# 1661번 데이터의 예측차 : [-1110.2539]
# 1662번 데이터의 예측차 : [-1928.8594]
# 1663번 데이터의 예측차 : [-2613.7852]
# 1664번 데이터의 예측차 : [-3404.1836]
# 1665번 데이터의 예측차 : [-4089.3828]
# 1666번 데이터의 예측차 : [-4145.258]
# 1667번 데이터의 예측차 : [-4123.2695]
# 1668번 데이터의 예측차 : [-4655.5156]
# 1669번 데이터의 예측차 : [-4816.121]
# 1670번 데이터의 예측차 : [-5037.082]
# 1671번 데이터의 예측차 : [-5863.043]
# 1672번 데이터의 예측차 : [-5888.7773]
# 1673번 데이터의 예측차 : [-5590.6797]
# 1674번 데이터의 예측차 : [-6557.584]
# 1675번 데이터의 예측차 : [-6781.1523]
# 1676번 데이터의 예측차 : [-6559.]
# 1677번 데이터의 예측차 : [-6777.922]
# 1678번 데이터의 예측차 : [-6533.6836]
# 1679번 데이터의 예측차 : [-6098.1406]
# 1680번 데이터의 예측차 : [-5908.8594]
# 1681번 데이터의 예측차 : [-5776.8125]
# 1682번 데이터의 예측차 : [-5772.2773]
# 1683번 데이터의 예측차 : [-5366.4688]
# 1684번 데이터의 예측차 : [-5245.3555]
# 1685번 데이터의 예측차 : [-4749.9375]
# 1686번 데이터의 예측차 : [-5489.664]
# 1687번 데이터의 예측차 : [-5265.5938]
# 1688번 데이터의 예측차 : [-5542.5586]
# 1689번 데이터의 예측차 : [-4972.4453]
# 1690번 데이터의 예측차 : [-5085.957]
# 1691번 데이터의 예측차 : [-5635.7344]
# 1692번 데이터의 예측차 : [-5165.664]
# ...
# 16766번 데이터의 예측차 : [10364.145]
# 16767번 데이터의 예측차 : [9875.613]
# 16768번 데이터의 예측차 : [10188.613]
# 16769번 데이터의 예측차 : [10528.461]
# 16770번 데이터의 예측차 : [10684.287]
# 16771번 데이터의 예측차 : [8237.074]
# 16772번 데이터의 예측차 : [7562.709]
# 16773번 데이터의 예측차 : [7682.6426]
# 16774번 데이터의 예측차 : [7485.619]
# 16775번 데이터의 예측차 : [6785.2773]
# 16776번 데이터의 예측차 : [3747.1562]
# 16777번 데이터의 예측차 : [2940.2832]
# 16778번 데이터의 예측차 : [2632.2285]
# 16779번 데이터의 예측차 : [2530.166]
# 16780번 데이터의 예측차 : [2000.791]
# 16781번 데이터의 예측차 : [1801.248]
# 16782번 데이터의 예측차 : [1840.041]
# 16783번 데이터의 예측차 : [1808.3379]
# 16784번 데이터의 예측차 : [1130.375]
# 16785번 데이터의 예측차 : [209.875]
# 16786번 데이터의 예측차 : [-125.359375]
# 16787번 데이터의 예측차 : [-555.02734]
# 16788번 데이터의 예측차 : [-1512.002]
# 16789번 데이터의 예측차 : [-1512.3301]
# 16790번 데이터의 예측차 : [-2303.1035]
# 16791번 데이터의 예측차 : [-2713.879]
# 16792번 데이터의 예측차 : [-2903.4883]
# 16793번 데이터의 예측차 : [-3448.418]
# 16794번 데이터의 예측차 : [-3423.418]
# 16795번 데이터의 예측차 : [-2936.748]
# 16796번 데이터의 예측차 : [-2461.5352]
# 16797번 데이터의 예측차 : [-2687.8887]
# 16798번 데이터의 예측차 : [-2785.8613]
# 16799번 데이터의 예측차 : [-2371.6035]
# 16800번 데이터의 예측차 : [-2442.3125]
# 16801번 데이터의 예측차 : [-2354.5977]
# 16802번 데이터의 예측차 : [-1889.9922]
# 16803번 데이터의 예측차 : [-1879.752]
# 16804번 데이터의 예측차 : [-1728.9141]
# 16805번 데이터의 예측차 : [-2271.0527]
# 16806번 데이터의 예측차 : [-2051.5898]
# 16807번 데이터의 예측차 : [-2370.5117]
# 16808번 데이터의 예측차 : [-2209.7031]
# 16809번 데이터의 예측차 : [-1869.5156]
# 16810번 데이터의 예측차 : [-1529.2246]
# 16811번 데이터의 예측차 : [-1674.3516]
# 16812번 데이터의 예측차 : [-1125.7949]
# 16813번 데이터의 예측차 : [-778.6289]
# 16814번 데이터의 예측차 : [1441.0938]
# 16815번 데이터의 예측차 : [-672.87695]
# 16816번 데이터의 예측차 : [3411.6172]
# 16817번 데이터의 예측차 : [4481.922]
# 16818번 데이터의 예측차 : [5020.0176]
# 16819번 데이터의 예측차 : [4674.0566]
# 16820번 데이터의 예측차 : [4101.9062]
# 16821번 데이터의 예측차 : [4247.424]
# 16822번 데이터의 예측차 : [4340.6465]
# 16823번 데이터의 예측차 : [4268.498]
# 16824번 데이터의 예측차 : [3896.4531]
# 16825번 데이터의 예측차 : [3502.4648]
# 16826번 데이터의 예측차 : [2192.1992]
# 16827번 데이터의 예측차 : [19.871094]
# 16828번 데이터의 예측차 : [-3600.6758]
# 16829번 데이터의 예측차 : [-5359.0156]
# 16830번 데이터의 예측차 : [-5973.035]
# 16831번 데이터의 예측차 : [-6065.3477]
# 16832번 데이터의 예측차 : [-6178.5547]
# 16833번 데이터의 예측차 : [-6744.707]
# 16834번 데이터의 예측차 : [-7048.6016]
# 16835번 데이터의 예측차 : [-6826.789]
# 16836번 데이터의 예측차 : [-6196.8633]
# 16837번 데이터의 예측차 : [-6355.2188]
# 16838번 데이터의 예측차 : [-5795.5977]
# 16839번 데이터의 예측차 : [-5828.1484]
# 16840번 데이터의 예측차 : [-5847.4766]
# 16841번 데이터의 예측차 : [-5784.832]
# 16842번 데이터의 예측차 : [-5727.9023]
# 16843번 데이터의 예측차 : [-5594.1094]
# 16844번 데이터의 예측차 : [-5456.918]
# 16845번 데이터의 예측차 : [-5215.3906]
# 16846번 데이터의 예측차 : [-5093.953]
# 16847번 데이터의 예측차 : [-5123.0234]
# 16848번 데이터의 예측차 : [-4798.25]
# 16849번 데이터의 예측차 : [-4659.703]
# 16850번 데이터의 예측차 : [-4414.836]
# 16851번 데이터의 예측차 : [-4159.4062]
# 16852번 데이터의 예측차 : [-4154.7773]
# 16853번 데이터의 예측차 : [-3960.2227]
# 16854번 데이터의 예측차 : [-3882.7559]
# 16855번 데이터의 예측차 : [-3252.9258]
# 16856번 데이터의 예측차 : [-2018.3008]
# 16857번 데이터의 예측차 : [-785.8633]
# 16858번 데이터의 예측차 : [-447.29688]
# 16859번 데이터의 예측차 : [247.15625]
# 16860번 데이터의 예측차 : [1699.707]
# 16861번 데이터의 예측차 : [3261.6309]
# 16862번 데이터의 예측차 : [3861.6367]
# 16863번 데이터의 예측차 : [4989.3125]
# 16864번 데이터의 예측차 : [5656.965]
# 16865번 데이터의 예측차 : [5914.2207]
# 16866번 데이터의 예측차 : [7014.256]
# 16867번 데이터의 예측차 : [7181.461]
# 16868번 데이터의 예측차 : [7145.2656]
# 16869번 데이터의 예측차 : [7634.0938]
# 16870번 데이터의 예측차 : [8265.225]
# 16871번 데이터의 예측차 : [8589.783]
# 16872번 데이터의 예측차 : [9086.445]
# 16873번 데이터의 예측차 : [8606.713]
# 16874번 데이터의 예측차 : [8025.5293]
# 16875번 데이터의 예측차 : [7769.463]
# 16876번 데이터의 예측차 : [8100.213]
# 16877번 데이터의 예측차 : [8114.084]
# 16878번 데이터의 예측차 : [6925.176]
# 16879번 데이터의 예측차 : [6315.666]
# 16880번 데이터의 예측차 : [6745.967]
# 16881번 데이터의 예측차 : [7216.496]
# 16882번 데이터의 예측차 : [7661.8906]
# 16883번 데이터의 예측차 : [7801.627]
# 16884번 데이터의 예측차 : [7770.8867]
# 16885번 데이터의 예측차 : [7992.869]
# 16886번 데이터의 예측차 : [8074.752]
# 16887번 데이터의 예측차 : [8070.4824]
# 16888번 데이터의 예측차 : [8096.1094]
# 16889번 데이터의 예측차 : [8467.166]
# 16890번 데이터의 예측차 : [8531.926]
# 16891번 데이터의 예측차 : [8564.83]
# 16892번 데이터의 예측차 : [8591.002]
# 16893번 데이터의 예측차 : [8439.674]
# 16894번 데이터의 예측차 : [8582.17]
# 16895번 데이터의 예측차 : [8282.73]
# 16896번 데이터의 예측차 : [8209.486]
# 16897번 데이터의 예측차 : [7932.9766]
# 16898번 데이터의 예측차 : [8140.42]
# 16899번 데이터의 예측차 : [7838.3555]
# 16900번 데이터의 예측차 : [7647.254]
# 16901번 데이터의 예측차 : [7631.67]
# 16902번 데이터의 예측차 : [6892.9863]
# 16903번 데이터의 예측차 : [6178.7695]
# 16904번 데이터의 예측차 : [6181.621]
# 16905번 데이터의 예측차 : [5757.9727]
# 16906번 데이터의 예측차 : [5509.545]
# 16907번 데이터의 예측차 : [5540.912]
# 16908번 데이터의 예측차 : [5938.1406]
# 16909번 데이터의 예측차 : [6553.0566]
# 16910번 데이터의 예측차 : [6911.91]
# 16911번 데이터의 예측차 : [6673.455]
# 16912번 데이터의 예측차 : [7234.6094]
# 16913번 데이터의 예측차 : [7707.035]
# 16914번 데이터의 예측차 : [7822.2227]
# 16915번 데이터의 예측차 : [7021.3633]
# 16916번 데이터의 예측차 : [6412.783]
# 16917번 데이터의 예측차 : [6260.6855]
# 16918번 데이터의 예측차 : [5919.2617]
# 16919번 데이터의 예측차 : [4842.8457]
# 16920번 데이터의 예측차 : [2651.3008]
# 16921번 데이터의 예측차 : [1195.0605]
# 16922번 데이터의 예측차 : [1698.7148]
# 16923번 데이터의 예측차 : [1651.4629]
# 16924번 데이터의 예측차 : [2051.088]
# 16925번 데이터의 예측차 : [1831.0527]
# 16926번 데이터의 예측차 : [1508.125]
# 16927번 데이터의 예측차 : [1255.6016]
# 16928번 데이터의 예측차 : [927.70703]
# 16929번 데이터의 예측차 : [715.3594]
# 16930번 데이터의 예측차 : [277.27344]
# 16931번 데이터의 예측차 : [-378.5996]
# 16932번 데이터의 예측차 : [-641.6387]
# 16933번 데이터의 예측차 : [-934.83203]
# 16934번 데이터의 예측차 : [-1215.7871]
# 16935번 데이터의 예측차 : [-1281.0898]
# 16936번 데이터의 예측차 : [-2146.7363]
# 16937번 데이터의 예측차 : [-2283.75]
# 16938번 데이터의 예측차 : [-2255.5938]
# 16939번 데이터의 예측차 : [-2318.0996]
# 16940번 데이터의 예측차 : [-2695.1035]
# 16941번 데이터의 예측차 : [-2969.039]
# 16942번 데이터의 예측차 : [-3390.7969]
# 16943번 데이터의 예측차 : [-3058.8848]
# 16944번 데이터의 예측차 : [-3181.2852]
# 16945번 데이터의 예측차 : [-2461.838]
# 16946번 데이터의 예측차 : [-2302.461]
# 16947번 데이터의 예측차 : [-2478.0742]
# 16948번 데이터의 예측차 : [-1795.082]
# 16949번 데이터의 예측차 : [-965.8457]
# 16950번 데이터의 예측차 : [-1082.7129]
# 16951번 데이터의 예측차 : [-1176.375]
# 16952번 데이터의 예측차 : [-1702.7852]
# 16953번 데이터의 예측차 : [-1670.5684]
# 16954번 데이터의 예측차 : [-1480.5547]
# 16955번 데이터의 예측차 : [-1680.7559]
# 16956번 데이터의 예측차 : [-1535.5293]
# 16957번 데이터의 예측차 : [-1746.1328]
# 16958번 데이터의 예측차 : [-1451.6504]
# 16959번 데이터의 예측차 : [-1203.7344]
# 16960번 데이터의 예측차 : [-1083.8535]
# 16961번 데이터의 예측차 : [-719.4219]
# 16962번 데이터의 예측차 : [-566.625]
# 16963번 데이터의 예측차 : [-713.61914]
# 16964번 데이터의 예측차 : [-1172.9512]
# 16965번 데이터의 예측차 : [-1309.0352]
# 16966번 데이터의 예측차 : [-1792.9629]
# 16967번 데이터의 예측차 : [-634.084]
# 16968번 데이터의 예측차 : [-1350.2422]
# 16969번 데이터의 예측차 : [-1763.5156]
# 16970번 데이터의 예측차 : [-1145.3984]
# 16971번 데이터의 예측차 : [-2000.3281]
# 16972번 데이터의 예측차 : [-4051.0898]
# 16973번 데이터의 예측차 : [-6846.0938]
# 16974번 데이터의 예측차 : [-7975.449]
# 16975번 데이터의 예측차 : [-8468.918]
# 16976번 데이터의 예측차 : [-8856.723]
# 16977번 데이터의 예측차 : [-9480.387]
# 16978번 데이터의 예측차 : [-9445.]
# 16979번 데이터의 예측차 : [-9487.145]
# 16980번 데이터의 예측차 : [-9582.906]
# 16981번 데이터의 예측차 : [-9489.395]
# 16982번 데이터의 예측차 : [-10172.234]
# 16983번 데이터의 예측차 : [-8667.76]
# 16984번 데이터의 예측차 : [-6787.7207]
# 16985번 데이터의 예측차 : [-6552.5176]
# 16986번 데이터의 예측차 : [-6180.5117]
# 16987번 데이터의 예측차 : [-6355.9883]
# 16988번 데이터의 예측차 : [-6767.242]
# 16989번 데이터의 예측차 : [-6550.742]
# 16990번 데이터의 예측차 : [-6854.0195]
# 16991번 데이터의 예측차 : [-6403.664]
# 16992번 데이터의 예측차 : [-6229.793]
# 16993번 데이터의 예측차 : [-6219.371]
# 16994번 데이터의 예측차 : [-6029.4023]
# 16995번 데이터의 예측차 : [-5378.992]
# 16996번 데이터의 예측차 : [-4818.453]
# 16997번 데이터의 예측차 : [-4126.3086]
# 16998번 데이터의 예측차 : [-3952.293]
# 16999번 데이터의 예측차 : [-3290.8086]
# 17000번 데이터의 예측차 : [-3006.6094]
# 17001번 데이터의 예측차 : [-2266.5234]
# 17002번 데이터의 예측차 : [-1406.957]
# 17003번 데이터의 예측차 : [-855.0508]
# 17004번 데이터의 예측차 : [-133.03516]
# 17005번 데이터의 예측차 : [1060.0078]
# 17006번 데이터의 예측차 : [1927.0938]
# 17007번 데이터의 예측차 : [2958.838]
# 17008번 데이터의 예측차 : [3539.3828]
# 17009번 데이터의 예측차 : [4105.959]
# 17010번 데이터의 예측차 : [5038.992]
# 17011번 데이터의 예측차 : [5940.5215]
# 17012번 데이터의 예측차 : [6120.301]
# 17013번 데이터의 예측차 : [6925.4414]
# 17014번 데이터의 예측차 : [7289.203]
# 17015번 데이터의 예측차 : [7687.4785]
# 17016번 데이터의 예측차 : [8387.369]
# 17017번 데이터의 예측차 : [8678.619]
# 17018번 데이터의 예측차 : [9313.33]
# 17019번 데이터의 예측차 : [9478.602]
# 17020번 데이터의 예측차 : [9712.154]
# 17021번 데이터의 예측차 : [10184.01]
# 17022번 데이터의 예측차 : [10814.273]
# 17023번 데이터의 예측차 : [11201.555]
# 17024번 데이터의 예측차 : [11050.014]
# 17025번 데이터의 예측차 : [11235.414]
# 17026번 데이터의 예측차 : [11467.936]
# 17027번 데이터의 예측차 : [11710.744]
# 17028번 데이터의 예측차 : [11680.352]
# 17029번 데이터의 예측차 : [11918.225]
# 17030번 데이터의 예측차 : [11967.693]
# 17031번 데이터의 예측차 : [12008.865]
# 17032번 데이터의 예측차 : [11813.1]
# 17033번 데이터의 예측차 : [11676.463]
# 17034번 데이터의 예측차 : [11687.9375]
# 17035번 데이터의 예측차 : [12184.158]
# 17036번 데이터의 예측차 : [12145.115]
# 17037번 데이터의 예측차 : [12401.8125]
# 17038번 데이터의 예측차 : [12290.734]
# 17039번 데이터의 예측차 : [11995.334]
# 17040번 데이터의 예측차 : [12056.033]
# 17041번 데이터의 예측차 : [11857.773]
# 17042번 데이터의 예측차 : [11434.391]
# 17043번 데이터의 예측차 : [11254.07]
# 17044번 데이터의 예측차 : [10971.664]
# 17045번 데이터의 예측차 : [10432.145]
# 17046번 데이터의 예측차 : [9519.857]
# 17047번 데이터의 예측차 : [9108.947]
# 17048번 데이터의 예측차 : [9186.3125]
# 17049번 데이터의 예측차 : [8814.244]
# 17050번 데이터의 예측차 : [8701.463]
# 17051번 데이터의 예측차 : [8681.328]
# 17052번 데이터의 예측차 : [8584.447]
# 17053번 데이터의 예측차 : [8667.248]
# 17054번 데이터의 예측차 : [8651.285]
# 17055번 데이터의 예측차 : [8548.332]
# 17056번 데이터의 예측차 : [9201.539]
# 17057번 데이터의 예측차 : [9449.227]
# 17058번 데이터의 예측차 : [9663.604]
# 17059번 데이터의 예측차 : [9451.396]
# 17060번 데이터의 예측차 : [9047.426]
# 17061번 데이터의 예측차 : [8849.424]
# 17062번 데이터의 예측차 : [8757.164]
# 17063번 데이터의 예측차 : [7982.3906]
# 17064번 데이터의 예측차 : [5648.8887]
# 17065번 데이터의 예측차 : [4838.125]
# 17066번 데이터의 예측차 : [4006.3828]
# 17067번 데이터의 예측차 : [3076.1133]
# 17068번 데이터의 예측차 : [2529.1484]
# 17069번 데이터의 예측차 : [2354.4492]
# 17070번 데이터의 예측차 : [1960.4414]
# 17071번 데이터의 예측차 : [1373.625]
# 17072번 데이터의 예측차 : [871.49023]
# 17073번 데이터의 예측차 : [592.8086]
# 17074번 데이터의 예측차 : [77.82422]
# 17075번 데이터의 예측차 : [-284.25195]
# 17076번 데이터의 예측차 : [-682.959]
# 17077번 데이터의 예측차 : [-446.72656]
# 17078번 데이터의 예측차 : [-1053.9844]
# 17079번 데이터의 예측차 : [-1053.2129]
# 17080번 데이터의 예측차 : [-1552.0938]
# 17081번 데이터의 예측차 : [-1799.3184]
# 17082번 데이터의 예측차 : [-1297.6543]
# 17083번 데이터의 예측차 : [-689.3496]
# 17084번 데이터의 예측차 : [-483.64258]
# 17085번 데이터의 예측차 : [-445.12695]
# 17086번 데이터의 예측차 : [-260.98242]
# 17087번 데이터의 예측차 : [-153.39844]
# 17088번 데이터의 예측차 : [295.0078]
# 17089번 데이터의 예측차 : [428.17578]
# 17090번 데이터의 예측차 : [44.39453]
# 17091번 데이터의 예측차 : [-447.68945]
# 17092번 데이터의 예측차 : [-584.09766]
# 17093번 데이터의 예측차 : [-295.04688]
# 17094번 데이터의 예측차 : [-421.0918]
# 17095번 데이터의 예측차 : [-383.06836]
# 17096번 데이터의 예측차 : [-227.55273]
# 17097번 데이터의 예측차 : [-67.92578]
# 17098번 데이터의 예측차 : [-213.92773]
# 17099번 데이터의 예측차 : [106.302734]
# 17100번 데이터의 예측차 : [549.91406]
# 17101번 데이터의 예측차 : [500.1621]
# 17102번 데이터의 예측차 : [681.0254]
# 17103번 데이터의 예측차 : [440.99023]
# 17104번 데이터의 예측차 : [804.6992]
# 17105번 데이터의 예측차 : [844.83203]
# 17106번 데이터의 예측차 : [902.35547]
# 17107번 데이터의 예측차 : [908.95703]
# 17108번 데이터의 예측차 : [672.57227]
# 17109번 데이터의 예측차 : [348.9707]
# 17110번 데이터의 예측차 : [653.8379]
# 17111번 데이터의 예측차 : [1886.5293]
# 17112번 데이터의 예측차 : [2976.0762]
# 17113번 데이터의 예측차 : [3445.2168]
# 17114번 데이터의 예측차 : [3459.711]
# 17115번 데이터의 예측차 : [2130.3633]
# 17116번 데이터의 예측차 : [-918.3164]
# 17117번 데이터의 예측차 : [-1808.8594]
# 17118번 데이터의 예측차 : [-3090.0156]
# 17119번 데이터의 예측차 : [-3409.1797]
# 17120번 데이터의 예측차 : [-3983.2773]
# 17121번 데이터의 예측차 : [-5002.3438]
# 17122번 데이터의 예측차 : [-5085.492]
# 17123번 데이터의 예측차 : [-5193.7266]
# 17124번 데이터의 예측차 : [-4897.578]
# 17125번 데이터의 예측차 : [-4777.6953]
# 17126번 데이터의 예측차 : [-4702.8047]
# 17127번 데이터의 예측차 : [-4403.0195]
# 17128번 데이터의 예측차 : [-4281.7227]
# 17129번 데이터의 예측차 : [-3907.418]
# 17130번 데이터의 예측차 : [-3732.1445]
# 17131번 데이터의 예측차 : [-3552.4023]
# 17132번 데이터의 예측차 : [-3931.5469]
# 17133번 데이터의 예측차 : [-4201.6484]
# 17134번 데이터의 예측차 : [-4109.168]
# 17135번 데이터의 예측차 : [-4007.4102]
# 17136번 데이터의 예측차 : [-3775.586]
# 17137번 데이터의 예측차 : [-3476.75]
# 17138번 데이터의 예측차 : [-3002.8047]
# 17139번 데이터의 예측차 : [-2971.1016]
# 17140번 데이터의 예측차 : [-2535.5703]
# 17141번 데이터의 예측차 : [-2253.5703]
# 17142번 데이터의 예측차 : [-1781.2266]
# 17143번 데이터의 예측차 : [-1107.1133]
# 17144번 데이터의 예측차 : [-700.75]
# 17145번 데이터의 예측차 : [-303.3789]
# 17146번 데이터의 예측차 : [66.64844]
# 17147번 데이터의 예측차 : [649.1953]
# 17148번 데이터의 예측차 : [976.66406]
# 17149번 데이터의 예측차 : [1643.6348]
# 17150번 데이터의 예측차 : [2263.4102]
# 17151번 데이터의 예측차 : [2774.0156]
# 17152번 데이터의 예측차 : [3058.4668]
# 17153번 데이터의 예측차 : [4392.7773]
# 17154번 데이터의 예측차 : [4924.545]
# 17155번 데이터의 예측차 : [5841.834]
# 17156번 데이터의 예측차 : [6658.5]
# 17157번 데이터의 예측차 : [7187.0664]
# 17158번 데이터의 예측차 : [7480.006]
# 17159번 데이터의 예측차 : [7834.908]
# 17160번 데이터의 예측차 : [8398.855]
# 17161번 데이터의 예측차 : [9213.213]
# 17162번 데이터의 예측차 : [9605.883]
# 17163번 데이터의 예측차 : [9882.217]
# 17164번 데이터의 예측차 : [10362.689]
# 17165번 데이터의 예측차 : [10482.775]
# 17166번 데이터의 예측차 : [10796.293]
# 17167번 데이터의 예측차 : [11086.758]
# 17168번 데이터의 예측차 : [10752.072]
# 17169번 데이터의 예측차 : [10876.496]
# 17170번 데이터의 예측차 : [11119.885]
# 17171번 데이터의 예측차 : [11188.5625]
# 17172번 데이터의 예측차 : [11218.098]
# 17173번 데이터의 예측차 : [11342.736]
# 17174번 데이터의 예측차 : [11573.5625]
# 17175번 데이터의 예측차 : [11692.393]
# 17176번 데이터의 예측차 : [11872.146]
# 17177번 데이터의 예측차 : [11881.066]
# 17178번 데이터의 예측차 : [12027.846]
# 17179번 데이터의 예측차 : [11840.928]
# 17180번 데이터의 예측차 : [11791.027]
# 17181번 데이터의 예측차 : [11825.936]
# 17182번 데이터의 예측차 : [11875.736]
# 17183번 데이터의 예측차 : [12035.104]
# 17184번 데이터의 예측차 : [11961.936]
# 17185번 데이터의 예측차 : [11993.648]
# 17186번 데이터의 예측차 : [12213.842]
# 17187번 데이터의 예측차 : [11963.928]
# 17188번 데이터의 예측차 : [11861.766]
# 17189번 데이터의 예측차 : [11776.838]
# 17190번 데이터의 예측차 : [10907.418]
# 17191번 데이터의 예측차 : [10123.275]
# 17192번 데이터의 예측차 : [10396.047]
# 17193번 데이터의 예측차 : [10542.021]
# 17194번 데이터의 예측차 : [10211.207]
# 17195번 데이터의 예측차 : [10104.787]
# 17196번 데이터의 예측차 : [10630.814]
# 17197번 데이터의 예측차 : [11099.311]
# 17198번 데이터의 예측차 : [11798.801]
# 17199번 데이터의 예측차 : [11974.906]
# 17200번 데이터의 예측차 : [12434.674]
# 17201번 데이터의 예측차 : [12574.672]
# 17202번 데이터의 예측차 : [12336.943]
# 17203번 데이터의 예측차 : [11636.682]
# 17204번 데이터의 예측차 : [11832.385]
# 17205번 데이터의 예측차 : [11535.928]
# 17206번 데이터의 예측차 : [11667.545]
# 17207번 데이터의 예측차 : [10702.838]
# 17208번 데이터의 예측차 : [7718.717]
# 17209번 데이터의 예측차 : [5933.9844]
# 17210번 데이터의 예측차 : [5165.6055]
# 17211번 데이터의 예측차 : [4265.449]
# 17212번 데이터의 예측차 : [4269.0176]
# 17213번 데이터의 예측차 : [4281.203]
# 17214번 데이터의 예측차 : [4050.8164]
# 17215번 데이터의 예측차 : [3256.709]
# 17216번 데이터의 예측차 : [2724.2754]
# 17217번 데이터의 예측차 : [2294.9258]
# 17218번 데이터의 예측차 : [1456.5605]
# 17219번 데이터의 예측차 : [1470.5762]
# 17220번 데이터의 예측차 : [1367.8516]
# 17221번 데이터의 예측차 : [1019.4551]
# 17222번 데이터의 예측차 : [717.1035]
# 17223번 데이터의 예측차 : [431.56055]
# 17224번 데이터의 예측차 : [52.88867]
# 17225번 데이터의 예측차 : [75.62695]
# 17226번 데이터의 예측차 : [195.39648]
# 17227번 데이터의 예측차 : [223.24023]
# 17228번 데이터의 예측차 : [267.27344]
# 17229번 데이터의 예측차 : [109.47266]
# 17230번 데이터의 예측차 : [-10.5625]
# 17231번 데이터의 예측차 : [61.82422]
# 17232번 데이터의 예측차 : [-29.283203]
# 17233번 데이터의 예측차 : [67.96484]
# 17234번 데이터의 예측차 : [44.61328]
# 17235번 데이터의 예측차 : [41.80664]
# 17236번 데이터의 예측차 : [364.86133]
# 17237번 데이터의 예측차 : [658.2578]
# 17238번 데이터의 예측차 : [723.5801]
# 17239번 데이터의 예측차 : [791.64453]
# 17240번 데이터의 예측차 : [538.8926]
# 17241번 데이터의 예측차 : [855.94336]
# 17242번 데이터의 예측차 : [895.18164]
# 17243번 데이터의 예측차 : [1175.7129]
# 17244번 데이터의 예측차 : [1654.7324]
# 17245번 데이터의 예측차 : [1885.2129]
# 17246번 데이터의 예측차 : [2096.1523]
# 17247번 데이터의 예측차 : [2047.7383]
# 17248번 데이터의 예측차 : [2307.0762]
# 17249번 데이터의 예측차 : [2599.6387]
# 17250번 데이터의 예측차 : [3054.7988]
# 17251번 데이터의 예측차 : [3085.588]
# 17252번 데이터의 예측차 : [2644.3203]
# 17253번 데이터의 예측차 : [2145.1602]
# 17254번 데이터의 예측차 : [2533.8926]
# 17255번 데이터의 예측차 : [3380.463]
# 17256번 데이터의 예측차 : [4049.293]
# 17257번 데이터의 예측차 : [4629.785]
# 17258번 데이터의 예측차 : [4387.492]
# 17259번 데이터의 예측차 : [3268.2266]
# 17260번 데이터의 예측차 : [791.3203]
# 17261번 데이터의 예측차 : [-45.097656]
# 17262번 데이터의 예측차 : [-3226.5547]
# 17263번 데이터의 예측차 : [-4683.5547]
# 17264번 데이터의 예측차 : [-5541.084]
# 17265번 데이터의 예측차 : [-6214.492]
# 17266번 데이터의 예측차 : [-7254.824]
# 17267번 데이터의 예측차 : [-7457.582]
# 17268번 데이터의 예측차 : [-7576.9473]
# 17269번 데이터의 예측차 : [-7805.408]
# 17270번 데이터의 예측차 : [-8134.545]
# 17271번 데이터의 예측차 : [-8419.93]
# 17272번 데이터의 예측차 : [-8666.898]
# 17273번 데이터의 예측차 : [-8508.041]
# 17274번 데이터의 예측차 : [-8465.715]
# 17275번 데이터의 예측차 : [-8585.535]
# 17276번 데이터의 예측차 : [-8785.9375]
# 17277번 데이터의 예측차 : [-8777.027]
# 17278번 데이터의 예측차 : [-8972.227]
# 17279번 데이터의 예측차 : [-8183.6543]
# 17280번 데이터의 예측차 : [-7958.0234]
# 17281번 데이터의 예측차 : [-8398.367]
# 17282번 데이터의 예측차 : [-9613.734]
# 17283번 데이터의 예측차 : [-9960.125]
# 17284번 데이터의 예측차 : [-9090.275]
# 17285번 데이터의 예측차 : [-8820.953]
# 17286번 데이터의 예측차 : [-8000.8047]
# 17287번 데이터의 예측차 : [-8274.008]
# 17288번 데이터의 예측차 : [-8804.141]
# 17289번 데이터의 예측차 : [-8378.449]
# 17290번 데이터의 예측차 : [-8152.551]
# 17291번 데이터의 예측차 : [-7878.252]
# 17292번 데이터의 예측차 : [-7325.668]
# 17293번 데이터의 예측차 : [-7179.0273]
# 17294번 데이터의 예측차 : [-6222.996]
# 17295번 데이터의 예측차 : [-5585.84]
# 17296번 데이터의 예측차 : [-4821.3086]
# 17297번 데이터의 예측차 : [-4355.703]
# 17298번 데이터의 예측차 : [-4108.67]

# %%
history.history.keys()
plt.title("Training and validation loss")
plt.xlabel("epochs")
plt.ylabel("loss")
x = np.arange(0, 100)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
